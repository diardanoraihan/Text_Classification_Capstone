# %% [markdown]
# # CNN Classification with MPQA Dataset
# <hr>
#
# We will build a text classification model using CNN model on the MPQA Dataset. Since there is no standard train/test split for this dataset, we will use 10-Fold Cross Validation (CV).
#
# ## Load the library

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import random
from nltk.corpus import stopwords, twitter_samples
# from nltk.tokenize import TweetTokenizer
from sklearn.model_selection import KFold
from nltk.stem import PorterStemmer
from string import punctuation
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
import time

# %config IPCompleter.greedy=True
# %config IPCompleter.use_jedi=False
# nltk.download('twitter_samples')

# %% [markdown]
# ## Load the Dataset

# %%
corpus = pd.read_pickle('../../0_data/MPQA/MPQA.pkl')
corpus.label = corpus.label.astype(int)
print(corpus.shape)
corpus
# Out:
# (10606, 3)
#                   sentence  label  split
# 0              complaining      0  train
# 1       failing to support      0  train
# 2        desperately needs      0  train
# 3      many years of decay      0  train
# 4             no quick fix      0  train
# ...                    ...    ...    ...
# 10601                urged      1  train
# 10602       strictly abide      1  train
# 10603                 hope      1  train
# 10604       strictly abide      1  train
# 10605                           1  train
#
# [10606 rows x 3 columns]

# %%
corpus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10606 entries, 0 to 10605
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  10606 non-null  object
#  1   label     10606 non-null  int32
#  2   split     10606 non-null  object
# dtypes: int32(1), object(2)
# memory usage: 207.3+ KB

# %%
corpus.groupby( by='label').count()
# Out:
#        sentence  split
# label
# 0          7294   7294
# 1          3312   3312

# %%
# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)

# %% [markdown]
# ## Raw Number of Vocabulary

# %%
# Build the raw vocobulary for first inspection
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
vocab_raw = tokenizer.word_index
print('\nThe vocabulary size: {}\n'.format(len(vocab_raw)))
print(vocab_raw)
# Out:
# The vocabulary size: 6234
#
# {'the': 1, 'of': 2, 'to': 3, 'a': 4, 'and': 5, 'not': 6, 'is': 7, 'in': 8, 'be': 9, 'has': 10, 'for': 11, 'will': 12, 'have': 13, 'are': 14, 'support': 15, 'would': 16, 'was': 17, 'it': 18, 'evil': 19, 'on': 20, 'with': 21, 'as': 22, 'an': 23, 'no': 24, 'more': 25, "'s": 26, 'that': 27, 'its': 28, 'axis': 29, 'against': 30, 'can': 31, 'his': 32, 'by': 33, 'their': 34, 'want': 35, 'had': 36, 'do': 37, 'all': 38, 'were': 39, 'been': 40, 'rights': 41, 'one': 42, 'very': 43, 'war': 44, 'out': 45, 'called': 46, 'only': 47, 'so': 48, 'could': 49, 'at': 50, 'this': 51, 'human': 52, 'good': 53, 'us': 54, 'peace': 55, 'should': 56, 'most': 57, 'up': 58, 'free': 59, 'concern': 60, 'they': 61, 'world': 62, 'fair': 63, 'criticism': 64, 'from': 65, "n't": 66, 'does': 67, 'even': 68, 'or': 69, 'any': 70, 'accused': 71, 'hope': 72, 'if': 73, 'people': 74, 'than': 75, 'like': 76, 'such': 77, 'way': 78, 'warned': 79, 'expressed': 80, 'but': 81, 'legitimate': 82, 'just': 83, 'terrorism': 84, 'better': 85, 'being': 86, 'protest': 87, 'wants': 88, 'right': 89, 'great': 90, 'also': 91, 'violence': 92, 'strong': 93, 'our': 94, 'there': 95, 'refused': 96, 'may': 97, 'serious': 98, 'without': 99, 'international': 100, 'who': 101, 'criticized': 102, 'never': 103, 'into': 104, 'justice': 105, 'what': 106, 'condemned': 107, 'far': 108, 'opposition': 109, 'concerns': 110, 'did': 111, 'we': 112, 'government': 113, 'israeli': 114, 'respect': 115, 'still': 116, 'denied': 117, 'rejected': 118, 'confidence': 119, 'supported': 120, 'dangerous': 121, 'wanted': 122, 'concerned': 123, 'nothing': 124, 'country': 125, 'accept': 126, 'political': 127, 'threat': 128, 'too': 129, 'difficult': 130, 'new': 131, 'power': 132, 'him': 133, 'now': 134, 'urged': 135, 'long': 136, 'security': 137, 'made': 138, 'well': 139, 'democracy': 140, 'put': 141, 'own': 142, 'policy': 143, 'intimidation': 144, 'protests': 145, 'down': 146, 'problem': 147, 'under': 148, 'interests': 149, 'them': 150, 'much': 151, 'back': 152, 'he': 153, 'campaign': 154, 'time': 155, 'enemy': 156, 'considered': 157, 'palestinian': 158, 'peaceful': 159, 'get': 160, 'feel': 161, 'little': 162, 'further': 163, 'must': 164, 'away': 165, 'bad': 166, 'because': 167, 'itself': 168, 'worse': 169, 'critical': 170, 'force': 171, 'freedom': 172, 'those': 173, 'threatened': 174, 'economic': 175, 'some': 176, 'you': 177, 'failed': 178, 'state': 179, 'fear': 180, 'always': 181, 'hopes': 182, 'agreed': 183, 'many': 184, 'opposed': 185, 'over': 186, 'act': 187, 'these': 188, 'every': 189, 'go': 190, 'enough': 191, 'anti': 192, 'hoped': 193, 'think': 194, 'take': 195, 'american': 196, 'law': 197, 'refusal': 198, 'become': 199, 'anything': 200, 'end': 201, 'off': 202, 'possible': 203, 'seek': 204, 'mistake': 205, 'fears': 206, 'already': 207, 'stand': 208, 'warning': 209, 'going': 210, 'situation': 211, 'day': 212, 'high': 213, 'impossible': 214, 'israel': 215, 'committed': 216, 'states': 217, 'wish': 218, 'hard': 219, 'true': 220, 'best': 221, 'threatening': 222, 'i': 223, 'however': 224, 'about': 225, 'side': 226, 'am': 227, 'crisis': 228, 'quite': 229, 'same': 230, 'refuses': 231, 'allow': 232, 'legal': 233, 'threats': 234, 'help': 235, 'supporting': 236, 'calling': 237, 'desire': 238, 'supports': 239, 'years': 240, 'happy': 241, 'other': 242, 'charges': 243, 'worried': 244, 'worst': 245, 'seen': 246, 'seeking': 247, 'use': 248, 'willing': 249, 'rejection': 250, 'growing': 251, 'themselves': 252, 'terrorists': 253, 'sense': 254, 'action': 255, 'despite': 256, 'full': 257, 'calm': 258, 'positive': 259, 'democratic': 260, 'wrong': 261, 'satisfied': 262, 'continue': 263, 'major': 264, 'calls': 265, 'rigged': 266, 'victory': 267, 'suffering': 268, 'fight': 269, 'innocent': 270, 'terror': 271, 'national': 272, 'less': 273, 'make': 274, 'lack': 275, 'see': 276, 'blamed': 277, 'asked': 278, 'united': 279, 'himself': 280, 'how': 281, 'success': 282, 'inhumane': 283, 'commitment': 284, 'election': 285, 'poor': 286, 'call': 287,  ...

# %% [markdown]
# <!--## Split Dataset-->

# %% [markdown]
# # Data Preprocessing
# <hr>

# %% [markdown]
# ## Define `clean_doc` function

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stemmer = PorterStemmer()
    
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # remove remaining tokens that are not alphabetic
#     tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    tokens = [w for w in tokens if not w in stopwords]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) >= 1]
    # Stem the token
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

# %% [markdown]
# ## Develop Vocabulary
#
# A part of preparing text for text classification involves defining and tailoring the vocabulary of words supported by the model. **We can do this by loading all of the documents in the dataset and building a set of words.**
#
# The larger the vocabulary, the more sparse the representation of each word or document. So, we may decide to support all of these words, or perhaps discard some. The final chosen vocabulary can then be saved to a file for later use, such as filtering words in new documents in the future.

# %% [markdown]
# We can use `Counter` class and create an instance called `vocab` as follows:

# %%
from collections import Counter

vocab = Counter()

def add_doc_to_vocab(docs, vocab):
    '''
    input:
        docs: a list of sentences (docs)
        vocab: a vocabulary dictionary
    output:
        return an updated vocabulary
    '''
    for doc in docs:
        tokens = clean_doc(doc)
        vocab.update(tokens)
    return vocab

# %%
# Example
add_doc_to_vocab(sentences, vocab)
print(len(vocab))
vocab
# Out:
# 4163
# Counter({'complain': 13,
#          'fail': 36,
#          'support': 264,
#          'desper': 19,
#          'need': 17,
#          'mani': 20,
#          'year': 21,
#          'decay': 2,
#          'quick': 5,
#          'fix': 3,
#          'happi': 17,
#          'long': 28,
#          'pain': 9,
#          'nobodi': 3,
#          'complic': 8,
#          'process': 8,
#          'decad': 4,
#          'dramat': 6,
#          'econom': 22,
#          'declin': 14,
#          'suffer': 26,
#          'would': 188,
#          'sure': 10,
#          'higher': 5,
#          'still': 30,
#          'forbidden': 1,
#          'intox': 1,
#          'far': 32,
#          'perfect': 2,
#          'sour': 1,
#          'relat': 12,
#          'fell': 3,
#          'mount': 3,
#          'rivalri': 1,
#          'hostil': 14,
#          'nation': 42,
#          'accus': 85,
#          'bow': 6,
#          'total': 18,
#          'depend': 4,
#          'lose': 10,
#          'control': 13,
#          'warn': 76,
#          'heel': 1,
#          'pressur': 8,
#          'knee': 1,
#          'militari': 14,
#          'adventur': 3,
#          'boost': 3,
#          'threaten': 52,
#          'heavili': 4,
#          'arm': 6,
#          'place': 18,
#          'world': 59,
#          'danger': 43,
#          'flashpoint': 1,
#          'want': 162,
#          'avoid': 13,
#          'superfici': 2,
#          'exercis': 7,
#          'mere': 19,
#          'speak': 8,
#          'deep': 9,
#          'diverg': 2,
#          'neg': 11,
#          'bias': 12,
#          'claim': 28,
#          'complaint': 10,
#          'suspicion': 13,
#          'squeez': 1,
#          'ruinou': 1,
#          'mistak': 21,
#          'play': 19,
#          'fire': 11,
#          'subvert': 3,
#          'tri': 30,
#          'provok': 14,
#          'protest': 80,
#          'mdc': 2,
#          'lot': 8,
#          'express': 70,
#          'concern': 124,
#          'shoot': 5,
#          'man': 9,
#          'offic': 4,
#          'extrem': 18,
#          'keen': 1,
#          'fight': 20,
#          'agit': 3,
#          'allegedli': 1,
#          'remov': 10,
#          'violent': 10,
#          'reluct': 10,
#          'villain': 1,
#          'nt': 57,
#          'challeng': 14,
#          'flirt': 1,
#          'charg': 37,
#          'oppos': 38,
#          'alleg': 25,
#          'languag': 4,
#          'violenc': 38,
#          'presid': 11,
#          'mugab': 5,
#          'fear': 56,
#          'refus': 88,
#          'parliamentarian': 1,
#          'tens': 4,
#          'relationship': 6,
#          'renegad': 3,
#          'provinc': 3,
#          'unusu': 1,
#          'worri': 28,
#          'disapprov': 13,
#          'call': 122,
#          'stop': 16,
#          'tactic': 8,
#          'resort': 8,
#          'privat': 2,
#          'diplomaci': 3,
#          'gulf': 2,
#          'possess': 1,
#          'necessari': 6,
#          'expertis': 1,
#          'act': 29,
#          'objection': 1,
#          'brutal': 13,
#          'gain': 10,
#          'popular': 9,
#          'may': 36,
#          'feel': 37,
#          'uneasi': 4,
#          'question': 19,
#          'certain': 7,
#          'excess': 12,
#          'load': 4,
#          'sin': 3,
#          'function': 3,
#          'optim': 2,
#          'color': 1,
#          'leftist': 2,
#          'ideolog': 4,
#          'hype': 1,
#          'even': 55,
#          'wors': 22,
#          'foster': 1,
#          'trade': 2,
#          'anarchi': 2,
#          'blind': 13,
#          'rather': 7,
#          'target': 13,
#          'altern': 5,
#          'conflict': 7,
#          'isol': 11,
#          'ultim': 2,
#          'war': 78,
#          'cold': 10,
#          'monster': 2,
#          'immens': 2,
#          'slow': 1,
#          'closur': 1,
#          'implement': 4,
#          'unheard': 1,
#          'thought': 10,
#          'annoy': 3,
#          'lost': 14,
#          'game': 6,
#          'littl': 23,
#          'liber': 6,
#          'got': 5,
#          'capit': 1,
#          'live': 16,
#          'polit': 40,
#          'highli': 8,
#          'sophist': 2,
#          'societi': 8,
#          'summit': 1,
#          'reject': 66,
#          'think': 25,
#          'howev': 17,
#          'illeg': 10,
#          'crise': 3,
#          'fierc': 6,
#          'competit': 8,
#          'right': 120,
#          'compli': 2,
#          'relentlessli': 2,
#          'demonstr': 20,
#          'abandon': 11,
#          'discredit': 6,
#          'fact': 10,
#          'unpreced': 7,
#          'seriou': 36,
#          'level': 7,
#          'weak': 5,
#          'opposit': 34,
#          'hand': 27,
#          'concoct': 1,
#          'without': 36,
#          'effect': 20,
#          'critic': 150,
#          'poverti': 1,
#          'entitl': 3,
#          'reach': 7,
#          'boil': 1,
#          'point': 16,
#          'roughli': 1,
#          'lack': 22,
#          'conclus': 5,
#          'oper': 2,
#          'reduc': 5,
#          'margin': 3,
#          'secur': 28,
#          'firm': 13,
#          'flop': 1,
#          'complet': 19,
#          'reserv': 3,
#          'experi': 4,
#          'alreadi': 18,
#          'volatil': 2,
#          'intens': 8,
#          'dissatisfact': 8,
#          'frustrat': 15,
#          'breed': 5,
#          'insecur': 2,
#          'undermin': 16,
#          'posit': 28,
#          'particular': 4,
#          'stanc': 11,
#          'global': 12,
#          'easili': 5,
#          'rais': 24,
#          'kill': 21,
#          'remind': 3,
#          'whose': 4,
#          'land': 5,
#          'occupi': 4,
#          'scene': 3,
#          'destruct': 19,
#          'tragic': 5,
#          'shock': 8,
#          'persecut': 5,
#          'enorm': 13,
#          'injustic': 13,
#          'expel': 2,
#          'homeland': 2,
#          'bombard': 1,
#          'hatr': 13,
#          'sorri': 3,
#          'fall': 10,
#          'victim': 7,
#          'sympathi': 12,
#          'grief': 3,
#          'sorrow': 2,
#          'take': 35,
#          'advantag': 14,
#          'us': 62,
#          'tragedi': 8,
#          'demolish': 4,
#          'struck': 2,
#          'innoc': 15,
#          'women': 5,
#          'children': 6,
#          'defenseless': 1,
#          'civilian': 7,
#          'deni': 46,
#          'twist': 7,
#          'logic': 10,
#          'ongo': 3,
#          'devast': 12,
#          'destroy': 23,
#          'depriv': 9,
#          'minimum': 4,
#          'human': 98,
#          'could': 69,
#          'one': 82,
#          'worst': 16,
#          'day': 23,
#          'american': 24,
#          'histori': 12,
#          'great': 40,
#          'ghastli': 2,
#          'barbar': 5,
#          'strongli': 14,
#          'condemn': 61,
#          'label': 12,
#          'terror': 61,
#          'attack': 33,
#          'villag': 3,
#          'loss': 7,
#          'unreservedli': 1,
#          'strongest': 2,
#          'term': 10,
#          'time': 33,
#          'wanton': 2,
#          'properti': 2,
#          'turn': 30,
#          'stand': 27,
#          'idli': 1,
#          'disrupt': 3,
#          'peac': 91,
#          'mankind': 6,
#          'voic': 24,
#          'condol': 3,
#          'everyth': 11,
#          'good': 67,
#          'nice': 1,
#          'exceed': 2,
#          'continu': 38,
#          'keep': 13,
#          'aliv': 3,
#          'easi': 6,
#          'context': 1,
#          'struggl': 9,
#          'intern': 39,
#          'caus': 18,
#          'demis': 1,
#          'threat': 45,
#          'distanc': 3,
#          'america': 10,
#          'chapter': 1,
#          'common': 6,
#          'enemi': 36,
#          'succeed': 12,
#          'seen': 16,
#          'behind': 14,
#          'chechen': 1,
#          'much': 25,
#          'expect': 11,
#          'written': 3,
#          'name': 8,
#          'moscow': 2,
#          'registr': 2,
#          'page': 3,
#          'side': 26,
#          'stereotyp': 3,
#          'rub': 4,
#          'palm': 3,
#          'length': 4,
#          'suspect': 15,
#          'leak': 3,
#          'frontier': 1,
#          'unsur': 2,
#          'awar': 5,
#          'ensur': 9,
#          'instabl': 4,
#          'milit': 1,
#          'mastermind': 4,
#          'disastr': 6,
#          'unavoid': 1,
#          'culmin': 1,
#          'trump': 2,
#          'card': 1,
#          'commit': 49,
#          'difficult': 28,
#          'unbeliev': 1,
#          'provoc': 15,
#          'evil': 152,
#          'foundat': 2,
#          'west': 6,
#          'degre': 5,
#          'repress': 11,
#          'sat': 2,
#          'back': 42,
#          'fold': 1,
#          'made': 27,
#          'hostag': 6,
#          'remain': 19,
#          'riski': 5,
#          'enterpris': 1,
#          'often': 8,
#          'confus': 12,
#          'thank': 21,
#          'taliban': 3,
#          'regim': 11,
#          'imperfect': 1,
#          'well': 27,
#          'defin': 1,
#          'pervers': 4,
#          'reaction': 8,
#          'repuls': 1,
#          'real': 11,
#          'unfortun': 11,
#          'bitter': 9,
#          'pill': 1,
#          'swallow': 2,
#          'mire': 1,
#          'increasingli': 11,
#          'uneas': 1,
#          'affront': 3,
#          'law': 28,
#          'democraci': 28,
#          'new': 28,
#          'dimens': 1,
#          'crime': 18,
#          'islam': 4,
#          'perceiv': 3,
#          'consid': 38,
#          'destabilis': 1,
#          'pretext': 17,
#          'crack': 6,
#          'legitim': 44,
#          'dissent': 6,
#          'jeopardis': 1,
#          'order': 13,
#          'creat': 12,
#          'troubl': 10,
#          'peopl': 50,
#          'rise': 10,
#          'mix': 4,
#          'expens': 5,
#          'disput': 7,
#          'unequivoc': 3,
#          'unpalat': 1,
#          'measur': 10,
#          'appal': 2,
#          'find': 15,
#          'afraid': 7,
#          'say': 13,
#          'self': 13,
#          'style': 4,
#          'sever': 19,
#          'tie': 4,
#          'sanction': 6,
#          'bust': 1,
#          'sympath': 1,
#          'displeasur': 3,
#          'lash': 5,
#          'loom': 1,
#          'join': 9,
#          'prevent': 12,
#          'toler': 14,
#          'turbul': 2,
#          'yet': 9,
#          'anoth': 13,
#          'burden': 11,
#          'perpetr': 6,
#          'disrespect': 1,
#          'advic': 6,
#          'crush': 11,
#          'predatori': 2,
#          'behaviour': 1,
#          'inevit': 7,
#          'chao': 4,
#          'assassin': 17,
#          'blatantli': 1,
#          'obstruct': 6,
#          'cycl': 4,
#          'decept': 3,
#          'ploy': 2,
#          'disregard': 9,
#          'fair': 60,
#          'weather': 1,
#          'friend': 15,
#          'abhorr': 1,
#          'affect': 10,
#          'everi': 20,
#          'corner': 7,
#          'earth': 6,
#          'utter': 2,
#          'defianc': 4,
#          'recip': 1,
#          'disast': 9,
#          'aggress': 29,
#          'persist': 5,
#          'deliber': 6,
#          'fuell': 1,
#          'expansionist': 4,
#          'tel': 1,
#          'aviv': 1,
#          'notic': 1,
#          'opt': 5,
#          'brute': 1,
#          'forc': 43,
#          'callous': 2,
#          'exploit': 7,
#          'intensifi': 3,
#          'acceler': 2,
#          'seek': 43,
#          'manipul': 8,
#          'risk': 15,
#          'divid': 1,
#          'rule': 19,
#          'condit': 9,
#          'former': 5,
#          'state': 42,
#          'tension': 13,
#          'confisc': 2,
#          'deal': 9,
#          'improv': 12,
#          'carbon': 1,
#          'copi': 2,
#          'edg': 4,
#          'mutin': 1,
#          'medic': 3,
#          'educ': 2,
#          'social': 14,
#          'life': 14,
#          'use': 36,
#          'factor': 3,
#          'like': 67,
#          'unabl': 10,
#          'meet': 9,
#          'kind': 15,
#          'collect': 6,
#          'punish': 12,
#          'heavi': 6,
#          'also': 40,
#          'reflect': 13,
#          'way': 47,
#          'inalien': 2,
#          'palestinian': 39,
#          'work': 19,
#          'push': 11,
#          'brag': 2,
#          'thing': 17,
#          'larg': 7,
#          'hegemoni': 5,
#          'first': 12,
#          'will': 19,
#          'recogn': 22,
#          'add': 1,
#          'fuel': 3,
#          'rage': 5,
#          'labyrinth': 3,
#          'tunnel': 1,
#          'justifi': 14,
#          'excus': 14,
#          'problem': 37,
#          'clamp': 1,
#          'freedom': 26,
#          'widespread': 14,
#          'tortur': 16,
#          'doubl': 11,
#          'standard': 17,
#          'pursu': 7,
#          'trend': 1,
#          'violat': 58,
#          'shortcom': 3,
#          'omin': 2,
#          'phenomenon': 2,
#          'afghan': 3,
#          'crisi': 17,
#          'forestal': 1,
#          'oil': 3,
#          'price': 3,
#          'intrigu': 1,
#          'go': 38,
#          'silent': 1,
#          'hidden': 2,
#          'subsidi': 1,
#          'look': 32,
#          'bleak': 2,
#          'futur': 8,
#          'everybodi': 1,
#          'jump': 3,
#          'check': 3,
#          'whether': 7,
#          'proper': 7,
#          'safeti': 6,
#          'net': 2,
#          'bottom': 1,
#          'advers': 4,
#          'must': 23,
#          'virtual': 2,
#          'noth': 29,
#          'breach': 1,
#          'constitut': 15,
#          'fundament': 11,
#          'unfair': 10,
#          'unjust': 6,
#          'render': 2,
#          'worthless': 1,
#          'ban': 5,
#          'dont': 1,
#          'reap': 2,
#          'benefit': 17,
#          'mock': 2,
#          'globalis': 1,
#          'greenpeac': 1,
#          'million': 6,
#          'street': 9,
#          'hide': 6,
#          'protestor': 1,
#          'respons': 27,
#          'island': 5,
#          'biggest': 9,
#          'face': 20,
#          'today': 2,
#          'vanish': 2,
#          'leav': 3,
#          'home': 7,
#          'disadvantag': 4,
#          'situat': 18,
#          'unfeas': 1,
#          'bill': 2,
#          'promis': 29,
#          'cheap': 1,
#          'kept': 5,
#          'deliv': 5,
#          'blow': 10,
#          'grim': 6,
#          'statist': 1,
#          'trot': 1,
#          'love': 6,
#          'incapac': 2,
#          'put': 33,
#          'direct': 7,
#          'recept': 3,
#          'elsewher': 1,
#          'repres': 5,
#          'pessimist': 5,
#          'outlook': 1,
#          'relish': 2,
#          'role': 9,
#          'cassandra': 1,
#          'philippin': 1,
#          'polic': 2,
#          'paint': 6,
#          'pictur': 3,
#          'breakdown': 4,
#          'less': 15,
#          'alarm': 15,
#          'skin': 2,
#          'make': 35,
#          'govern': 32,
#          'nemesi': 1,
#          'sap': 1,
#          'countri': 41,
#          'energi': 2,
#          'issu': 20,
#          'advisori': 2,
#          'bring': 11,
#          'turmoil': 2,
#          'gener': 10,
#          'anxieti': 2,
#          'doomsday': 1,
#          'scenario': 2,
#          'travel': 2,
#          'ca': 6,
#          'buri': 3,
#          'head': 10,
#          'sand': 1,
#          'misplac': 1,
#          'strateg': 5,
#          'prioriti': 10,
#          'strong': 38,
#          'percept': 7,
#          'embarrass': 6,
#          'administr': 4,
#          'scandal': 7,
#          'monger': 3,
#          'grow': 18,
#          'compatriot': 2,
#          'frighten': 7,
#          'tourist': 1,
#          'investor': 1,
#          'away': 23,
#          'damag': 25,
#          'crusad': 2,
#          'receiv': 6,
#          'fake': 2,
#          'uncertainti': 8,
#          'sent': 9,
#          'bell': 2,
#          'ring': 4,
#          'daunt': 1,
#          'spark': 3,
#          'recoveri': 1,
#          'form': 7,
#          'nationalist': 2,
#          'racism': 1,
#          'chang': 24,
#          'come': 15,
#          'stake': 3,
#          'quit': 18,
#          'naiv': 4,
#          'ignor': 16,
#          'spite': 5,
#          'blame': 32,
#          'fruitless': 1,
#          'effort': 13,
#          'empti': 7,
#          'failur': 14,
#          'foregon': 2,
#          'stingi': 1,
#          'wait': 7,
#          'anxious': 3,
#          'sort': 8,
#          'vain': 2,
#          'never': 34,
#          'guilti': 3,
#          'parti': 9,
#          'went': 11,
#          'shortsighted': 1,
#          'irrespons': 8,
#          'pay': 6,
#          'enough': 20,
#          'show': 22,
#          'modicum': 1,
#          'disciplin': 4,
#          'cool': 2,
#          'approach': 8,
#          'realiz': 11,
#          'variou': 1,
#          'mind': 7,
#          'becom': 26,
#          'irrit': 10,
#          'obviou': 3,
#          'domest': 5,
#          'difficulti': 11,
#          'leap': 2,
#          'void': 1,
#          'minist': 2,
#          'confront': 7,
#          'tendenc': 2,
#          'toward': 18,
#          'letterhead': 1,
#          'anyth': 19,
#          'heighten': 2,
#          'bother': 3,
#          'credibl': 19,
#          'unlik': 3,
#          'appar': 6,
#          'strategi': 7,
#          'zone': 1,
#          'delug': 1,
#          'doubt': 24,
#          'truli': 3,
#          'stress': 5,
#          'scourg': 2,
#          'ill': 6,
#          'serious': 10,
#          'hinder': 2,
#          'unrealist': 5,
#          'alien': 7,
#          'deterior': 7,
#          'pass': 6,
#          'horror': 4,
#          'hamper': 3,
#          'highest': 1,
#          'abruptli': 1,
#          'shelv': 1,
#          'altogeth': 1,
#          'see': 19,
#          'red': 4,
#          'light': 4,
#          'big': 7,
#          'unmistak': 1,
#          'potenti': 7,
#          'arduou': 1,
#          'negoti': 7,
#          'formid': 2,
#          'deadlock': 4,
#          'intend': 9,
#          'ratifi': 3,
#          'particularli': 11,
#          'might': 11,
#          'apart': 3,
#          'high': 19,
#          'distress': 4,
#          'rocket': 2,
#          'admit': 8,
#          'handicap': 1,
#          'pour': 3,
#          'money': 9,
#          'weaken': 5,
#          'soon': 4,
#          'accept': 54,
#          'lawbreak': 1,
#          'person': 19,
#          'inhospit': 1,
#          'ground': 10,
#          'serv': 9,
#          'give': 26,
#          'file': 3,
#          'held': 8,
#          'regard': 18,
#          'interest': 52,
#          'suffici': 6,
#          'allianc': 3,
#          'apathi': 2,
#          'disagr': 7,
#          'basic': 5,
#          'contravent': 2,
#          'choru': 5,
#          'alway': 21,
#          'divest': 1,
#          'basi': 6,
#          'blatant': 6,
#          'case': 9,
#          'discrimin': 5,
#          'consider': 9,
#          'heard': 3,
#          'anyon': 6,
#          'trial': 3,
#          'swift': 2,
#          'hollow': 1,
#          'toll': 4,
#          'smooth': 2,
#          'either': 8,
#          'significantli': 2,
#          'repeatedli': 10,
#          'outrag': 11,
#          'harm': 12,
#          'develop': 16,
#          'stymi': 1,
#          'protect': 15,
#          'insuffici': 4,
#          'evad': 1,
#          'past': 6,
#          'hundr': 2,
#          'thousand': 13,
#          'fulfil': 4,
#          'oblig': 4,
#          'absorb': 2,
#          'gestur': 1,
#          'signific': 7,
#          'road': 6,
#          'ahead': 6,
#          'surg': 4,
#          'deleteri': 1,
#          'suddenli': 2,
#          'prove': 6,
#          'imposs': 18,
#          'martyr': 1,
#          'resist': 14,
#          'disguis': 3,
#          'atmospher': 4,
#          'reign': 1,
#          'swiftli': 2,
#          'countermand': 1,
#          'foretast': 1,
#          'bad': 23,
#          'memori': 1,
#          'rebuf': 3,
#          'retali': 4,
#          'declar': 10,
#          'deter': 1,
#          'alon': 8,
#          'cater': 1,
#          'coal': 2,
#          'baron': 1,
#          'goe': 7,
#          'spi': 2,
#          'plane': 1,
#          'permit': 3,
#          'doorstep': 1,
#          'apolog': 2,
#          'consist': 4,
#          'terrorist': 25,
#          'flash': 2,
#          'carrot': 2,
#          'stick': 5,
#          'object': 29,
#          'rubbl': 1,
#          'legitimaci': 12,
#          'sens': 20,
#          'oppress': 15,
#          'activ': 11,
#          'vindict': 2,
#          'isra': 32,
#          'action': 17,
#          'falter': 1,
#          'result': 8,
#          'israel': 18,
#          'intransig': 1,
#          'despit': 16,
#          'weapon': 9,
#          'achiev': 17,
#          'full': 16,
#          'comprehens': 5,
#          'quiet': 2,
#          'reveng': 6,
#          'demand': 17,
#          'overlook': 2,
#          'attempt': 11,
#          'suppress': 10,
#          'calm': 16,
#          'power': 32,
#          'shrink': 1,
#          'chavez': 8,
#          'incap': 5,
#          'leader': 10,
#          'misfortun': 4,
#          'main': 5,
#          'area': 4,
#          'mean': 18,
#          'resound': 2,
#          'sustain': 5,
#          'regret': 5,
#          'embark': 3,
#          'trampl': 5,
#          'upon': 10,
#          'deplor': 2,
#          'prohibit': 2,
#          'denounc': 23,
#          'last': 13,
#          'move': 11,
#          'contest': 6,
#          'unconstitut': 2,
#          'republ': 4,
#          'china': 7,
#          'quarri': 1,
#          'ambit': 7,
#          'crafti': 2,
#          'ruse': 1,
#          'pretend': 7,
#          'unstabl': 2,
#          'infuri': 4,
#          'sphere': 2,
#          'domin': 11,
#          'adamantli': 1,
#          'employ': 1,
#          'trick': 5,
#          'scheme': 3,
#          'due': 6,
#          'settlement': 10,
#          'burn': 2,
#          'territori': 6,
#          'sympathet': 2,
#          'wound': 3,
#          'hesit': 3,
#          'took': 13,
#          'imperi': 3,
#          'sourc': 3,
#          'unchang': 1,
#          'insult': 8,
#          'reason': 24,
#          'optimist': 12,
#          'vassal': 1,
#          'abid': 8,
#          'decis': 17,
#          'disturb': 7,
#          'appear': 15,
#          'drag': 5,
#          'feet': 2,
#          'atroci': 3,
#          'stratagem': 1,
#          'abus': 22,
#          'rampant': 2,
#          'ruthlessli': 1,
#          'deem': 4,
#          'realli': 14,
#          'revert': 2,
#          '1960': 1,
#          'subject': 8,
#          'simpli': 9,
#          'adjud': 1,
#          'passag': 1,
#          'forget': 6,
#          'pick': 9,
#          'quarrel': 5,
#          'send': 7,
#          'disagre': 13,
#          'surpris': 10,
#          'talk': 8,
#          'wonder': 3,
#          'imperialist': 9,
#          'reactionari': 1,
#          'teach': 2,
#          'lesson': 5,
#          'two': 9,
#          'qualifi': 5,
#          'indiffer': 5,
#          'gaze': 1,
#          'seem': 21,
#          'extra': 2,
#          'judici': 1,
#          'liquid': 3,
#          'instrument': 5,
#          'hope': 105,
#          'massacr': 9,
#          'sabra': 1,
#          'shatila': 1,
#          'deriv': 1,
#          'encourag': 25,
#          'chanc': 11,
#          'exodu': 2,
#          'collaps': 10,
#          'death': 10,
#          'normal': 4,
#          'settl': 4,
#          'someon': 2,
#          'els': 4,
#          'absolut': 10,
#          'extremist': 8,
#          'drive': 3,
#          'approv': 27,
#          'ask': 26,
#          'polici': 40,
#          'eat': 3,
#          'feed': 1,
#          'longer': 9,
#          'encyst': 1,
#          'expuls': 1,
#          'contradictori': 2,
#          'believ': 24,
#          'end': 25,
#          'french': 1,
#          ...})

# %%
vocab.items()
# Out:
# dict_items([('complain', 13), ('fail', 36), ('support', 264), ('desper', 19), ('need', 17), ('mani', 20), ('year', 21), ('decay', 2), ('quick', 5), ('fix', 3), ('happi', 17), ('long', 28), ('pain', 9), ('nobodi', 3), ('complic', 8), ('process', 8), ('decad', 4), ('dramat', 6), ('econom', 22), ('declin', 14), ('suffer', 26), ('would', 188), ('sure', 10), ('higher', 5), ('still', 30), ('forbidden', 1), ('intox', 1), ('far', 32), ('perfect', 2), ('sour', 1), ('relat', 12), ('fell', 3), ('mount', 3), ('rivalri', 1), ('hostil', 14), ('nation', 42), ('accus', 85), ('bow', 6), ('total', 18), ('depend', 4), ('lose', 10), ('control', 13), ('warn', 76), ('heel', 1), ('pressur', 8), ('knee', 1), ('militari', 14), ('adventur', 3), ('boost', 3), ('threaten', 52), ('heavili', 4), ('arm', 6), ('place', 18), ('world', 59), ('danger', 43), ('flashpoint', 1), ('want', 162), ('avoid', 13), ('superfici', 2), ('exercis', 7), ('mere', 19), ('speak', 8), ('deep', 9), ('diverg', 2), ('neg', 11), ('bias', 12), ('claim', 28), ('complaint', 10), ('suspicion', 13), ('squeez', 1), ('ruinou', 1), ('mistak', 21), ('play', 19), ('fire', 11), ('subvert', 3), ('tri', 30), ('provok', 14), ('protest', 80), ('mdc', 2), ('lot', 8), ('express', 70), ('concern', 124), ('shoot', 5), ('man', 9), ('offic', 4), ('extrem', 18), ('keen', 1), ('fight', 20), ('agit', 3), ('allegedli', 1), ('remov', 10), ('violent', 10), ('reluct', 10), ('villain', 1), ('nt', 57), ('challeng', 14), ('flirt', 1), ('charg', 37), ('oppos', 38), ('alleg', 25), ('languag', 4), ('violenc', 38), ('presid', 11), ('mugab', 5), ('fear', 56), ('refus', 88), ('parliamentarian', 1), ('tens', 4), ('relationship', 6), ('renegad', 3), ('provinc', 3), ('unusu', 1), ('worri', 28), ('disapprov', 13), ('call', 122), ('stop', 16), ('tactic', 8), ('resort', 8), ('privat', 2), ('diplomaci', 3), ('gulf', 2), ('possess', 1), ('necessari', 6), ('expertis', 1), ('act', 29), ('objection', 1), ('brutal', 13), ('gain', 10), ('popular', 9), ('may', 36), ('feel', 37), ('uneasi', 4), ('question', 19), ('certain', 7), ('excess', 12), ('load', 4), ('sin', 3), ('function', 3), ('optim', 2), ('color', 1), ('leftist', 2), ('ideolog', 4), ('hype', 1), ('even', 55), ('wors', 22), ('foster', 1), ('trade', 2), ('anarchi', 2), ('blind', 13), ('rather', 7), ('target', 13), ('altern', 5), ('conflict', 7), ('isol', 11), ('ultim', 2), ('war', 78), ('cold', 10), ('monster', 2), ('immens', 2), ('slow', 1), ('closur', 1), ('implement', 4), ('unheard', 1), ('thought', 10), ('annoy', 3), ('lost', 14), ('game', 6), ('littl', 23), ('liber', 6), ('got', 5), ('capit', 1), ('live', 16), ('polit', 40), ('highli', 8), ('sophist', 2), ('societi', 8), ('summit', 1), ('reject', 66), ('think', 25), ('howev', 17), ('illeg', 10), ('crise', 3), ('fierc', 6), ('competit', 8), ('right', 120), ('compli', 2), ('relentlessli', 2), ('demonstr', 20), ('abandon', 11), ('discredit', 6), ('fact', 10), ('unpreced', 7), ('seriou', 36), ('level', 7), ('weak', 5), ('opposit', 34), ('hand', 27), ('concoct', 1), ('without', 36), ('effect', 20), ('critic', 150), ('poverti', 1), ('entitl', 3), ('reach', 7), ('boil', 1), ('point', 16), ('roughli', 1), ('lack', 22), ('conclus', 5), ('oper', 2), ('reduc', 5), ('margin', 3), ('secur', 28), ('firm', 13), ('flop', 1), ('complet', 19), ('reserv', 3), ('experi', 4), ('alreadi', 18), ('volatil', 2), ('intens', 8), ('dissatisfact', 8), ('frustrat', 15), ('breed', 5), ('insecur', 2), ('undermin', 16), ('posit', 28), ('particular', 4), ('stanc', 11), ('global', 12), ('easili', 5), ('rais', 24), ('kill', 21), ('remind', 3), ('whose', 4), ('land', 5), ('occupi', 4), ('scene', 3), ('destruct', 19), ('tragic', 5), ('shock', 8), ('persecut', 5), ('enorm', 13), ('injustic', 13), ('expel', 2), ('homeland', 2), ('bombard', 1), ('hatr', 13), ('sorri', 3), ('fall', 10), ('victim', 7), ('sympathi', 12), ('grief', 3), ('sorrow', 2), ('take', 35), ('advantag', 14), ('us', 62), ('tragedi', 8), ('demolish', 4), ('struck', 2), ('innoc', 15), ('women', ...

# %%
#########################
# Define the vocabulary #
#########################

from collections import Counter
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stemmer = PorterStemmer()
    
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # filter out stop words
    tokens = [w for w in tokens if not w in stopwords]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) >= 1]
    # Stem the token
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

def add_doc_to_vocab(docs, vocab):
    '''
    input:
        docs: a list of sentences (docs)
        vocab: a vocabulary dictionary
    output:
        return an updated vocabulary
    '''
    for doc in docs:
        tokens = clean_doc(doc)
        vocab.update(tokens)
    
    return vocab
        

# prepare cross validation with 10 splits and shuffle = True
kfold = KFold(10, True)

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)

acc_list = []

# kfold.split() will return set indices for each split
for train, test in kfold.split(sentences):
    # Instantiate a vocab object
    vocab = Counter()
    
    train_x, test_x = [], []
    train_y, test_y = [], []
    
    for i in train:
        train_x.append(sentences[i])
        train_y.append(labels[i])
    
    for i in test:
        test_x.append(sentences[i])
        test_y.append(labels[i])
    
    vocab = add_doc_to_vocab(train_x, vocab)
    print(len(train_x), len(test_x))
    print(len(vocab))
# Out:
# C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass shuffle=True as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# 9545 1061
# 3972
# 9545 1061
# 3978
# 9545 1061
# 3975
# 9545 1061
# 3983
# 9545 1061
# 3984
# 9545 1061
# 3959
# 9546 1060
# 3964
# 9546 1060
# 3975
# 9546 1060
# 4005
# 9546 1060
# 3959

# %% [markdown]
# <dir>

# %% [markdown]
# # Bag-of-Words Representation
# <hr>
#
# Once we define our vocab obtained from the training data, we need to **convert each review into a representation that we can feed to a Multilayer Perceptron Model.**
#
# As a reminder, here are the summary what we will do:
# - extract features from the text so the text input can be used with ML algorithms like neural networks
# - we do by converting the text into a vector representation. The larger the vocab, the longer the representation.
# - we will score the words in a document inside the vector. These scores are placed in the corresponding location in the vector representation.

# %%
def doc_to_line(doc):
    tokens = clean_doc(doc)
    # filter by vocab
    tokens = [token for token in tokens if token in vocab]
    line = ' '.join([token for token in tokens])
    return line

# %%
def clean_docs(docs):
    lines = []
    for doc in docs:
        line = doc_to_line(doc)
        lines.append(line)
    return lines

# %%
print(sentences[:5])
clean_sentences = clean_docs(sentences[:5])
print()
print( clean_sentences)
# Out:
# ['complaining', 'failing to support', 'desperately needs', 'many years of decay', 'no quick fix']
#
# ['complain', 'fail support', 'desper need', 'mani year decay', 'quick fix']

# %% [markdown]
# ## Bag-of-Words Vectors
#
# We will use the **Keras API** to **convert sentences to encoded document vectors**. Although the `Tokenizer` class from TF Keras provides cleaning and vocab definition, it's better we do this ourselves so that we know exactly we are doing.

# %%
def create_tokenizer(sentence):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %% [markdown]
# This process determines a consistent way to **convert the vocabulary to a fixed-length vector**, which is the total number of words in the vocabulary `vocab`.
#
# Next, documents can then be encoded using the Tokenizer by calling `texts_to_matrix()`.
#
# The function takes both a list of documents to encode and an encoding mode, which is the method used to score words in the document. Here we specify **freq** to score words based on their frequency in the document.
#
# This can be used to encode the loaded training and test data, for example:
#
# `Xtrain = tokenizer.texts_to_matrix(train_docs, mode='freq')`
#
# `Xtest = tokenizer.texts_to_matrix(test_docs, mode='freq')`

# %%
#########################
# Define the vocabulary #
#########################

from collections import Counter
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stemmer = PorterStemmer()
    
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # filter out stop words
    tokens = [w for w in tokens if not w in stopwords]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) >= 1]
    # Stem the token
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

def add_doc_to_vocab(docs, vocab):
    '''
    input:
        docs: a list of sentences (docs)
        vocab: a vocabulary dictionary
    output:
        return an updated vocabulary
    '''
    for doc in docs:
        tokens = clean_doc(doc)
        vocab.update(tokens)
    return vocab
        
def doc_to_line(doc, vocab):
    tokens = clean_doc(doc)
    # filter by vocab
    tokens = [token for token in tokens if token in vocab]
    line = ' '.join(tokens)
    return line

def clean_docs(docs, vocab):
    lines = []
    for doc in docs:
        line = doc_to_line(doc, vocab)
        lines.append(line)
    return lines

def create_tokenizer(sentences):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(sentences)
    return tokenizer

# prepare cross validation with 10 splits and shuffle = True
kfold = KFold(10, True)

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)

acc_list = []

# kfold.split() will return set indices for each split
for train, test in kfold.split(sentences):
    # Instantiate a vocab object
    vocab = Counter()
    
    train_x, test_x = [], []
    train_y, test_y = [], []
    
    for i in train:
        train_x.append(sentences[i])
        train_y.append(labels[i])
    
    for i in test:
        test_x.append(sentences[i])
        test_y.append(labels[i])
    
    # Turn the labels into a numpy array
    train_y = np.array(train_y)
    test_y = np.array(test_y)
    
    # Define a vocabulary for each fold
    vocab = add_doc_to_vocab(train_x, vocab)
    print('The number of vocab: ', len(vocab))
    
    # Clean the sentences
    train_x = clean_docs(train_x, vocab)
    test_x = clean_docs(test_x, vocab)
    
    # Define the tokenizer
    tokenizer = create_tokenizer(train_x)
    
    # encode data using freq mode
    Xtrain = tokenizer.texts_to_matrix(train_x, mode='freq')
    Xtest = tokenizer.texts_to_matrix(test_x, mode='freq')
   

print(Xtrain.shape)
print(train_x[0])
print(Xtrain[0])
print(Xtest.shape)
print(test_x[0])
print(Xtest[0])
# Out:
# The number of vocab:  3979
# The number of vocab:  3979
# The number of vocab:  3955
# The number of vocab:  3963
# The number of vocab:  3985
# The number of vocab:  4002
# The number of vocab:  3970
# The number of vocab:  3971
# The number of vocab:  3962
# The number of vocab:  3980
# (9546, 3981)
# complain
# [0. 0. 0. ... 0. 0. 0.]
# (1060, 3981)
# long pain
# [0. 0. 0. ... 0. 0. 0.]

# %% [markdown]
# # Training and Testing the Model

# %% [markdown]
# ## CNN Model
#
# Now, we will build Convolutional Neural Network (CNN) models to classify encoded documents as either positive or negative.
#
# The model takes inspiration from `CNN for Sentence Classification` by *Yoon Kim*.
#
# Now, we will define our CNN model as follows:
# - One Conv layer with 100 filters, kernel size 5, and relu activation function;
# - One MaxPool layer with pool size = 2;
# - One Dropout layer after flattened;
# - Optimizer: Adam (The best learning algorithm so far)
# - Loss function: binary cross-entropy (suited for binary classification problem)
#
# **Note**:
# - The whole purpose of dropout layers is to tackle the problem of over-fitting and to introduce generalization to the model. Hence it is advisable to keep dropout parameter near 0.5 in hidden layers.
# - https://missinglink.ai/guides/keras/keras-conv1d-working-1d-convolutional-neural-networks-keras/

# %%
def train_cnn(train_x, train_y, batch_size = 50, epochs = 10, verbose =2):
    
    n_words = train_x.shape[1]
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(filters=100, kernel_size=5, activation='relu', input_shape=(n_words,1)),
        tf.keras.layers.MaxPool1D(2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0,5),
        tf.keras.layers.Dense( units=1, activation='sigmoid')
    ])
    
    model.compile( loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    model.fit(train_x, train_y, batch_size, epochs, verbose)
    return model

# %% [markdown]
# ## Train and Test the Model

# %%
#########################
# Define the vocabulary #
#########################

from collections import Counter
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stemmer = PorterStemmer()
    
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # filter out stop words
    tokens = [w for w in tokens if not w in stopwords]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) >= 1]
    # Stem the token
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

def add_doc_to_vocab(docs, vocab):
    '''
    input:
        docs: a list of sentences (docs)
        vocab: a vocabulary dictionary
    output:
        return an updated vocabulary
    '''
    for doc in docs:
        tokens = clean_doc(doc)
        vocab.update(tokens)
    return vocab
        
def doc_to_line(doc, vocab):
    tokens = clean_doc(doc)
    # filter by vocab
    tokens = [token for token in tokens if token in vocab]
    line = ' '.join(tokens)
    return line

def clean_docs(docs, vocab):
    lines = []
    for doc in docs:
        line = doc_to_line(doc, vocab)
        lines.append(line)
    return lines

def create_tokenizer(sentences):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(sentences)
    return tokenizer

def train_cnn(train_x, train_y, batch_size = 50, epochs = 10, verbose =2):
    
    n_words = train_x.shape[1]
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(filters=100, kernel_size=5, activation='relu', input_shape=(n_words,1)),
        tf.keras.layers.MaxPool1D(2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense( units=1, activation='sigmoid')
    ])
    
    model.compile( loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    model.fit(train_x, train_y, batch_size, epochs, verbose)
    return model

# prepare cross validation with 10 splits and shuffle = True
kfold = KFold(10, True)

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)

acc_list = []

# kfold.split() will return set indices for each split
for train, test in kfold.split(sentences):
    # Instantiate a vocab object
    vocab = Counter()
    
    train_x, test_x = [], []
    train_y, test_y = [], []
    
    for i in train:
        train_x.append(sentences[i])
        train_y.append(labels[i])
    
    for i in test:
        test_x.append(sentences[i])
        test_y.append(labels[i])
    
    # Turn the labels into a numpy array
    train_y = np.array(train_y)
    test_y = np.array(test_y)
    
    # Define a vocabulary for each fold
    vocab = add_doc_to_vocab(train_x, vocab)
    # print('The number of vocab: ', len(vocab))
    
    # Clean the sentences
    train_x = clean_docs(train_x, vocab)
    test_x = clean_docs(test_x, vocab)
    
    # Define the tokenizer
    tokenizer = create_tokenizer(train_x)
    
    # encode data using freq mode
    Xtrain = tokenizer.texts_to_matrix(train_x, mode='freq')
    Xtest = tokenizer.texts_to_matrix(test_x, mode='freq')
    
    Xtrain = np.reshape(Xtrain, (Xtrain.shape[0], Xtrain.shape[1], 1))
    Xtest = np.reshape(Xtest, (Xtest.shape[0], Xtest.shape[1], 1))

    print(Xtrain.shape)
    print(Xtest.shape)
    # train the model
    model = train_cnn(Xtrain, train_y)
    
    # evaluate the model
    loss, acc = model.evaluate(Xtest, test_y, verbose=0)
    print('Test Accuracy: {}'.format(acc*100))
    
    acc_list.append(acc)

acc_list = np.array(acc_list)
print()
print('The test ccuracy for each training:\n{}'.format(acc_list))
print('The mean of the test accuracy: ', acc_list.mean())
# Out:
# (9545, 3995, 1)
# (1061, 3995, 1)
# Epoch 1/10
# 191/191 - 161s - loss: 0.5769 - accuracy: 0.7121
# Epoch 2/10
# 191/191 - 212s - loss: 0.4060 - accuracy: 0.8328
# Epoch 3/10
# 191/191 - 211s - loss: 0.3221 - accuracy: 0.8703
# Epoch 4/10
# 191/191 - 209s - loss: 0.2788 - accuracy: 0.8886
# Epoch 5/10
# 191/191 - 197s - loss: 0.2569 - accuracy: 0.8992
# Epoch 6/10
# 191/191 - 208s - loss: 0.2392 - accuracy: 0.9029
# Epoch 7/10
# 191/191 - 291s - loss: 0.2283 - accuracy: 0.9071
# Epoch 8/10
# 191/191 - 328s - loss: 0.2216 - accuracy: 0.9099
# Epoch 9/10
# 191/191 - 308s - loss: 0.2166 - accuracy: 0.9109
# Epoch 10/10
# 191/191 - 328s - loss: 0.2126 - accuracy: 0.9123
# Test Accuracy: 81.80961608886719
# (9545, 3938, 1)
# (1061, 3938, 1)
# Epoch 1/10
# 191/191 - 317s - loss: 0.5618 - accuracy: 0.7216
# Epoch 2/10
# 191/191 - 314s - loss: 0.4013 - accuracy: 0.8330
# Epoch 3/10
# 191/191 - 328s - loss: 0.3257 - accuracy: 0.8704
# Epoch 4/10
# 191/191 - 321s - loss: 0.2879 - accuracy: 0.8847
# Epoch 5/10
# 191/191 - 319s - loss: 0.2642 - accuracy: 0.8941
# Epoch 6/10
# 191/191 - 323s - loss: 0.2457 - accuracy: 0.9004
# Epoch 7/10
# 191/191 - 325s - loss: 0.2333 - accuracy: 0.9028
# Epoch 8/10
# 191/191 - 334s - loss: 0.2275 - accuracy: 0.9045
# Epoch 9/10
# 191/191 - 304s - loss: 0.2198 - accuracy: 0.9080
# Epoch 10/10
# 191/191 - 324s - loss: 0.2162 - accuracy: 0.9079
# Test Accuracy: 84.35438275337219
# (9545, 3965, 1)
# (1061, 3965, 1)
# Epoch 1/10
# 191/191 - 330s - loss: 0.5666 - accuracy: 0.7133
# Epoch 2/10
# 191/191 - 311s - loss: 0.3955 - accuracy: 0.8374
# Epoch 3/10
# 191/191 - 323s - loss: 0.3169 - accuracy: 0.8725
# Epoch 4/10
# 191/191 - 323s - loss: 0.2806 - accuracy: 0.8865
# Epoch 5/10
# 191/191 - 343s - loss: 0.2561 - accuracy: 0.8920
# Epoch 6/10
# 191/191 - 318s - loss: 0.2420 - accuracy: 0.9019
# Epoch 7/10
# 191/191 - 344s - loss: 0.2313 - accuracy: 0.9068
# Epoch 8/10
# 191/191 - 329s - loss: 0.2226 - accuracy: 0.9079
# Epoch 9/10
# 191/191 - 299s - loss: 0.2187 - accuracy: 0.9113
# Epoch 10/10
# 191/191 - 303s - loss: 0.2147 - accuracy: 0.9118
# Test Accuracy: 84.35438275337219
# (9545, 3991, 1)
# (1061, 3991, 1)
# Epoch 1/10
# 191/191 - 302s - loss: 0.5613 - accuracy: 0.7206
# Epoch 2/10
# 191/191 - 306s - loss: 0.3926 - accuracy: 0.8384
# Epoch 3/10
# 191/191 - 314s - loss: 0.3176 - accuracy: 0.8740
# Epoch 4/10
# 191/191 - 311s - loss: 0.2811 - accuracy: 0.8891
# Epoch 5/10
# 191/191 - 305s - loss: 0.2602 - accuracy: 0.8952
# Epoch 6/10
# 191/191 - 286s - loss: 0.2431 - accuracy: 0.8998
# Epoch 7/10
# 191/191 - 300s - loss: 0.2350 - accuracy: 0.9036
# Epoch 8/10
# 191/191 - 300s - loss: 0.2293 - accuracy: 0.9043
# Epoch 9/10
# 191/191 - 291s - loss: 0.2198 - accuracy: 0.9100
# Epoch 10/10
# 191/191 - 266s - loss: 0.2142 - accuracy: 0.9114
# Test Accuracy: 84.82563495635986
# (9545, 3978, 1)
# (1061, 3978, 1)
# Epoch 1/10
# 191/191 - 298s - loss: 0.5649 - accuracy: 0.7131
# Epoch 2/10
# 191/191 - 333s - loss: 0.3974 - accuracy: 0.8374
# Epoch 3/10
# 191/191 - 336s - loss: 0.3207 - accuracy: 0.8688
# Epoch 4/10
# 191/191 - 324s - loss: 0.2819 - accuracy: 0.8874
# Epoch 5/10
# 191/191 - 332s - loss: 0.2585 - accuracy: 0.8923
# Epoch 6/10
# 191/191 - 308s - loss: 0.2432 - accuracy: 0.8998
# Epoch 7/10
# 191/191 - 346s - loss: 0.2312 - accuracy: 0.9027
# Epoch 8/10
# 191/191 - 374s - loss: 0.2225 - accuracy: 0.9083
# Epoch 9/10
# 191/191 - 331s - loss: 0.2196 - accuracy: 0.9077
# Epoch 10/10
# 191/191 - 317s - loss: 0.2120 - accuracy: 0.9114
# Test Accuracy: 84.16588306427002
# (9545, 3979, 1)
# (1061, 3979, 1)
# Epoch 1/10
# 191/191 - 330s - loss: 0.5561 - accuracy: 0.7232
# Epoch 2/10
# 191/191 - 302s - loss: 0.3968 - accuracy: 0.8351
# Epoch 3/10
# 191/191 - 306s - loss: 0.3226 - accuracy: 0.8686
# Epoch 4/10
# 191/191 - 302s - loss: 0.2847 - accuracy: 0.8862
# Epoch 5/10
# 191/191 - 301s - loss: 0.2592 - accuracy: 0.8961
# Epoch 6/10
# 191/191 - 296s - loss: 0.2434 - accuracy: 0.8985
# Epoch 7/10
# 191/191 - 309s - loss: 0.2323 - accuracy: 0.9074
# Epoch 8/10
# 191/191 - 306s - loss: 0.2255 - accuracy: 0.9084
# Epoch 9/10
# 191/191 - 289s - loss: 0.2179 - accuracy: 0.9124
# Epoch 10/10
# 191/191 - 264s - loss: 0.2119 - accuracy: 0.9155
# Test Accuracy: 81.80961608886719
# (9546, 3978, 1)
# (1060, 3978, 1)
# Epoch 1/10
# 191/191 - 241s - loss: 0.5662 - accuracy: 0.7147
# Epoch 2/10
# 191/191 - 234s - loss: 0.4046 - accuracy: 0.8289
# Epoch 3/10
# 191/191 - 239s - loss: 0.3293 - accuracy: 0.8648
# Epoch 4/10
# 191/191 - 239s - loss: 0.2914 - accuracy: 0.8821
# Epoch 5/10
# 191/191 - 241s - loss: 0.2679 - accuracy: 0.8906
# Epoch 6/10
# 191/191 - 233s - loss: 0.2507 - accuracy: 0.8969
# Epoch 7/10
# 191/191 - 242s - loss: 0.2382 - accuracy: 0.9037
# Epoch 8/10
# 191/191 - 240s - loss: 0.2319 - accuracy: 0.9054
# Epoch 9/10
# 191/191 - 231s - loss: 0.2252 - accuracy: 0.9060
# Epoch 10/10
# 191/191 - 239s - loss: 0.2212 - accuracy: 0.9087
# Test Accuracy: 85.18868088722229
# (9546, 3979, 1)
# (1060, 3979, 1)
# Epoch 1/10
# 191/191 - 239s - loss: 0.5582 - accuracy: 0.7219
# Epoch 2/10
# 191/191 - 235s - loss: 0.3965 - accuracy: 0.8342
# Epoch 3/10
# 191/191 - 231s - loss: 0.3213 - accuracy: 0.8682
# Epoch 4/10
# 191/191 - 212s - loss: 0.2810 - accuracy: 0.8886
# Epoch 5/10
# 191/191 - 218s - loss: 0.2547 - accuracy: 0.8980
# Epoch 6/10
# 191/191 - 221s - loss: 0.2428 - accuracy: 0.9016
# Epoch 7/10
# 191/191 - 239s - loss: 0.2314 - accuracy: 0.9062
# Epoch 8/10
# 191/191 - 238s - loss: 0.2201 - accuracy: 0.9069
# Epoch 9/10
# 191/191 - 229s - loss: 0.2212 - accuracy: 0.9079
# Epoch 10/10
# 191/191 - 237s - loss: 0.2124 - accuracy: 0.9117
# Test Accuracy: 84.5283031463623
# (9546, 3980, 1)
# (1060, 3980, 1)
# Epoch 1/10
# 191/191 - 240s - loss: 0.5687 - accuracy: 0.7173
# Epoch 2/10
# 191/191 - 236s - loss: 0.4049 - accuracy: 0.8312
# Epoch 3/10
# 191/191 - 220s - loss: 0.3254 - accuracy: 0.8718
# Epoch 4/10
# 191/191 - 233s - loss: 0.2884 - accuracy: 0.8840
# Epoch 5/10
# 191/191 - 233s - loss: 0.2656 - accuracy: 0.8967
# Epoch 6/10
# 191/191 - 225s - loss: 0.2511 - accuracy: 0.9013
# Epoch 7/10
# 191/191 - 234s - loss: 0.2376 - accuracy: 0.9077
# Epoch 8/10
# 191/191 - 234s - loss: 0.2319 - accuracy: 0.9067
# Epoch 9/10
# 191/191 - 238s - loss: 0.2260 - accuracy: 0.9111
# Epoch 10/10
# 191/191 - 228s - loss: 0.2187 - accuracy: 0.9140
# Test Accuracy: 83.77358317375183
# (9546, 3976, 1)
# (1060, 3976, 1)
# Epoch 1/10
# 191/191 - 234s - loss: 0.5591 - accuracy: 0.7201
# Epoch 2/10
# 191/191 - 235s - loss: 0.3929 - accuracy: 0.8385
# Epoch 3/10
# 191/191 - 224s - loss: 0.3130 - accuracy: 0.8759
# Epoch 4/10
# 191/191 - 238s - loss: 0.2786 - accuracy: 0.8871
# Epoch 5/10
# 191/191 - 238s - loss: 0.2566 - accuracy: 0.8994
# Epoch 6/10
# 191/191 - 245s - loss: 0.2391 - accuracy: 0.9043
# Epoch 7/10
# 191/191 - 252s - loss: 0.2297 - accuracy: 0.9080
# Epoch 8/10
# 191/191 - 261s - loss: 0.2207 - accuracy: 0.9097
# Epoch 9/10
# 191/191 - 265s - loss: 0.2159 - accuracy: 0.9138
# Epoch 10/10
# 191/191 - 270s - loss: 0.2096 - accuracy: 0.9148
# Test Accuracy: 83.58490467071533
#
# The test ccuracy for each training:
# [0.81809616 0.84354383 0.84354383 0.84825635 0.84165883 0.81809616
#  0.85188681 0.84528303 0.83773583 0.83584905]
# The mean of the test accuracy:  0.8383949875831604

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 3972, 100)         600
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 1986, 100)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 198600)            0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 198600)            0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 198601
# =================================================================
# Total params: 199,201
# Trainable params: 199,201
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Comparing the Word Scoring Methods

# %% [markdown]
# When we use `text_to_matrix()` function, we are given 4 different methods for scoring words:
# - `binary`: words are marked as 1 (present) or 0 (absent)
# - `count`: words are counted based on their occurrence (integer)
# - `tfidf`: words are scored  based on their frequency of occurrence in their own document, but also are being penalized if they are common across  all documents
# - `freq`: wrods are scored based on their frequency of occurrence in their own document

# %%
# prepare bag-of-words encoding of docs
def prepare_data(train_docs, test_docs, mode):
    # create the tokenizer
    tokenizer = Tokenizer()
    # fit the tokenizer on the documents
    tokenizer.fit_on_texts(train_docs)
    # encode training data set
    Xtrain = tokenizer.texts_to_matrix(train_docs, mode=mode)
    # encode test data set
    Xtest = tokenizer.texts_to_matrix(test_docs, mode=mode)
    return Xtrain, Xtest

# %%
#########################
# Define the vocabulary #
#########################

from collections import Counter
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stemmer = PorterStemmer()
    
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # filter out stop words
    tokens = [w for w in tokens if not w in stopwords]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) >= 1]
    # Stem the token
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

def add_doc_to_vocab(docs, vocab):
    '''
    input:
        docs: a list of sentences (docs)
        vocab: a vocabulary dictionary
    output:
        return an updated vocabulary
    '''
    for doc in docs:
        tokens = clean_doc(doc)
        vocab.update(tokens)
    return vocab
        
def doc_to_line(doc, vocab):
    tokens = clean_doc(doc)
    # filter by vocab
    tokens = [token for token in tokens if token in vocab]
    line = ' '.join(tokens)
    return line

def clean_docs(docs, vocab):
    lines = []
    for doc in docs:
        line = doc_to_line(doc, vocab)
        lines.append(line)
    return lines

# prepare bag-of-words encoding of docs
def prepare_data(train_docs, test_docs, mode):
    # create the tokenizer
    tokenizer = Tokenizer()
    # fit the tokenizer on the documents
    tokenizer.fit_on_texts(train_docs)
    # encode training data set
    Xtrain = tokenizer.texts_to_matrix(train_docs, mode=mode)
    # encode test data set
    Xtest = tokenizer.texts_to_matrix(test_docs, mode=mode)
    return Xtrain, Xtest

def train_cnn(train_x, train_y, batch_size = 50, epochs = 10, verbose =2):
    
    n_words = train_x.shape[1]
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(filters=100, kernel_size=5, activation='relu', input_shape=(n_words,1)),
        tf.keras.layers.MaxPool1D(2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense( units=1, activation='sigmoid')
    ])
    
    model.compile( loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    model.fit(train_x, train_y, batch_size, epochs, verbose)
    return model

# prepare cross validation with 10 splits and shuffle = True
kfold = KFold(10, True)

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)

# Run Experiment of 4 different modes
modes = ['binary', 'count', 'tfidf', 'freq']
results = pd.DataFrame()

for mode in modes:
    print('mode: ', mode)
    acc_list = []
    
    # kfold.split() will return set indices for each split
    for train, test in kfold.split(sentences):
        # Instantiate a vocab object
        vocab = Counter()

        train_x, test_x = [], []
        train_y, test_y = [], []

        for i in train:
            train_x.append(sentences[i])
            train_y.append(labels[i])

        for i in test:
            test_x.append(sentences[i])
            test_y.append(labels[i])

        # Turn the labels into a numpy array
        train_y = np.array(train_y)
        test_y = np.array(test_y)

        # Define a vocabulary for each fold
        vocab = add_doc_to_vocab(train_x, vocab)
        # print('The number of vocab: ', len(vocab))

        # Clean the sentences
        train_x = clean_docs(train_x, vocab)
        test_x = clean_docs(test_x, vocab)

        # encode data using freq mode
        Xtrain, Xtest = prepare_data(train_x, test_x, mode)
        
        Xtrain = np.reshape(Xtrain, (Xtrain.shape[0], Xtrain.shape[1], 1))
        Xtest = np.reshape(Xtest, (Xtest.shape[0], Xtest.shape[1], 1))

        # train the model
        model = train_cnn(Xtrain, train_y, verbose=0)

        # evaluate the model
        loss, acc = model.evaluate(Xtest, test_y, verbose=0)
        print('Test Accuracy: {}'.format(acc*100))

        acc_list.append(acc)
    
    results[mode] = acc_list
    acc_list = np.array(acc_list)
    print('The test ccuracy for each training:\n{}'.format(acc_list))
    print('The mean of the test accuracy: ', acc_list.mean())
    print()

print(results)
# Out:
# mode:  binary
# Test Accuracy: 84.26012992858887
# Test Accuracy: 83.41187834739685
# Test Accuracy: 82.09236860275269
# Test Accuracy: 83.12912583351135
# Test Accuracy: 84.82563495635986
# Test Accuracy: 86.23939752578735
# Test Accuracy: 84.1509461402893
# Test Accuracy: 83.11320543289185
# Test Accuracy: 85.18868088722229
# Test Accuracy: 83.67924690246582
# The test ccuracy for each training:
# [0.8426013  0.83411878 0.82092369 0.83129126 0.84825635 0.86239398
#  0.84150946 0.83113205 0.85188681 0.83679247]
# The mean of the test accuracy:  0.8400906145572662
#
# mode:  count
# Test Accuracy: 84.91988778114319
# Test Accuracy: 82.6578676700592
# Test Accuracy: 84.54288244247437
# Test Accuracy: 83.7888777256012
# Test Accuracy: 82.75212049484253
# Test Accuracy: 85.29688715934753
# Test Accuracy: 82.92452692985535
# Test Accuracy: 84.05660390853882
# Test Accuracy: 82.26414918899536
# Test Accuracy: 85.37735939025879
# The test ccuracy for each training:
# [0.84919888 0.82657868 0.84542882 0.83788878 0.8275212  0.85296887
#  0.82924527 0.84056604 0.82264149 0.85377359]
# The mean of the test accuracy:  0.8385811626911164
#
# mode:  tfidf
# Test Accuracy: 81.90386295318604
# Test Accuracy: 83.2233726978302
# Test Accuracy: 83.2233726978302
# Test Accuracy: 84.26012992858887
# Test Accuracy: 81.24411106109619
# Test Accuracy: 83.88313055038452
# Test Accuracy: 83.39622616767883
# Test Accuracy: 84.24528241157532
# Test Accuracy: 83.20754766464233
# Test Accuracy: 84.62263941764832
# The test ccuracy for each training:
# [0.81903863 0.83223373 0.83223373 0.8426013  0.81244111 0.83883131
#  0.83396226 0.84245282 0.83207548 0.84622639]
# The mean of the test accuracy:  0.8332096755504608
#
# mode:  freq
# Test Accuracy: 82.75212049484253
# Test Accuracy: 83.69462490081787
# Test Accuracy: 85.29688715934753
# Test Accuracy: 85.29688715934753
# Test Accuracy: 83.41187834739685
# Test Accuracy: 83.60037803649902
# Test Accuracy: 83.49056839942932
# Test Accuracy: 83.77358317375183
# Test Accuracy: 83.39622616767883
# Test Accuracy: 82.83019065856934
# The test ccuracy for each training:
# [0.8275212  0.83694625 0.85296887 0.85296887 0.83411878 0.83600378
#  0.83490568 0.83773583 0.83396226 0.82830191]
# The mean of the test accuracy:  0.8375433444976806
#
#      binary     count     tfidf      freq
# 0  0.842601  0.849199  0.819039  0.827521
# 1  0.834119  0.826579  0.832234  0.836946
# 2  0.820924  0.845429  0.832234  0.852969
# 3  0.831291  0.837889  0.842601  0.852969
# 4  0.848256  0.827521  0.812441  0.834119
# 5  0.862394  0.852969  0.838831  0.836004
# 6  0.841509  0.829245  0.833962  0.834906
# 7  0.831132  0.840566  0.842453  0.837736
# 8  0.851887  0.822641  0.832075  0.833962
# 9  0.836792  0.853774  0.846226  0.828302

# %%
results
# Out:
#      binary     count     tfidf      freq
# 0  0.842601  0.849199  0.819039  0.827521
# 1  0.834119  0.826579  0.832234  0.836946
# 2  0.820924  0.845429  0.832234  0.852969
# 3  0.831291  0.837889  0.842601  0.852969
# 4  0.848256  0.827521  0.812441  0.834119
# 5  0.862394  0.852969  0.838831  0.836004
# 6  0.841509  0.829245  0.833962  0.834906
# 7  0.831132  0.840566  0.842453  0.837736
# 8  0.851887  0.822641  0.832075  0.833962
# 9  0.836792  0.853774  0.846226  0.828302

# %%
import seaborn as sns

results.boxplot()
plt.show()

# %%
results.describe()
# Out:
#           binary      count      tfidf       freq
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.840091   0.838581   0.833210   0.837543
# std     0.011941   0.011593   0.010597   0.008794
# min     0.820924   0.822641   0.812441   0.827521
# 25%     0.831998   0.827952   0.832115   0.834001
# 50%     0.839151   0.839227   0.833098   0.835455
# 75%     0.846843   0.848256   0.841547   0.837538
# max     0.862394   0.853774   0.846226   0.852969
