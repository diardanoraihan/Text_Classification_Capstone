# %% [markdown]
# # Naive Bayes Classification with MR Dataset
# <hr>
#
# We will build a text classification model using Naive Bayes on the Moview Review Dataset. Since there is no standard train/test split for this dataset, we will use 10-Fold Cross Validation (CV).
#
# ## Load the library

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import random
from nltk.corpus import stopwords, twitter_samples
from nltk.tokenize import TweetTokenizer
from sklearn.model_selection import KFold
from nltk.stem import PorterStemmer
from string import punctuation
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
import time

# %config IPCompleter.greedy=True
# %config IPCompleter.use_jedi=False
# nltk.download('twitter_samples')
# Out:
# Bad key text.latex.unicode in file C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 112 ('text.latex.unicode : False # use "ucs" and "inputenc" LaTeX packages for handling')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.2/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.frameon in file C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 423 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.2/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key pgf.debug in file C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 444 ('pgf.debug           : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.2/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.level in file C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 475 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.2/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 476 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.2/matplotlibrc.template
# or from the matplotlib source distribution
# In C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# ## Load the Dataset

# %%
corpus = pd.read_pickle('../0_data/MR/MR.pkl')
corpus.label = corpus.label.astype(int)
print(corpus.shape)
corpus
# Out:
# (10662, 3)
#                                                 sentence  label  split
# 0                       simplistic , silly and tedious .      0  train
# 1      it 's so laddish and juvenile , only teenage b...      0  train
# 2      exploitative and largely devoid of the depth o...      0  train
# 3      garbus discards the potential for pathological...      0  train
# 4      a visually flashy but narratively opaque and e...      0  train
# ...                                                  ...    ...    ...
# 10657  both exuberantly romantic and serenely melanch...      1  train
# 10658  mazel tov to a film about a family 's joyous l...      1  train
# 10659  standing in the shadows of motown is the best ...      1  train
# 10660  it 's nice to see piscopo again after all thes...      1  train
# 10661  provides a porthole into that noble , tremblin...      1  train
#
# [10662 rows x 3 columns]

# %%
corpus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10662 entries, 0 to 10661
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  10662 non-null  object
#  1   label     10662 non-null  int32
#  2   split     10662 non-null  object
# dtypes: int32(1), object(2)
# memory usage: 208.4+ KB

# %%
corpus.groupby( by='label').count()
# Out:
#        sentence  split
# label
# 0          5331   5331
# 1          5331   5331

# %%
# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)

# %% [markdown]
# ## Raw Number of Vocabulary

# %%
# Build the raw vocobulary for first inspection
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
vocab_raw = tokenizer.word_index
print('\nThe vocabulary size: {}\n'.format(len(vocab_raw)))
print(vocab_raw)
# Out:
# The vocabulary size: 18758
#
# {'the': 1, 'a': 2, 'and': 3, 'of': 4, 'to': 5, 'is': 6, "'s": 7, 'it': 8, 'in': 9, 'that': 10, 'as': 11, 'but': 12, 'film': 13, 'with': 14, 'for': 15, 'this': 16, 'movie': 17, 'its': 18, 'an': 19, 'you': 20, 'be': 21, "n't": 22, 'on': 23, 'not': 24, 'by': 25, 'one': 26, 'like': 27, 'are': 28, 'about': 29, 'has': 30, 'more': 31, 'at': 32, 'than': 33, 'from': 34, 'all': 35, 'have': 36, 'his': 37, 'so': 38, 'if': 39, 'i': 40, 'or': 41, 'story': 42, 'too': 43, 'what': 44, 'there': 45, 'out': 46, 'who': 47, 'just': 48, 'up': 49, 'good': 50, 'into': 51, 'does': 52, 'most': 53, 'no': 54, 'much': 55, 'even': 56, 'comedy': 57, 'time': 58, 'will': 59, 'can': 60, 'some': 61, 'well': 62, 'characters': 63, 'he': 64, 'director': 65, 'only': 66, 'little': 67, 'way': 68, 'do': 69, 'funny': 70, 'their': 71, 'make': 72, 'been': 73, 'they': 74, 'your': 75, 'enough': 76, 'very': 77, 'we': 78, 'never': 79, 'when': 80, 'life': 81, 'makes': 82, 'would': 83, 'bad': 84, 'may': 85, 'us': 86, 'which': 87, 'best': 88, 'work': 89, 'was': 90, 'love': 91, 'any': 92, 'could': 93, 'made': 94, 'while': 95, 'new': 96, 'movies': 97, 'her': 98, 'off': 99, 'through': 100, 'something': 101, 'action': 102, 'how': 103, 'really': 104, 'drama': 105, 'two': 106, 'should': 107, 'plot': 108, 'own': 109, 'them': 110, 'see': 111, 'performances': 112, 'long': 113, 'many': 114, 'those': 115, 'still': 116, 'look': 117, 'films': 118, 'every': 119, 'old': 120, 'over': 121, 'people': 122, 'big': 123, 'first': 124, 'nothing': 125, "'re": 126, 'better': 127, 'fun': 128, 'get': 129, 'other': 130, 'without': 131, 'being': 132, 'great': 133, 'character': 134, 'both': 135, 'might': 136, 'though': 137, "'": 138, 'audience': 139, 'also': 140, 'here': 141, 'another': 142, 'world': 143, 'cast': 144, 'real': 145, 'humor': 146, 'kind': 147, 'ever': 148, 'self': 149, 'script': 150, 'between': 151, 'year': 152, 'sense': 153, 'feel': 154, 'such': 155, 'less': 156, 'down': 157, 'often': 158, 'far': 159, 'performance': 160, 'feels': 161, 'thing': 162, 'few': 163, 'hard': 164, 'because': 165, 'man': 166, 'screen': 167, 'thriller': 168, 'seems': 169, 'minutes': 170, 'picture': 171, 'tale': 172, 'heart': 173, 'full': 174, 'quite': 175, 'documentary': 176, 'hollywood': 177, 'almost': 178, 'ca': 179, 'end': 180, 'yet': 181, 'interesting': 182, "'ve": 183, "'ll": 184, 'after': 185, 'go': 186, 'american': 187, 'these': 188, 'entertaining': 189, 'rather': 190, 'my': 191, 'were': 192, 'take': 193, 'de': 194, 'itself': 195, 'family': 196, 'watching': 197, 'seen': 198, 'romantic': 199, 'ultimately': 200, 'comes': 201, 'moments': 202, 'me': 203, 'right': 204, 'despite': 205, 'lot': 206, 'where': 207, 'had': 208, 'original': 209, 'acting': 210, 'before': 211, 'human': 212, 'same': 213, 'then': 214, 'find': 215, 'worth': 216, 'gets': 217, 'come': 218, 'times': 219, 'back': 220, 'takes': 221, 'things': 222, 'dialogue': 223, 'actors': 224, 'scenes': 225, 'watch': 226, 'high': 227, 'compelling': 228, 'our': 229, 'material': 230, 'young': 231, 'once': 232, 'years': 233, 'music': 234, 'style': 235, 'going': 236, 'half': 237, 'cinema': 238, 'anyone': 239, 'works': 240, 'did': 241, 'think': 242, 'emotional': 243, 'star': 244, 'writer': 245, 'seem': 246, 'know': 247, 'want': 248, 'she': 249, 'least': 250, 'last': 251, 'point': 252, 'gives': 253, 'special': 254, 'piece': 255, 'give': 256, 'again': 257, 'making': 258, 'say': 259, 'part': 260, 'kids': 261, 'show': 262, 'sometimes': 263, 'subject': 264, 'pretty': 265, 'cinematic': 266, 'entertainment': 267, 'together': 268, 'moving': 269, 'video': 270, 'bit': 271, 'keep': 272, 'dull': 273, 'whole': 274, 'fans': 275, 'why': 276, 'sweet': 277, 'war': 278, 'art': 279, 'fascinating': 280, 'true': 281, 'anything': 282, 'need': 283, 'away': 284, 'age': 285, 'since': 286, 'three': 287, 'manages': 288, 'laughs': 289, 'women': 290, 'flick': 291, 'offers': 292, 'history': 293, 'dark': 294, 'experience': 295, 'clever': 296, 'always': 297, 'silly': 298, 'predictable': 299, 'direction ...

# %% [markdown]
# <!--## Split Dataset-->

# %% [markdown]
# # Data Preprocessing
# <hr>

# %% [markdown]
# ## Define `clean_doc` function

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stemmer = PorterStemmer()
    
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # remove remaining tokens that are not alphabetic
#     tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    tokens = [w for w in tokens if not w in stopwords]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) >= 1]
    # Stem the token
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

# %% [markdown]
# ## Define `count_docs` function

# %%
def count_docs(data, docs, ys):
    '''
    Input:
        data: a dictionary that will be used to map each pair to its frequency
        docs: a list of sentences
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''
    onehot = OneHotEncoder( sparse=False)
    y_onehot = onehot.fit_transform(np.reshape(ys, (-1,1)))
    # print(y_onehot)
    count = 0                    
    for doc, y in zip(docs, y_onehot):
        # For each word
        for word in clean_doc(doc):
            # if not in the data yet
            if word not in data:
                # assign it
                data[word] = y
            # if already in the data 
            else:
                # update it
                data[word] = data.get(word) + y

    return data

# %% [markdown]
# ## Build Frequencies Dictionary

# %%
# Build the freqs dictionary for later uses
freqs = count_docs({}, sentences, labels)
freqs
# Out:
# {'simplist': array([15.,  4.]),
#  'silli': array([64., 20.]),
#  'tediou': array([28.,  5.]),
#  'laddish': array([1., 0.]),
#  'juvenil': array([5., 2.]),
#  'teenag': array([14., 11.]),
#  'boy': array([36., 36.]),
#  'could': array([128.,  94.]),
#  'possibl': array([33., 32.]),
#  'find': array([70., 74.]),
#  'funni': array([110., 185.]),
#  'exploit': array([30.,  9.]),
#  'larg': array([25., 24.]),
#  'devoid': array([16.,  2.]),
#  'depth': array([19., 22.]),
#  'sophist': array([11., 17.]),
#  'would': array([170.,  81.]),
#  'make': array([280., 338.]),
#  'watch': array([122., 105.]),
#  'graphic': array([9., 6.]),
#  'treatment': array([ 9., 10.]),
#  'crime': array([35., 25.]),
#  'bearabl': array([2., 0.]),
#  'garbu': array([1., 0.]),
#  'discard': array([2., 1.]),
#  'potenti': array([24., 16.]),
#  'patholog': array([3., 4.]),
#  'studi': array([18., 45.]),
#  'exhum': array([1., 0.]),
#  'instead': array([52., 19.]),
#  'skew': array([2., 1.]),
#  'melodrama': array([32., 21.]),
#  'circumstanti': array([2., 0.]),
#  'situat': array([32., 17.]),
#  'visual': array([53., 76.]),
#  'flashi': array([9., 3.]),
#  'narr': array([37., 36.]),
#  'opaqu': array([4., 2.]),
#  'emot': array([ 61., 106.]),
#  'vapid': array([8., 0.]),
#  'exercis': array([43., 11.]),
#  'style': array([44., 56.]),
#  'mystif': array([1., 0.]),
#  'stori': array([250., 290.]),
#  'also': array([56., 97.]),
#  'unorigin': array([7., 2.]),
#  'come': array([146., 139.]),
#  'alreadi': array([36.,  8.]),
#  'recycl': array([13.,  4.]),
#  'time': array([255., 249.]),
#  'care': array([61., 43.]),
#  'count': array([ 6., 15.]),
#  'thing': array([170.,  71.]),
#  'give': array([ 72., 125.]),
#  'movi': array([929., 673.]),
#  'point': array([78., 48.]),
#  'bravado': array([3., 0.]),
#  'take': array([111., 140.]),
#  'entir': array([36., 32.]),
#  'stale': array([18.,  1.]),
#  'concept': array([31., 14.]),
#  'push': array([ 9., 12.]),
#  'audienc': array([107.,  92.]),
#  'meat': array([5., 2.]),
#  'grinder': array([1., 1.]),
#  'one': array([402., 392.]),
#  'much': array([234., 154.]),
#  'farcic': array([4., 2.]),
#  'sour': array([12.,  2.]),
#  'unfortun': array([29.,  6.]),
#  'actor': array([81., 78.]),
#  'serv': array([31., 17.]),
#  'hack': array([6., 2.]),
#  'script': array([113.,  46.]),
#  'disquiet': array([2., 3.]),
#  'rel': array([15.,  6.]),
#  'gore': array([8., 3.]),
#  'free': array([18., 12.]),
#  'allus': array([2., 1.]),
#  'serial': array([8., 1.]),
#  'murder': array([20., 19.]),
#  'fall': array([44., 19.]),
#  'attempt': array([52., 16.]),
#  'human': array([ 35., 105.]),
#  'subject': array([46., 59.]),
#  'sentiment': array([41., 27.]),
#  'mess': array([46.,  9.]),
#  'never': array([152., 111.]),
#  'ring': array([14., 13.]),
#  'true': array([31., 49.]),
#  'perform': array([108., 251.]),
#  'often': array([60., 81.]),
#  'engag': array([26., 60.]),
#  'loos': array([15.,  5.]),
#  'collect': array([20.,  8.]),
#  'improvis': array([9., 4.]),
#  'number': array([34., 16.]),
#  'probabl': array([40., 24.]),
#  'work': array([146., 231.]),
#  'better': array([104.,  69.]),
#  'hour': array([76., 43.]),
#  'tv': array([53.,  7.]),
#  'documentari': array([40., 96.]),
#  'interest': array([120.,  83.]),
#  'compel': array([27., 72.]),
#  'cut': array([28., 27.]),
#  'room': array([15., 11.]),
#  'floor': array([3., 2.]),
#  'somewher': array([14.,  7.]),
#  'lie': array([12., 18.]),
#  'footag': array([10., 10.]),
#  'might': array([98., 60.]),
#  'made': array([123.,  99.]),
#  'trenchant': array([1., 3.]),
#  'iron': array([8., 8.]),
#  'cultur': array([18., 77.]),
#  'satir': array([29., 20.]),
#  'frustrat': array([18., 11.]),
#  'misfir': array([9., 0.]),
#  'ensembl': array([10., 18.]),
#  'player': array([9., 5.]),
#  'gain': array([5., 2.]),
#  'notic': array([ 7., 11.]),
#  'guy': array([47., 22.]),
#  'ritchi': array([10.,  1.]),
#  'lock': array([3., 3.]),
#  'stock': array([10.,  9.]),
#  'two': array([ 90., 105.]),
#  'smoke': array([2., 3.]),
#  'barrel': array([7., 3.]),
#  'snatch': array([3., 0.]),
#  'bod': array([1., 0.]),
#  'unlik': array([16., 25.]),
#  'becom': array([75., 54.]),
#  'household': array([1., 1.]),
#  'name': array([30., 10.]),
#  'basi': array([4., 3.]),
#  'first': array([ 75., 100.]),
#  'star': array([75., 62.]),
#  'vehicl': array([11.,  8.]),
#  'differ': array([18., 41.]),
#  'courag': array([ 7., 14.]),
#  'go': array([122.,  89.]),
#  'top': array([21., 21.]),
#  'nt': array([596., 348.]),
#  'stupid': array([37.,  3.]),
#  'noth': array([122.,  53.]),
#  'seem': array([154.,  87.]),
#  'analyz': array([6., 7.]),
#  'even': array([205., 187.]),
#  'joe': array([7., 1.]),
#  'viterelli': array([1., 0.]),
#  'de': array([45., 73.]),
#  'niro': array([15., 10.]),
#  'right': array([51., 62.]),
#  'hand': array([54., 26.]),
#  'goombah': array([1., 0.]),
#  'master': array([14., 33.]),
#  'screenwrit': array([31., 11.]),
#  'courtesi': array([1., 0.]),
#  'john': array([41., 16.]),
#  'pogu': array([1., 0.]),
#  'yale': array([1., 0.]),
#  'grad': array([1., 0.]),
#  'previous': array([2., 0.]),
#  'gave': array([5., 0.]),
#  'us': array([ 85., 156.]),
#  'skull': array([1., 0.]),
#  'last': array([51., 40.]),
#  'year': array([ 87., 154.]),
#  'rollerbal': array([8., 0.]),
#  'enough': array([140., 128.]),
#  'said': array([13.,  8.]),
#  'except': array([31., 21.]),
#  'film': array([ 781., 1032.]),
#  'overboard': array([2., 0.]),
#  'common': array([6., 9.]),
#  'sens': array([73., 81.]),
#  'fli': array([9., 9.]),
#  'window': array([6., 7.]),
#  'along': array([27., 26.]),
#  'hail': array([2., 1.]),
#  'bullet': array([4., 4.]),
#  'none': array([31.,  9.]),
#  'ever': array([61., 87.]),
#  'hit': array([30., 41.]),
#  'sascha': array([1., 0.]),
#  '100': array([9., 2.]),
#  'minut': array([137.,  56.]),
#  '25': array([4., 0.]),
#  'decent': array([18., 13.]),
#  'materi': array([63., 35.]),
#  'execut': array([24., 22.]),
#  'pedestrian': array([7., 1.]),
#  'posit': array([11., 10.]),
#  'comment': array([5., 1.]),
#  'rob': array([8., 3.]),
#  'schneider': array([11.,  0.]),
#  'actual': array([48., 33.]),
#  'turn': array([78., 59.]),
#  'pretti': array([44., 39.]),
#  'convinc': array([20., 20.]),
#  'prissi': array([1., 0.]),
#  'girl': array([32., 52.]),
#  'remak': array([19., 15.]),
#  'pale': array([4., 3.]),
#  'imit': array([13.,  1.]),
#  'show': array([74., 74.]),
#  'studio': array([16.,  6.]),
#  'firmli': array([4., 2.]),
#  'believ': array([46., 48.]),
#  'peopl': array([85., 92.]),
#  'lost': array([20., 16.]),
#  'abil': array([ 8., 20.]),
#  'think': array([80., 52.]),
#  'forgiv': array([ 5., 10.]),
#  'shoddi': array([5., 0.]),
#  'product': array([48., 22.]),
#  'long': array([122.,  71.]),
#  'littl': array([173., 134.]),
#  'action': array([131.,  76.]),
#  'farc': array([11.,  6.]),
#  'parodi': array([12.,  3.]),
#  'comedi': array([191., 224.]),
#  'premis': array([48., 17.]),
#  'comparison': array([10.,  0.]),
#  'realiti': array([25., 25.]),
#  'commentari': array([9., 3.]),
#  'knowledg': array([3., 8.]),
#  'excit': array([26., 29.]),
#  'exotic': array([1., 1.]),
#  'sound': array([25., 26.]),
#  'typic': array([11., 14.]),
#  'pax': array([1., 0.]),
#  'viewer': array([52., 36.]),
#  'rest': array([16., 13.]),
#  'lull': array([5., 1.]),
#  'coma': array([3., 1.]),
#  'parti': array([16.,  6.]),
#  'scene': array([81., 65.]),
#  'deliv': array([29., 66.]),
#  'tawdri': array([3., 2.]),
#  'kick': array([13.,  7.]),
#  'dudsvil': array([1., 0.]),
#  'head': array([33., 27.]),
#  'toilet': array([6., 1.]),
#  'feroc': array([1., 1.]),
#  'frozen': array([1., 3.]),
#  'burrito': array([1., 0.]),
#  'night': array([25., 13.]),
#  'tequila': array([1., 0.]),
#  'bender': array([2., 1.]),
#  'know': array([61., 71.]),
#  'seen': array([50., 66.]),
#  'jackass': array([5., 1.]),
#  'critic': array([18., 12.]),
#  'rise': array([17., 12.]),
#  'easi': array([23., 32.]),
#  'cynic': array([13., 12.]),
#  'potshot': array([2., 0.]),
#  'moral': array([27., 32.]),
#  'bankrupt': array([2., 0.]),
#  'charact': array([255., 239.]),
#  'someth': array([119.,  84.]),
#  'borrow': array([8., 6.]),
#  'construct': array([14., 22.]),
#  'feel': array([209., 144.]),
#  'less': array([92., 51.]),
#  'love': array([101., 203.]),
#  'well': array([151., 188.]),
#  'integr': array([ 2., 12.]),
#  'homag': array([7., 7.]),
#  'like': array([493., 330.]),
#  'mere': array([29., 14.]),
#  'excus': array([13.,  2.]),
#  'wan': array([2., 0.]),
#  'thinli': array([4., 1.]),
#  'sketch': array([10.,  0.]),
#  'kill': array([17., 11.]),
#  'infantil': array([4., 2.]),
#  'redund': array([9., 1.]),
#  'sloppi': array([12.,  3.]),
#  'amateurish': array([13.,  1.]),
#  'yep': array([1., 0.]),
#  'wake': array([8., 3.]),
#  'reno': array([7., 9.]),
#  'back': array([52., 55.]),
#  'sleep': array([13.,  4.]),
#  'middl': array([24., 26.]),
#  'demm': array([6., 0.]),
#  'experi': array([32., 62.]),
#  'harvest': array([1., 1.]),
#  'moment': array([71., 76.]),
#  'gem': array([ 1., 17.]),
#  'field': array([6., 6.]),
#  'roughag': array([1., 0.]),
#  'domin': array([2., 8.]),
#  'clich': array([90., 27.]),
#  'pile': array([11.,  1.]),
#  'payami': array([1., 2.]),
#  'tri': array([105.,  46.]),
#  'rais': array([12., 11.]),
#  'seriou': array([29., 25.]),
#  'issu': array([20., 21.]),
#  'iran': array([1., 4.]),
#  'elector': array([1., 0.]),
#  'process': array([14., 21.]),
#  'result': array([32., 19.]),
#  'subtl': array([ 7., 22.]),
#  'polit': array([21., 50.]),
#  'broadcast': array([2., 0.]),
#  'surpris': array([39., 59.]),
#  'heavyweight': array([1., 1.]),
#  'joel': array([3., 2.]),
#  'silver': array([2., 6.]),
#  'robert': array([20., 13.]),
#  'zemecki': array([1., 0.]),
#  'agre': array([1., 0.]),
#  'produc': array([35., 15.]),
#  'assum': array([7., 3.]),
#  'director': array([158., 173.]),
#  'pictur': array([80., 84.]),
#  'cavort': array([1., 0.]),
#  'ladi': array([ 7., 10.]),
#  'underwear': array([1., 1.]),
#  'anoth': array([99., 53.]),
#  'useless': array([4., 1.]),
#  'brutal': array([10., 15.]),
#  'mid': array([6., 1.]),
#  '70': array([11.,  6.]),
#  'american': array([49., 86.]),
#  'sport': array([13., 20.]),
#  'laugh': array([80., 60.]),
#  'smile': array([11., 11.]),
#  'surviv': array([9., 8.]),
#  'pleas': array([15., 21.]),
#  'someon': array([23.,  8.]),
#  'stop': array([17., 13.]),
#  'eric': array([3., 6.]),
#  'schaeffer': array([7., 2.]),
#  'problem': array([57., 21.]),
#  'deriv': array([18., 13.]),
#  'screenplay': array([43., 26.]),
#  'rather': array([75., 44.]),
#  'mediocr': array([31.,  2.]),
#  'involv': array([34., 23.]),
#  'mood': array([ 8., 31.]),
#  'fun': array([ 52., 117.]),
#  'bad': array([217.,  34.]),
#  'want': array([81., 63.]),
#  'catch': array([12., 11.]),
#  'freak': array([8., 7.]),
#  'matine': array([4., 7.]),
#  'curl': array([2., 2.]),
#  'may': array([104., 141.]),
#  'uniqu': array([ 4., 25.]),
#  'men': array([32., 26.]),
#  'broom': array([2., 1.]),
#  'distinctli': array([5., 0.]),
#  'ordinari': array([8., 5.]),
#  'though': array([68., 90.]),
#  'opera': array([36., 19.]),
#  'place': array([42., 52.]),
#  'mostli': array([27., 29.]),
#  'indoor': array([2., 1.]),
#  'jacquot': array([3., 6.]),
#  'unsur': array([2., 0.]),
#  'evok': array([ 4., 14.]),
#  'sort': array([38., 19.]),
#  'natur': array([35., 45.]),
#  'set': array([62., 53.]),
#  'get': array([184., 129.]),
#  'around': array([37., 33.]),
#  'fact': array([36., 18.]),
#  'reveng': array([ 8., 11.]),
#  'nerd': array([3., 0.]),
#  'revisit': array([1., 1.]),
#  'effort': array([42., 35.]),
#  'sincer': array([15., 18.]),
#  'honest': array([ 8., 33.]),
#  'bleak': array([3., 7.]),
#  'hardli': array([15., 10.]),
#  'watchabl': array([ 8., 17.]),
#  'regurgit': array([2., 1.]),
#  'water': array([24., 16.]),
#  'mani': array([96., 87.]),
#  'previou': array([11., 14.]),
#  'success': array([24., 36.]),
#  'new': array([ 96., 116.]),
#  'swing': array([10.,  2.]),
#  'thrown': array([8., 0.]),
#  'flashbulb': array([1., 1.]),
#  'edit': array([23., 15.]),
#  'cover': array([11.,  7.]),
#  'absenc': array([1., 2.]),
#  'continu': array([ 9., 17.]),
#  'undisput': array([3., 3.]),
#  'nearli': array([43., 27.]),
#  'incoher': array([15.,  1.]),
#  'close': array([35., 29.]),
#  'bout': array([3., 0.]),
#  'imposs': array([22., 26.]),
#  'win': array([16., 40.]),
#  'stink': array([5., 0.]),
#  'start': array([52., 31.]),
#  'finish': array([14., 11.]),
#  'wet': array([6., 2.]),
#  'burlap': array([1., 0.]),
#  'sack': array([2., 1.]),
#  'gloom': array([1., 0.]),
#  'civil': array([3., 4.]),
#  'mind': array([42., 47.]),
#  'ballist': array([11.,  0.]),
#  'eck': array([7., 1.]),
#  'vs': array([12.,  6.]),
#  'sever': array([33., 19.]),
#  'ordeal': array([3., 0.]),
#  'amus': array([37., 44.]),
#  'equlibrium': array([1., 0.]),
#  'pass': array([22., 10.]),
#  'thirteen': array([1., 3.]),
#  'old': array([84., 96.]),
#  'book': array([30., 36.]),
#  'report': array([14., 12.]),
#  'totalitarian': array([1., 1.]),
#  'theme': array([12., 33.]),
#  '1984': array([2., 1.]),
#  'farenheit': array([1., 0.]),
#  '451': array([2., 0.]),
#  'lack': array([108.,  38.]),
#  'everyth': array([44., 27.]),
#  'self': array([79., 69.]),
#  'conscious': array([12.,  7.]),
#  'poetic': array([10., 11.]),
#  'forc': array([31., 44.]),
#  'piti': array([13.,  6.]),
#  'nelson': array([6., 2.]),
#  'achiev': array([18., 23.]),
#  'match': array([16., 11.]),
#  'ambit': array([13.,  4.]),
#  'seagal': array([17.,  0.]),
#  'appear': array([29., 15.]),
#  'orang': array([2., 3.]),
#  'prison': array([10.,  5.]),
#  'jumpsuit': array([1., 0.]),
#  'stand': array([27., 33.]),
#  'theater': array([42., 27.]),
#  'shout': array([5., 2.]),
#  'hey': array([11.,  4.]),
#  'kool': array([1., 0.]),
#  'aid': array([5., 3.]),
#  'annoy': array([16.,  3.]),
#  'demeanour': array([1., 0.]),
#  'lead': array([35., 34.]),
#  'imagin': array([51., 53.]),
#  'cleanflick': array([1., 0.]),
#  'version': array([29., 33.]),
#  'ali': array([2., 1.]),
#  'macgraw': array([1., 0.]),
#  'profan': array([4., 3.]),
#  'replac': array([7., 3.]),
#  'romanc': array([29., 35.]),
#  'novel': array([18., 23.]),
#  'platitud': array([3., 0.]),
#  'pc': array([1., 0.]),
#  'stabil': array([1., 0.]),
#  'notwithstand': array([3., 2.]),
#  'suffer': array([36., 15.]),
#  'pat': array([6., 6.]),
#  'fairi': array([7., 6.]),
#  'tale': array([54., 89.]),
#  'conclus': array([7., 9.]),
#  'forget': array([13., 13.]),
#  'mislead': array([1., 0.]),
#  'titl': array([65., 17.]),
#  'unexplain': array([1., 2.]),
#  'baboon': array([1., 0.]),
#  'cameo': array([4., 2.]),
#  'odd': array([15., 21.]),
#  'haphazard': array([5., 2.]),
#  'inconsequenti': array([8., 1.]),
#  'romant': array([42., 74.]),
#  'fan': array([45., 57.]),
#  'assuredli': array([1., 1.]),
#  'bone': array([7., 6.]),
#  'tickl': array([2., 1.]),
#  'other': array([13., 22.]),
#  'humor': array([72., 95.]),
#  'seek': array([12., 12.]),
#  'dollar': array([4., 1.]),
#  'best': array([ 73., 170.]),
#  'spent': array([9., 3.]),
#  'elsewher': array([4., 1.]),
#  'pascal': array([1., 0.]),
#  'bailli': array([2., 0.]),
#  'rom': array([1., 2.]),
#  'com': array([8., 4.]),
#  'provid': array([18., 45.]),
#  'audrey': array([2., 1.]),
#  'tautou': array([1., 1.]),
#  'fabuleux': array([1., 0.]),
#  'destin': array([ 9., 10.]),
#  'e': array([12., 18.]),
#  'banal': array([16.,  2.]),
#  'spiritu': array([ 9., 14.]),
#  'quest': array([5., 9.]),
#  'static': array([6., 4.]),
#  'sugari': array([4., 0.]),
#  'half': array([63., 28.]),
#  'school': array([38., 14.]),
#  'special': array([49., 40.]),
#  'interfaith': array([1., 0.]),
#  'understand': array([19., 27.]),
#  'stretch': array([14.,  4.]),
#  '90': array([24.,  5.]),
#  'chemistri': array([14., 13.]),
#  'freeman': array([3., 3.]),
#  'judd': array([4., 3.]),
#  'howev': array([18., 12.]),
#  'almost': array([74., 53.]),
#  'worth': array([35., 69.]),
#  'see': array([104., 135.]),
#  'pretenti': array([38.,  5.]),
#  'ultim': array([79., 61.]),
#  'empti': array([21.,  6.]),
#  'examin': array([ 5., 39.]),
#  'sick': array([6., 8.]),
#  'evil': array([10., 12.]),
#  'woman': array([18., 29.]),
#  'countri': array([16., 11.]),
#  'bear': array([26.,  3.]),
#  'upset': array([3., 2.]),
#  'frighten': array([7., 6.]),
#  'young': array([39., 55.]),
#  'flat': array([38.,  4.]),
#  'entertain': array([ 74., 157.]),
#  'either': array([29., 22.]),
#  'cumul': array([3., 1.]),
#  'effect': array([63., 73.]),
#  '65': array([2., 1.]),
#  'trifl': array([13.,  5.]),
#  'trap': array([20.,  7.]),
#  'weird': array([17., 14.]),
#  'trot': array([5., 0.]),
#  'video': array([68., 20.]),
#  'took': array([8., 5.]),
#  'famili': array([ 36., 100.]),
#  'vacat': array([1., 0.]),
#  'stoneheng': array([1., 0.]),
#  'desper': array([19., 18.]),
#  'end': array([143., 100.]),
#  'leav': array([58., 46.]),
#  'connect': array([14., 18.]),
#  'identif': array([1., 0.]),
#  'frustratingli': array([4., 1.]),
#  'reach': array([17., 12.]),
#  'mattei': array([4., 2.]),
#  'underdevelop': array([2., 0.]),
#  'conveni': array([7., 1.]),
#  'conveyor': array([1., 0.]),
#  'belt': array([4., 3.]),
#  'brood': array([2., 4.]),
#  'person': array([44., 44.]),
#  'parad': array([6., 3.]),
#  'camp': array([10.,  9.]),
#  'drowsi': array([2., 0.]),
#  'drama': array([ 81., 124.]),
#  'infatu': array([2., 1.]),
#  'final': array([47., 37.]),
#  'shot': array([37., 35.]),
#  'rabbit': array([3., 4.]),
#  'proof': array([5., 7.]),
#  'fenc': array([3., 6.]),
#  'author': array([7., 9.]),
#  'look': array([144., 164.]),
#  'sharp': array([ 8., 24.]),
#  'origin': array([64., 73.]),
#  'despit': array([65., 46.]),
#  'virtu': array([6., 8.]),
#  'blade': array([12.,  8.]),
#  'ii': array([18., 14.]),
#  'play': array([105.,  83.]),
#  'badli': array([25.,  0.]),
#  '91': array([1., 0.]),
#  'trailer': array([7., 3.]),
#  'ca': array([85., 42.]),
#  'coher': array([11.,  4.]),
#  'rhythm': array([ 7., 17.]),
#  'mayb': array([21., 11.]),
#  'leblanc': array([2., 0.]),
#  'thought': array([33., 74.]),
#  'basebal': array([2., 4.]),
#  'monkey': array([3., 0.]),
#  'wors': array([28.,  4.]),
#  'expect': array([43., 36.]),
#  'bar': array([6., 4.]),
#  'sixth': array([4., 1.]),
#  'grade': array([9., 5.]),
#  'height': array([3., 2.]),
#  'barri': array([ 8., 11.]),
#  'sonnenfeld': array([2., 0.]),
#  'owe': array([6., 3.]),
#  'frank': array([12.,  4.]),
#  'pug': array([2., 0.]),
#  'big': array([93., 83.]),
#  'biggest': array([10.,  3.]),
#  'roger': array([ 7., 11.]),
#  'avari': array([7., 0.]),
#  'uproar': array([1., 0.]),
#  'mpaa': array([1., 0.]),
#  'glori': array([7., 4.]),
#  'bare': array([34., 10.]),
#  'shock': array([17., 20.]),
#  'anyth': array([51., 27.]),
#  'riddl': array([5., 1.]),
#  'unansw': array([1., 0.]),
#  'question': array([25., 30.]),
#  'requir': array([16.,  8.]),
#  'gargantuan': array([2., 0.]),
#  'leap': array([1., 7.]),
#  'faith': array([11., 23.]),
#  'plod': array([19.,  0.]),
#  'approach': array([22., 22.]),
#  'usher': array([3., 0.]),
#  'sit': array([41., 16.]),
#  'ask': array([17., 12.]),
#  'earnest': array([25., 22.]),
#  'heavi': array([46.,  9.]),
#  'sinis': array([1., 0.]),
#  'brain': array([17., 10.]),
#  'five': array([16., 10.]),
#  'plot': array([148.,  66.]),
#  'goe': array([41., 24.]),
#  'way': array([146., 192.]),
#  'introduc': array([3., 7.]),
#  'obstacl': array([3., 5.]),
#  'stumbl': array([5., 4.]),
#  'slow': array([32., 23.]),
#  'younger': array([6., 3.]),
#  'crowd': array([12., 15.]),
#  'shallow': array([19.,  3.]),
#  'older': array([10.,  3.]),
#  'reason': array([50., 25.]),
#  'offer': array([50., 76.]),
#  'advanc': array([6., 2.]),
#  'screen': array([78., 72.]),
#  'adventur': array([23., 41.]),
#  'pluto': array([4., 0.]),
#  'nash': array([4., 0.]),
#  'stinker': array([4., 0.]),
#  'punch': array([13., 16.]),
#  'line': array([42., 24.]),
#  'without': array([78., 89.]),
#  'joke': array([67., 13.]),
#  'built': array([10.,  2.]),
#  'musti': array([5., 0.]),
#  'memori': array([12., 32.]),
#  'dimension': array([8., 5.]),
#  'put': array([49., 44.]),
#  'battl': array([12., 12.]),
#  'will': array([ 9., 10.]),
#  'buy': array([12.,  6.]),
#  'wo': array([26., 34.]),
#  'intellig': array([38., 65.]),
#  'entic': array([2., 3.]),
#  'prospect': array([4., 3.]),
#  'lot': array([78., 63.]),
#  'nubil': array([1., 0.]),
#  'campu': array([3., 0.]),
#  'deprav': array([4., 0.]),
#  'fade': array([8., 1.]),
#  'amid': array([6., 3.]),
#  'deliber': array([5., 5.]),
#  'tiresom': array([19.,  1.]),
#  'ugli': array([27.,  6.]),
#  'render': array([8., 8.]),
#  'failur': array([12.,  4.]),
#  'trace': array([3., 4.]),
#  'dramat': array([40., 34.]),
#  'reel': array([4., 6.]),
#  'spoiler': array([1., 0.]),
#  'alert': array([2., 3.]),
#  'significantli': array([2., 2.]),
#  'charm': array([46., 94.]),
#  'listen': array([4., 6.]),
#  'four': array([20., 17.]),
#  'tast': array([25., 16.]),
#  'exagger': array([6., 2.]),
#  'recount': array([1., 1.]),
#  'halloween': array([8., 2.]),
#  'trip': array([15., 12.]),
#  'haunt': array([ 9., 24.]),
#  'hous': array([19., 18.]),
#  'confus': array([18., 11.]),
#  'messag': array([32., 37.]),
#  'desir': array([ 9., 14.]),
#  'contort': array([1., 0.]),
#  'idea': array([78., 40.]),
#  'three': array([40., 35.]),
#  'actress': array([17., 22.]),
#  'deserv': array([27., 25.]),
#  'deadli': array([8., 3.]),
#  'dull': array([78.,  7.]),
#  'pointless': array([18.,  0.]),
#  'medit': array([ 5., 22.]),
#  'loser': array([4., 2.]),
#  'gone': array([28., 11.]),
#  'seed': array([1., 3.]),
#  'hotel': array([4., 4.]),
#  'sensibl': array([5., 7.]),
#  'overrun': array([1., 3.]),
#  'character': array([15., 11.]),
#  'robot': array([4., 0.]),
#  'juri': array([1., 0.]),
#  'bestow': array([2., 0.]),
#  'hoffman': array([11.,  7.]),
#  'brother': array([15., 17.]),
#  'gordi': array([1., 0.]),
#  'waldo': array([1., 0.]),
#  'salt': array([3., 1.]),
#  'award': array([ 5., 10.]),
#  '2002': array([15.,  9.]),
#  'sundanc': array([2., 4.]),
#  'festiv': array([ 9., 10.]),
#  'honor': array([6., 8.]),
#  'pull': array([15., 27.]),
#  'prescrib': array([1., 0.]),
#  'recommend': array([17., 17.]),
#  'bland': array([33.,  5.]),
#  'dentist': array([2., 0.]),
#  'wait': array([24., 16.]),
#  'complet': array([51., 27.]),
#  'sooth': array([2., 1.]),
#  'muzak': array([1., 0.]),
#  'cushion': array([1., 1.]),
#  'predict': array([61., 32.]),
#  'sex': array([21., 29.]),
#  'lame': array([23.,  2.]),
#  'evad': array([3., 0.]),
#  'respons': array([8., 9.]),
#  'dog': array([31.,  9.]),
#  'alon': array([14., 14.]),
#  'toddler': array([1., 0.]),
#  'boob': array([2., 1.]),
#  'fantasti': array([1., 0.]),
#  'huge': array([ 8., 21.]),
#  'topic': array([ 7., 10.]),
#  'surfacey': array([1., 0.]),
#  'insight': array([31., 38.]),
#  'instanc': array([3., 2.]),
#  'good': array([196., 236.]),
#  'happen': array([37., 22.]),
#  'portrait': array([ 7., 50.]),
#  'alien': array([10., 16.]),
#  'perfect': array([12., 43.]),
#  'certainli': array([29., 26.]),
#  'succeed': array([4., 9.]),
#  'code': array([3., 5.]),
#  'talker': array([1., 0.]),
#  'hollow': array([9., 2.]),
#  'tribut': array([ 6., 11.]),
#  'skip': array([12.,  3.]),
#  'philip': array([5., 3.]),
#  'glass': array([8., 9.]),
#  'soundtrack': array([15.,  8.]),
#  'cd': array([1., 0.]),
#  'cold': array([26., 14.]),
#  'man': array([51., 86.]),
#  'motion': array([14., 11.]),
#  'dignifi': array([1., 0.]),
#  'ceo': array([1., 0.]),
#  'meet': array([10., 12.]),
#  'rustic': array([1., 1.]),
#  'retreat': array([2., 1.]),
#  'pee': array([2., 1.]),
#  'tree': array([3., 2.]),
#  'laughter': array([8., 6.]),
#  'mechan': array([14.,  1.]),
#  'kinda': array([6., 1.]),
#  'goofi': array([14., 11.]),
#  'museum': array([2., 2.]),
#  'exhibit': array([2., 1.]),
#  'view': array([25., 39.]),
#  'contemporari': array([ 7., 21.]),
#  'interpret': array([3., 6.]),
#  'joan': array([5., 2.]),
#  'prefeminist': array([1., 0.]),
#  'plight': array([3., 4.]),
#  'left': array([35., 13.]),
#  'present': array([28., 30.]),
#  'standard': array([21., 18.]),
#  'allow': array([12., 28.]),
#  'plenti': array([15., 17.]),
#  'nuditi': array([1., 2.]),
#  'bewar': array([2., 0.]),
#  'quirki': array([23., 33.]),
#  'brit': array([6., 3.]),
#  'dime': array([4., 0.]),
#  'oddli': array([ 5., 12.]),
#  'tedious': array([4., 0.]),
#  'subplot': array([8., 1.]),
#  'gag': array([40., 13.]),
#  'mix': array([28., 20.]),
#  'bag': array([11.,  3.]),
#  'aw': array([29.,  9.]),
#  'iranian': array([ 1., 13.]),
#  'grouchi': array([1., 0.]),
#  'ayatollah': array([1., 0.]),
#  'mosqu': array([1., 0.]),
#  'troubl': array([15., 16.]),
#  'everi': array([115.,  64.]),
#  'day': array([54., 53.]),
#  'extract': array([1., 0.]),
#  'byatt': array([1., 3.]),
#  'purpos': array([19.,  6.]),
#  'hollywood': array([60., 68.]),
#  'musker': array([1., 0.]),
#  'ron': array([2., 1.]),
#  'clement': array([1., 0.]),
#  'team': array([10.,  8.]),
#  'behind': array([19., 15.]),
#  'mermaid': array([1., 1.]),
#  'sparkl': array([2., 9.]),
#  'retina': array([1., 0.]),
#  'candi': array([7., 5.]),
#  'abl': array([10., 21.]),
#  'muster': array([4., 0.]),
#  'reson': array([11., 24.]),
#  'vacuum': array([2., 1.]),
#  'space': array([ 9., 17.]),
#  'adam': array([20.,  7.]),
#  'sandler': array([16.,  6.]),
#  'heart': array([ 40., 123.]),
#  'need': array([74., 61.]),
#  'butt': array([2., 1.]),
#  'doubt': array([15.,  9.]),
#  'highli': array([ 7., 23.]),
#  'ambiti': array([13., 18.]),
#  'project': array([35., 19.]),
#  'egoyan': array([5., 4.]),
#  'next': array([38., 16.]),
#  'clumsi': array([14.,  3.]),
#  'convolut': array([8., 3.]),
#  'offbeat': array([3., 9.]),
#  'touch': array([19., 74.]),
#  'knockaround': array([4., 0.]),
#  'rare': array([25., 65.]),
#  'raison': array([1., 0.]),
#  'detr': array([1., 0.]),
#  'fresh': array([20., 42.]),
#  'face': array([34., 51.]),
#  'gun': array([12.,  8.]),
#  'cast': array([ 72., 111.]),
#  'tame': array([3., 0.]),
#  'offens': array([16.,  1.]),
#  'pay': array([21., 14.]),
#  'queen': array([18.,  7.]),
#  'thoroughli': array([16., 17.]),
#  'modern': array([24., 38.]),
#  'maiden': array([1., 0.]),
#  'foolish': array([4., 0.]),
#  'victim': array([ 9., 12.]),
#  'mental': array([7., 7.]),
#  'ill': array([23.,  6.]),
#  'im': array([31., 19.]),
#  'say': array([63., 42.]),
#  'ice': array([11., 12.]),
#  'age': array([33., 82.]),
#  'fairli': array([14., 20.]),
#  'substanc': array([15., 10.]),
#  'life': array([ 92., 170.]),
#  'tell': array([46., 34.]),
#  'untold': array([1., 0.]),
#  'bui': array([1., 0.]),
#  'choos': array([8., 8.]),
#  'suspici': array([1., 1.]),
#  'familiar': array([36., 38.]),
#  'boilerpl': array([2., 0.]),
#  'subtleti': array([6., 6.]),
#  'target': array([20.,  8.]),
#  'realiz': array([18., 17.]),
#  'exact': array([3., 1.]),
#  'hundr': array([3., 2.]),
#  'termin': array([5., 1.]),
#  'dead': array([27., 16.]),
#  'episod': array([30.,  7.]),
#  'beauti': array([ 23., 117.]),
#  'act': array([109., 106.]),
#  'admittedli': array([2., 3.]),
#  'problemat': array([4., 4.]),
#  'specif': array([6., 9.]),
#  'j': array([ 6., 12.]),
#  'lo': array([7., 9.]),
#  'earn': array([7., 7.]),
#  'share': array([13., 19.]),
#  'holiday': array([8., 8.]),
#  'box': array([9., 5.]),
#  'offic': array([6., 7.]),
#  'pie': array([9., 0.]),
#  'although': array([24., 37.]),
#  'perfectli': array([ 8., 24.]),
#  'clear': array([17., 19.]),
#  'rymer': array([2., 0.]),
#  'trust': array([5., 4.]),
#  'conjur': array([3., 6.]),
#  'proper': array([2., 3.]),
#  'respect': array([ 9., 24.]),
#  'follow': array([28., 23.]),
#  'whole': array([53., 27.]),
#  'undead': array([2., 1.]),
#  'genr': array([31., 46.]),
#  'vampir': array([12.,  5.]),
#  'pic': array([7., 7.]),
#  'shrieki': array([1., 0.]),
#  'soprano': array([3., 0.]),
#  'incred': array([ 8., 14.]),
#  'date': array([15., 18.]),
#  'unfunni': array([26.,  0.]),
#  'demonstr': array([ 9., 15.]),
#  'maker': array([10., 10.]),
#  'cash': array([3., 2.]),
#  'sequel': array([31., 24.]),
#  'wow': array([6., 8.]),
#  'disappoint': array([29., 12.]),
#  'hook': array([9., 5.]),
#  'overlong': array([8., 2.]),
#  'credit': array([20., 22.]),
#  'writer': array([54., 47.]),
#  'watstein': array([1., 1.]),
#  'drag': array([31.,  7.]),
#  'nettelbeck': array([2., 3.]),
#  'women': array([30., 44.]),
#  'least': array([49., 39.]),
#  'harri': array([14.,  9.]),
#  'ham': array([6., 2.]),
#  'physic': array([ 2., 12.]),
#  'disintegr': array([5., 0.]),
#  'cours': array([16.,  9.]),
#  'certain': array([10., 18.]),
#  'poignanc': array([5., 8.]),
#  'light': array([30., 39.]),
#  'recent': array([20., 31.]),
#  'death': array([28., 24.]),
#  'boyd': array([3., 0.]),
#  'els': array([40., 16.]),
#  'consequ': array([6., 4.]),
#  'curiou': array([4., 4.]),
#  'note': array([12.,  4.]),
#  'similarli': array([2., 4.]),
#  'antitrust': array([1., 0.]),
#  'easili': array([16., 27.]),
#  'fraction': array([1., 0.]),
#  'budget': array([25., 13.]),
#  'ejemplo': array([1., 1.]),
#  'una': array([ 8., 12.]),
#  'cinta': array([4., 3.]),
#  'en': array([3., 7.]),
#  'que': array([16., 22.]),
#  'importa': array([1., 0.]),
#  'el': array([ 8., 13.]),
#  'talento': array([2., 0.]),
#  'su': array([2., 7.]),
#  'reparto': array([1., 0.]),
#  'interesant': array([2., 2.]),
#  'pudo': array([1., 0.]),
#  'haber': array([1., 0.]),
#  'resultado': array([2., 0.]),
#  'premisa': array([1., 0.]),
#  'pue': array([2., 1.]),
#  'es': array([ 7., 18.]),
#  'francament': array([1., 0.]),
#  'aburrido': array([1., 0.]),
#  'por': array([5., 2.]),
#  'momento': array([2., 4.]),
#  'deplor': array([1., 0.]),
#  'regist': array([3., 1.]),
#  'blip': array([2., 1.]),
#  'radar': array([2., 3.]),
#  'trope': array([4., 1.]),
#  'van': array([10.,  3.]),
#  'wilder': array([9., 0.]),
#  'unfaith': array([8., 4.]),
#  'whatsoev': array([3., 0.]),
#  'move': array([29., 92.]),
#  'filmmak': array([ 73., 100.]),
#  'chop': array([3., 3.]),
#  'suey': array([1., 0.]),
#  'seri': array([49., 22.]),
#  'trek': array([7., 5.]),
#  'nemesi': array([5., 1.]),
#  'suggest': array([15., 13.]),
#  '65th': array([1., 0.]),
#  'class': array([20., 21.]),
#  'reunion': array([2., 5.]),
#  'mixer': array([1., 0.]),
#  'eight': array([7., 8.]),
#  'member': array([10., 12.]),
#  'drink': array([5., 3.]),
#  'fail': array([61., 12.]),
#  'dystopian': array([1., 0.]),
#  ...}

# %%
# convert the freqs dictionary to nested list
def freqs_to_df(freqs, train_y):
    '''
    input:
        freqs: a frequencies dictionary (ex: {'simplist': array([15.,  4.]), 
                                              'silli': array([64., 20.]), . . })
        train_y: labels for data
    output:
        a frequencies dictionary in the form of dataframe
    '''
    # initialize an empty list to store the rows for dataframe
    freqs_list = []
    
    # Define the names of the dataframe columns
    column_names = ['word']
    column_names = column_names + list(np.unique(train_y))
    
    # convert the keys from the freqs dictionary to a list
    keys = list(freqs.keys())

    # For each row
    for i in range(len(freqs)):
        
        # define the elements for each column
        row = [keys[i]] + list(freqs.get(keys[i]))
        
        # update the frequency list
        freqs_list.append(row)
    
    # Create the dataframe
    df = pd.DataFrame(freqs_list, columns=column_names)
    df.set_index('word', inplace=True)
    return df

# %%
freqs_df = freqs_to_df(freqs, labels)
print(freqs_df)
# Out:
#              0     1
# word
# simplist  15.0   4.0
# silli     64.0  20.0
# tediou    28.0   5.0
# laddish    1.0   0.0
# juvenil    5.0   2.0
# ...        ...   ...
# deplet     0.0   1.0
# piscopo    0.0   1.0
# chaykin    0.0   1.0
# headli     0.0   1.0
# porthol    0.0   1.0
#
# [12666 rows x 2 columns]

# %%
freqs_df[0].sum()
# Out:
# 57518.0

# %% [markdown]
# # Training and Testing the Model

# %% [markdown]
# ## Build Training Function

# %%
def train_naive_bayes(freq_df, train_x, train_y):
    '''
    Input:
        freqs: a pandas dataframe with word indexing
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    
    freqs = freq_df

    # calculate V, the number of unique words in the vocabulary
    vocab = list(freqs.index)
    V = len(vocab)
    
    ########################################################################################
    # Part 1: Calculate the log prior probability for each class
    
    # Calculate D, the number of documents
    D = len(train_y)
    
    labels = list(np.unique(train_y.astype(int)))
    count = np.zeros((len(labels),))

    for train_label in train_y:
        for unique_label in labels:
            if train_label == unique_label:
                count[unique_label]+=1
                
    # -> count = [4000, 4000]; it means perfectly balanced between each classese

    # Calculate prior probability for each class
    prior = count/D # -> prior = array([0.5, 0.5])
    
        
    # Calculate the logprior for each class
    logprior = np.log(prior) # -> prior = array([-0.69314718, -0.69314718])
    
    ########################################################################################
    # Part 2.a. Calculate the total number of word occurrences for each class
    
    columns = list(freqs.columns)
    N_classes = []
    # calculate N frequency for each class
    for column in columns:
        
        freqs[column] = (freqs[column] + 1)/(freqs[column].sum()+V)
        
    # Calculate the log likelihood of the word
    loglikelihood = np.log(freqs)
        
    ########################################################################################
        
    return logprior, loglikelihood

# %%
labels = np.array(labels)
logprior, loglikelihood = train_naive_bayes(freqs_df, sentences, labels)
print(logprior)
loglikelihood
# Out:
# [-0.69314718 -0.69314718]
#                   0          1
# word
# simplist  -8.386287  -9.560856
# silli     -6.984488  -8.125772
# tediou    -7.791580  -9.378535
# laddish  -10.465728 -11.170294
# juvenil   -9.367116 -10.071682
# ...             ...        ...
# deplet   -11.158876 -10.477147
# piscopo  -11.158876 -10.477147
# chaykin  -11.158876 -10.477147
# headli   -11.158876 -10.477147
# porthol  -11.158876 -10.477147
#
# [12666 rows x 2 columns]

# %% [markdown]
# ## Build Testing Function

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    input:
        tweet: a string
        logprior: initial probability based on dataset
        loglikelihood: a dictionary of words mapping to numbers
    output:
        p: the sum of all the loglikelihood of each word in the tweet
        (if found in the dictionary) + logprior (a number)
    '''
    
    # process the tweet to get the list of words
    words = clean_doc(tweet)
    
    
    # Initialize probability to zero
    probs = []
    columns = list(loglikelihood.columns)
    for column in columns:
        prob = 0
        # Iterate for each word in word list
        for word in words:

            # check if the word exist in the loglikelihood dictionary
            if word in loglikelihood.index:
                prob += loglikelihood.loc[word, column]
        
        probs.append(prob)
        
    probs = logprior + probs
    y_hat = np.argmax(probs)
    
    return probs, y_hat

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    output:
        accuracy: (# of tweets classified correctly)/total # of tweets
    """
    # initial accuracy
    acc = 0
    
    # initialize an empty list for storing the predictions
    y_hats = []

    for tweet in test_x:
        
        _ , y = naive_bayes_predict(tweet, logprior, loglikelihood)
        
#         y_hat = np.argmax(probs)
        
        # update the y_hats
        y_hats.append(y)
        
#     Error: the mean absolute values between y_hats and test_y
    error = np.mean(np.abs(np.array(y_hats)-np.array(test_y)))
        
#     Accuracy is 1 - error
    acc = 1-error
    return acc

# %% [markdown]
# ## KFold CV

# %%
# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), np.array(list(corpus.label))

# Build the freqs dictionary for later uses
freqs = count_docs({}, sentences, labels)

# Turn the frequencies dictionary into dataframe
freqs_df = freqs_to_df(freqs, labels)
print(freqs_df.head())

# Retrieve the logprior and loglikelihood
logprior, loglikelihood = train_naive_bayes(freqs_df, sentences, labels)
print(logprior)
print(loglikelihood.head())

print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(sentences, labels, logprior, loglikelihood)))
# Out:
#              0     1
# word
# simplist  15.0   4.0
# silli     64.0  20.0
# tediou    28.0   5.0
# laddish    1.0   0.0
# juvenil    5.0   2.0
# [-0.69314718 -0.69314718]
#                   0          1
# word
# simplist  -8.386287  -9.560856
# silli     -6.984488  -8.125772
# tediou    -7.791580  -9.378535
# laddish  -10.465728 -11.170294
# juvenil   -9.367116 -10.071682
# Naive Bayes accuracy = 0.8987

# %%
# prepare cross validation
kfold = KFold(10, True)

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)
# count = 0
acc_list = []
# kfold.split() will return set indices for each split
for train, test in kfold.split(sentences):
    train_x, train_y = [], []
    test_x, test_y = [], []
    for i in train:
        train_x.append(sentences[i])
        train_y.append(labels[i])
        
    for i in test:
        test_x.append(sentences[i])
        test_y.append(labels[i])
    
    train_y = np.array(train_y)
    test_y = np.array(test_y)
    
    # Build the freqs dictionary for later uses
    freqs = count_docs({}, train_x, train_y)

    # Turn the frequencies dictionary into dataframe
    freqs_df = freqs_to_df(freqs, train_y)
#     print(freqs_df.head())

    # Retrieve the logprior and loglikelihood
    logprior, loglikelihood = train_naive_bayes(freqs_df, train_x, train_y)
    print('loglikelihood:\n{}'.format(loglikelihood.head()))
    print('logprior: {}'.format(logprior))
    
    acc = test_naive_bayes(test_x, test_y, logprior, loglikelihood)
    print("Naive Bayes test accuracy = %0.4f\n" %(acc))
    
    acc_list.append(acc)

acc_list = np.array(acc_list)
print()
print('The test ccuracy for each training:\n{}'.format(acc_list))
print('The mean of the test accuracy: ', acc_list.mean())
# Out:
# C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass shuffle=True as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# loglikelihood:
#                   0          1
# word
# simplist  -8.290324  -9.690078
# silli     -6.952039  -8.080640
# tediou    -7.730708  -9.284613
# laddish  -10.369766 -11.076372
# juvenil   -9.271153  -9.977760
# logprior: [-0.69554714 -0.69075297]
# Naive Bayes test accuracy = 0.7844
#
# loglikelihood:
#                   0          1
# word
# simplist  -8.296406  -9.465308
# silli     -7.043643  -8.184374
# tediou    -7.850119  -9.282987
# laddish  -10.375848 -11.074746
# juvenil   -9.277235 -10.381599
# logprior: [-0.69012933 -0.69617416]
# Naive Bayes test accuracy = 0.7919
#
# loglikelihood:
#                  0         1
# word
# simplist -8.425548 -9.976227
# silli    -6.953731 -8.184467
# tediou   -7.806509 -9.465401
# exploit  -7.663408 -8.772254
# larg     -7.886551 -8.030317
# logprior: [-0.69356411 -0.69273043]
# Naive Bayes test accuracy = 0.7580
#
# loglikelihood:
#                   0          1
# word
# simplist  -8.505058  -9.465928
# silli     -6.975663  -8.130927
# tediou    -7.737803  -9.465928
# laddish  -10.376860 -11.075366
# juvenil   -9.278248  -9.976754
# logprior: [-0.68836497 -0.69795237]
# Naive Bayes test accuracy = 0.7767
#
# loglikelihood:
#                   0          1
# word
# simplist  -8.500516  -9.469546
# silli     -6.987928  -8.134545
# tediou    -7.846590  -9.469546
# laddish  -10.372319 -11.078984
# juvenil   -9.456028  -9.980371
# logprior: [-0.69481593 -0.69148121]
# Naive Bayes test accuracy = 0.7730
#
# loglikelihood:
#                   0          1
# word
# simplist  -8.294550  -9.462670
# silli     -7.024087  -8.027585
# tediou    -7.771301  -9.280348
# laddish  -10.373991 -11.072108
# juvenil   -9.457700  -9.973495
# logprior: [-0.69044138 -0.69586032]
# Naive Bayes test accuracy = 0.7692
#
# loglikelihood:
#                  0          1
# word
# laddish -10.368510 -11.083880
# juvenil  -9.452219  -9.985267
# teenag   -8.496708  -8.598973
# boy      -7.535297  -7.557519
# could    -6.308067  -6.629532
# logprior: [-0.69900004 -0.68732838]
# Naive Bayes test accuracy = 0.7702
#
# loglikelihood:
#                   0          1
# word
# simplist  -8.422301  -9.468743
# silli     -7.018308  -8.187809
# tediou    -7.803262  -9.286421
# laddish  -10.368212 -11.078181
# juvenil   -9.269599 -10.385034
# logprior: [-0.69544243 -0.69085718]
# Naive Bayes test accuracy = 0.7786
#
# loglikelihood:
#                   0          1
# word
# simplist  -8.423636  -9.463431
# silli     -7.002250  -8.182497
# tediou    -7.730489  -9.281109
# laddish  -10.369546 -11.072869
# juvenil   -9.270934  -9.974257
# logprior: [-0.69148121 -0.69481593]
# Naive Bayes test accuracy = 0.7720
#
# loglikelihood:
#                   0          1
# word
# simplist  -8.294065  -9.467568
# silli     -6.972309  -8.132567
# tediou    -7.847778  -9.690712
# laddish  -10.373507 -11.077006
# juvenil   -9.274895  -9.978394
# logprior: [-0.69273043 -0.69356411]
# Naive Bayes test accuracy = 0.7589
#
#
# The test ccuracy for each training:
# [0.78444236 0.79194002 0.75797373 0.77673546 0.77298311 0.76923077
#  0.77016886 0.77861163 0.77204503 0.75891182]
# The mean of the test accuracy:  0.7733042793264066
