# %% [markdown]
# # Naive Bayes Classification with SUBJ Dataset
# <hr>
#
# We will build a text classification model using Naive Bayes on the Subjectivitiy Dataset. Since there is no standard train/test split for this dataset, we will use 10-Fold Cross Validation (CV).
#
# ## Load the library

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import random
from nltk.corpus import stopwords, twitter_samples
# from nltk.tokenize import TweetTokenizer
from sklearn.model_selection import KFold
from nltk.stem import PorterStemmer
from string import punctuation
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
import time

# %config IPCompleter.greedy=True
# %config IPCompleter.use_jedi=False
# nltk.download('twitter_samples')

# %% [markdown]
# ## Load the Dataset

# %%
corpus = pd.read_pickle('../0_data/SUBJ/SUBJ.pkl')
corpus.label = corpus.label.astype(int)
print(corpus.shape)
corpus
# Out:
# (10000, 3)
#                                                sentence  label  split
# 0     smart and alert , thirteen conversations about...      0  train
# 1     color , musical bounce and warm seas lapping o...      0  train
# 2     it is not a mass market entertainment but an u...      0  train
# 3     a light hearted french film about the spiritua...      0  train
# 4     my wife is an actress has its moments in looki...      0  train
# ...                                                 ...    ...    ...
# 9995  in the end , they discover that balance in lif...      1  train
# 9996  a counterfeit 1000 tomin bank note is passed i...      1  train
# 9997  enter the beautiful and mysterious secret agen...      1  train
# 9998  after listening to a missionary from china spe...      1  train
# 9999  looking for a short cut to fame , glass concoc...      1  train
#
# [10000 rows x 3 columns]

# %%
corpus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  10000 non-null  object
#  1   label     10000 non-null  int32
#  2   split     10000 non-null  object
# dtypes: int32(1), object(2)
# memory usage: 195.4+ KB

# %%
corpus.groupby( by='label').count()
# Out:
#        sentence  split
# label
# 0          5000   5000
# 1          5000   5000

# %%
# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)

# %% [markdown]
# ## Raw Number of Vocabulary

# %%
# Build the raw vocobulary for first inspection
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
vocab_raw = tokenizer.word_index
print('\nThe vocabulary size: {}\n'.format(len(vocab_raw)))
print(vocab_raw)
# Out:
# The vocabulary size: 21322
#
# {'the': 1, 'a': 2, 'and': 3, 'of': 4, 'to': 5, 'in': 6, 'is': 7, "'s": 8, 'it': 9, 'that': 10, 'his': 11, 'with': 12, 'as': 13, 'for': 14, 'an': 15, 'but': 16, 'on': 17, 'he': 18, 'her': 19, 'this': 20, 'by': 21, 'film': 22, 'who': 23, 'has': 24, 'be': 25, 'from': 26, 'are': 27, 'its': 28, 'their': 29, 'one': 30, 'at': 31, 'movie': 32, 'you': 33, 'they': 34, "n't": 35, 'about': 36, 'not': 37, 'when': 38, 'all': 39, 'out': 40, 'she': 41, 'have': 42, 'into': 43, 'more': 44, 'life': 45, 'up': 46, 'story': 47, 'him': 48, 'than': 49, 'like': 50, 'love': 51, 'what': 52, 'so': 53, 'or': 54, 'will': 55, 'new': 56, 'time': 57, 'if': 58, 'only': 59, 'world': 60, 'there': 61, 'just': 62, 'does': 63, 'two': 64, 'man': 65, 'no': 66, 'can': 67, 'them': 68, 'young': 69, 'old': 70, 'way': 71, 'was': 72, 'good': 73, 'some': 74, 'after': 75, 'even': 76, 'most': 77, 'which': 78, 'too': 79, 'much': 80, 'been': 81, 'i': 82, 'make': 83, 'while': 84, 'family': 85, 'own': 86, 'get': 87, 'do': 88, 'year': 89, 'through': 90, 'where': 91, 'first': 92, 'find': 93, 'well': 94, 'comedy': 95, 'other': 96, 'best': 97, 'very': 98, 'years': 99, 'back': 100, 'little': 101, 'work': 102, 'never': 103, 'off': 104, 'how': 105, 'director': 106, 'between': 107, 'characters': 108, 'enough': 109, 'also': 110, 'over': 111, 'down': 112, 'makes': 113, 'may': 114, 'we': 115, 'being': 116, 'day': 117, 'people': 118, 'go': 119, 'father': 120, 'girl': 121, 'before': 122, 'made': 123, 'see': 124, 'take': 125, 'would': 126, 'could': 127, 'end': 128, 'us': 129, 'both': 130, 'now': 131, 'must': 132, 'long': 133, 'then': 134, 'still': 135, 'any': 136, 'lives': 137, 'your': 138, 'american': 139, 'woman': 140, 'comes': 141, 'home': 142, 'takes': 143, 'action': 144, 'finds': 145, 'bad': 146, 'school': 147, 'mother': 148, 'himself': 149, 'real': 150, 'many': 151, 'friends': 152, 'those': 153, 'funny': 154, 'together': 155, 'another': 156, 'high': 157, 'help': 158, 'look': 159, 'death': 160, 'big': 161, 'had': 162, 'movies': 163, 'set': 164, 'three': 165, 'every': 166, 'without': 167, 'drama': 168, 'really': 169, 'become': 170, 'great': 171, 'nothing': 172, 'something': 173, 'city': 174, 'because': 175, 'each': 176, 'come': 177, 'should': 178, 'heart': 179, 'becomes': 180, 'war': 181, 'gets': 182, 'these': 183, 'things': 184, 'ever': 185, 'were': 186, 'son': 187, 'better': 188, "'re": 189, 'such': 190, 'against': 191, 'last': 192, 'though': 193, 'true': 194, 'documentary': 195, 'might': 196, 'character': 197, 'ca': 198, 'away': 199, 'women': 200, 'self': 201, 'seems': 202, 'films': 203, 'place': 204, 'soon': 205, 'cast': 206, 'wife': 207, 'boy': 208, 'plot': 209, 'past': 210, 'same': 211, 'yet': 212, 'whose': 213, 'men': 214, 'hard': 215, 'once': 216, 'daughter': 217, 'around': 218, 'few': 219, 'kind': 220, 'going': 221, 'goes': 222, 'friend': 223, 'far': 224, 'hollywood': 225, 'sense': 226, 'job': 227, 'john': 228, 'thing': 229, 'begins': 230, 'tale': 231, 'performances': 232, 'less': 233, 'turns': 234, 'small': 235, 'part': 236, 'de': 237, 'here': 238, 'fun': 239, 'falls': 240, 'until': 241, 'money': 242, 'works': 243, 'along': 244, 'beautiful': 245, 'however': 246, 'live': 247, 'dark': 248, 'night': 249, 'screen': 250, 'star': 251, 'human': 252, 'often': 253, 'house': 254, 'murder': 255, 'music': 256, 'quite': 257, 'full': 258, 'ultimately': 259, "'ll": 260, 'kids': 261, 'everything': 262, "'": 263, 'again': 264, 'our': 265, 'children': 266, 'almost': 267, 'during': 268, 'town': 269, 'despite': 270, 'know': 271, 'dead': 272, 'tries': 273, 'keep': 274, 'romantic': 275, 'living': 276, 'wants': 277, 'making': 278, 'itself': 279, 'left': 280, 'york': 281, 'meets': 282, 'right': 283, 'thriller': 284, 'audience': 285, 'watching': 286, 'art': 287, 'want': 288, 'power': 289, 'relationship': 290, 'script': 291, 'writer': 292, 'entertaining': 293, 'since': 294, 's': 295, 'evil': 296, 'black': 297, 'humor': 298, 'feel': 299, 'gives': 300, "'ve": 301, 'age': 302, 'under': 303, 'dream': 304, 'in ...

# %% [markdown]
# <!--## Split Dataset-->

# %% [markdown]
# # Data Preprocessing
# <hr>

# %% [markdown]
# ## Define `clean_doc` function

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stemmer = PorterStemmer()
    
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # remove remaining tokens that are not alphabetic
#     tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    tokens = [w for w in tokens if not w in stopwords]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) >= 1]
    # Stem the token
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

# %% [markdown]
# ## Define `count_docs` function

# %%
def count_docs(data, docs, ys):
    '''
    Input:
        data: a dictionary that will be used to map each pair to its frequency
        docs: a list of sentences
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''
    onehot = OneHotEncoder( sparse=False)
    y_onehot = onehot.fit_transform(np.reshape(ys, (-1,1)))
    # print(y_onehot)
    count = 0                    
    for doc, y in zip(docs, y_onehot):
        # For each word
        for word in clean_doc(doc):
            # if not in the data yet
            if word not in data:
                # assign it
                data[word] = y
            # if already in the data 
            else:
                # update it
                data[word] = data.get(word) + y

    return data

# %% [markdown]
# ## Build Frequencies Dictionary

# %%
# Build the freqs dictionary for later uses
freqs = count_docs({}, sentences, labels)
freqs
# Out:
# {'smart': array([31., 10.]),
#  'alert': array([5., 0.]),
#  'thirteen': array([2., 2.]),
#  'convers': array([8., 9.]),
#  'one': array([409., 375.]),
#  'thing': array([123.,  89.]),
#  'small': array([34., 61.]),
#  'gem': array([10.,  3.]),
#  'color': array([37., 13.]),
#  'music': array([62., 48.]),
#  'bounc': array([3., 0.]),
#  'warm': array([19.,  6.]),
#  'sea': array([12., 19.]),
#  'lap': array([2., 0.]),
#  'island': array([ 7., 28.]),
#  'shore': array([3., 7.]),
#  'enough': array([161.,  26.]),
#  'scienc': array([9., 3.]),
#  'send': array([ 8., 27.]),
#  'home': array([ 35., 122.]),
#  'think': array([68., 52.]),
#  'mass': array([2., 9.]),
#  'market': array([8., 4.]),
#  'entertain': array([129.,   7.]),
#  'uncompromis': array([6., 3.]),
#  'attempt': array([34., 59.]),
#  'artist': array([26., 50.]),
#  'anoth': array([69., 64.]),
#  'light': array([37., 25.]),
#  'heart': array([88., 59.]),
#  'french': array([29., 16.]),
#  'film': array([914., 226.]),
#  'spiritu': array([10., 14.]),
#  'quest': array([ 8., 24.]),
#  'fashion': array([26., 16.]),
#  'model': array([3., 6.]),
#  'seek': array([11., 41.]),
#  'peac': array([ 7., 15.]),
#  'mind': array([54., 37.]),
#  'love': array([178., 327.]),
#  'affair': array([ 9., 35.]),
#  'veterinarian': array([1., 2.]),
#  'non': array([12.,  6.]),
#  'practic': array([7., 6.]),
#  'jew': array([ 2., 10.]),
#  'wife': array([12., 93.]),
#  'actress': array([21., 10.]),
#  'moment': array([87., 28.]),
#  'look': array([160.,  89.]),
#  'comic': array([36., 24.]),
#  'effect': array([87., 14.]),
#  'jealousi': array([3., 4.]),
#  'end': array([128., 118.]),
#  'though': array([85., 29.]),
#  'mildli': array([10.,  0.]),
#  'amus': array([43.,  3.]),
#  'could': array([111.,  47.]),
#  'much': array([215.,  51.]),
#  'work': array([189., 163.]),
#  'engag': array([46., 15.]),
#  'drama': array([106.,  27.]),
#  'incis': array([6., 1.]),
#  'difficulti': array([5., 4.]),
#  'face': array([39., 82.]),
#  'nativ': array([3., 8.]),
#  'american': array([62., 94.]),
#  'even': array([215.,  74.]),
#  'harden': array([2., 0.]),
#  'voyeur': array([2., 1.]),
#  'would': array([114.,  45.]),
#  'requir': array([9., 7.]),
#  'patienc': array([9., 1.]),
#  'job': array([22., 79.]),
#  'get': array([153., 278.]),
#  'intermin': array([3., 0.]),
#  'shapeless': array([6., 0.]),
#  'documentari': array([62., 51.]),
#  'swing': array([8., 1.]),
#  'subcultur': array([7., 2.]),
#  'perri': array([3., 7.]),
#  'fist': array([6., 2.]),
#  'bull': array([2., 0.]),
#  'moor': array([12.,  7.]),
#  'farm': array([ 4., 16.]),
#  'matter': array([41., 17.]),
#  'time': array([259., 200.]),
#  'upper': array([5., 4.]),
#  'hand': array([50., 63.]),
#  'charact': array([244.,  66.]),
#  'paper': array([ 7., 13.]),
#  'thin': array([23.,  3.]),
#  'person': array([42., 79.]),
#  'undergo': array([2., 7.]),
#  'radic': array([2., 5.]),
#  'chang': array([26., 79.]),
#  'suit': array([7., 4.]),
#  'script': array([74.,  4.]),
#  'tire': array([13.,  6.]),
#  'joy': array([11., 11.]),
#  'rise': array([17., 18.]),
#  'stale': array([7., 0.]),
#  'materi': array([54.,  5.]),
#  'bland': array([15.,  1.]),
#  'outweigh': array([1., 1.]),
#  'nifti': array([2., 0.]),
#  'cleti': array([5., 0.]),
#  'tout': array([5., 1.]),
#  'never': array([117.,  75.]),
#  'becom': array([ 62., 205.]),
#  'clever': array([42.,  3.]),
#  'crime': array([29., 44.]),
#  'comedi': array([182.,  65.]),
#  'direct': array([91., 17.]),
#  'david': array([23., 28.]),
#  'twohi': array([2., 0.]),
#  'great': array([86., 42.]),
#  'eye': array([42., 48.]),
#  'eeri': array([4., 0.]),
#  'understat': array([2., 0.]),
#  'brought': array([13., 19.]),
#  'pitch': array([12.,  4.]),
#  'black': array([29., 46.]),
#  'tast': array([14.,  6.]),
#  'rock': array([25., 30.]),
#  'roll': array([16., 12.]),
#  'movi': array([783.,  80.]),
#  'put': array([43., 47.]),
#  'coffe': array([2., 1.]),
#  'tabl': array([4., 7.]),
#  'anywher': array([6., 0.]),
#  'provid': array([42., 17.]),
#  'kind': array([84., 16.]),
#  'laugh': array([59.,  1.]),
#  'therapi': array([5., 5.]),
#  'need': array([59., 43.]),
#  'offbeat': array([4., 1.]),
#  'humor': array([72.,  9.]),
#  'happi': array([22., 30.]),
#  'see': array([140.,  90.]),
#  'analyz': array([6., 0.]),
#  'feel': array([158.,  40.]),
#  'better': array([88., 28.]),
#  'alreadi': array([23., 20.]),
#  'worth': array([61., 10.]),
#  'side': array([31., 29.]),
#  'issu': array([28., 11.]),
#  'perspect': array([10.,  6.]),
#  'offer': array([61., 32.]),
#  'public': array([ 5., 16.]),
#  'rare': array([46., 10.]),
#  'watch': array([117.,  47.]),
#  'like': array([388.,  97.]),
#  'read': array([22., 11.]),
#  'portrait': array([35., 10.]),
#  'grief': array([12.,  7.]),
#  'keep': array([81., 50.]),
#  'shift': array([11.,  6.]),
#  'focu': array([19.,  4.]),
#  'journalist': array([ 4., 12.]),
#  'wrote': array([6., 7.]),
#  'despit': array([66., 15.]),
#  'annoy': array([12.,  1.]),
#  'capabl': array([15., 10.]),
#  'clayburgh': array([4., 0.]),
#  'tambor': array([4., 0.]),
#  'realli': array([97., 29.]),
#  'anchor': array([5., 0.]),
#  'emot': array([90., 33.]),
#  'realiti': array([29., 37.]),
#  'middl': array([28., 30.]),
#  'age': array([52., 51.]),
#  'good': array([229.,  76.]),
#  'woolli': array([1., 1.]),
#  'mammoth': array([1., 3.]),
#  'extinct': array([1., 0.]),
#  'everi': array([90., 37.]),
#  'kid': array([63., 50.]),
#  'schoolyard': array([1., 1.]),
#  'wish': array([11., 17.]),
#  'preposter': array([7., 0.]),
#  'tediou': array([17.,  0.]),
#  'sonni': array([2., 1.]),
#  'spike': array([6., 0.]),
#  'unintent': array([14.,  0.]),
#  'laughter': array([10.,  2.]),
#  'unfortun': array([19., 18.]),
#  'occur': array([3., 6.]),
#  'infrequ': array([1., 0.]),
#  'make': array([325., 193.]),
#  'guilti': array([12.,  5.]),
#  'pleasur': array([36.,  9.]),
#  '4ever': array([7., 0.]),
#  'sledgehamm': array([2., 0.]),
#  'appeal': array([35.,  4.]),
#  'pokemon': array([9., 0.]),
#  'video': array([40., 26.]),
#  'breath': array([11.,  5.]),
#  'big': array([86., 47.]),
#  'screen': array([87.,  6.]),
#  'induc': array([8., 3.]),
#  'headach': array([1., 0.]),
#  'slowli': array([ 9., 20.]),
#  'si': array([2., 3.]),
#  'el': array([ 9., 11.]),
#  'siglo': array([1., 1.]),
#  'xxi': array([1., 1.]),
#  'necesita': array([1., 0.]),
#  'de': array([62., 31.]),
#  'h': array([6., 5.]),
#  'roe': array([1., 0.]),
#  'hombr': array([1., 0.]),
#  'ara': array([1., 0.]),
#  'parec': array([1., 0.]),
#  'haber': array([2., 0.]),
#  'llegado': array([1., 0.]),
#  'para': array([8., 3.]),
#  'quedars': array([1., 0.]),
#  'hard': array([69., 32.]),
#  'tell': array([49., 76.]),
#  'crash': array([ 2., 14.]),
#  'bang': array([5., 1.]),
#  'salesmanship': array([1., 0.]),
#  'begin': array([ 27., 122.]),
#  'desper': array([22., 35.]),
#  'want': array([ 66., 120.]),
#  'wacki': array([8., 2.]),
#  'screwbal': array([2., 1.]),
#  'screwi': array([1., 0.]),
#  'mani': array([92., 44.]),
#  'talent': array([56., 14.]),
#  'peopl': array([97., 79.]),
#  'convinc': array([24., 29.]),
#  'wast': array([22.,  7.]),
#  'writer': array([53., 32.]),
#  'director': array([167.,  34.]),
#  'walter': array([ 3., 10.]),
#  'hill': array([10.,  6.]),
#  'hypermasculin': array([1., 0.]),
#  'element': array([26.,  5.]),
#  'abl': array([17., 43.]),
#  'inject': array([5., 3.]),
#  'real': array([75., 63.]),
#  'vital': array([10.,  2.]),
#  'art': array([52., 55.]),
#  'pulpi': array([3., 0.]),
#  'concept': array([21.,  4.]),
#  'complet': array([36., 23.]),
#  'forgett': array([13.,  0.]),
#  'go': array([115., 156.]),
#  'motion': array([11.,  7.]),
#  'pale': array([4., 1.]),
#  'extrem': array([23., 17.]),
#  'well': array([166.,  70.]),
#  'cast': array([109.,  22.]),
#  'especi': array([30., 13.]),
#  'larg': array([23., 15.]),
#  'number': array([27., 15.]),
#  'support': array([ 9., 17.]),
#  'role': array([38., 18.]),
#  'chill': array([17.,  5.]),
#  'tale': array([63., 43.]),
#  '20th': array([5., 3.]),
#  'centuri': array([22., 20.]),
#  'franc': array([ 6., 16.]),
#  'murder': array([ 22., 121.]),
#  'two': array([107., 222.]),
#  'rich': array([24., 27.]),
#  'women': array([34., 77.]),
#  'servant': array([1., 2.]),
#  '1933': array([1., 0.]),
#  'dark': array([39., 58.]),
#  'quirki': array([27.,  9.]),
#  'road': array([15., 25.]),
#  'constantli': array([ 5., 10.]),
#  'defi': array([5., 1.]),
#  'expect': array([40., 22.]),
#  'impostor': array([3., 1.]),
#  'nt': array([498., 186.]),
#  'templat': array([1., 0.]),
#  'remark': array([22.,  5.]),
#  'strong': array([35., 15.]),
#  'lack': array([68.,  5.]),
#  'utter': array([4., 2.]),
#  'author': array([ 9., 20.]),
#  'genr': array([32.,  7.]),
#  'certain': array([15.,  6.]),
#  'robust': array([2., 0.]),
#  'mix': array([21.,  7.]),
#  'bloodlet': array([1., 2.]),
#  'open': array([24., 30.]),
#  'amid': array([6., 2.]),
#  'blood': array([13., 19.]),
#  'gore': array([7., 2.]),
#  'del': array([6., 1.]),
#  'toro': array([2., 3.]),
#  'unexpect': array([15., 18.]),
#  'graviti': array([5., 0.]),
#  'blade': array([11.,  5.]),
#  'ii': array([12.,  8.]),
#  'undeni': array([7., 1.]),
#  'enjoy': array([73.,  6.]),
#  'cram': array([3., 0.]),
#  'refer': array([7., 3.]),
#  'fun': array([83., 10.]),
#  'wear': array([14.,  6.]),
#  'noth': array([76., 48.]),
#  'els': array([22., 16.]),
#  'happen': array([24., 52.]),
#  'purpos': array([13., 17.]),
#  'puls': array([5., 0.]),
#  'help': array([ 34., 126.]),
#  'lil': array([3., 1.]),
#  'bow': array([6., 0.]),
#  'wow': array([5., 0.]),
#  'tone': array([27.,  2.]),
#  'pint': array([1., 0.]),
#  'size': array([10.,  2.]),
#  'gangsta': array([1., 1.]),
#  'act': array([121.,  34.]),
#  'play': array([100., 118.]),
#  'someon': array([13., 20.]),
#  'resembl': array([11.,  2.]),
#  'mimet': array([1., 0.]),
#  'approxim': array([1., 0.]),
#  'contempt': array([3., 0.]),
#  '8': array([4., 6.]),
#  '1': array([6., 7.]),
#  '2': array([24., 12.]),
#  'eastwood': array([3., 2.]),
#  'icon': array([6., 2.]),
#  'moviemak': array([5., 0.]),
#  'best': array([139.,  82.]),
#  'actor': array([83., 24.]),
#  'produc': array([19., 33.]),
#  'around': array([37., 61.]),
#  'respons': array([ 8., 16.]),
#  'excel': array([29.,  1.]),
#  'hero': array([28., 17.]),
#  'stumbl': array([ 7., 12.]),
#  'sometim': array([50., 14.]),
#  'nair': array([7., 0.]),
#  'use': array([61., 89.]),
#  'monsoon': array([3., 0.]),
#  'wed': array([14., 33.]),
#  'lament': array([2., 0.]),
#  'loss': array([10., 12.]),
#  'cultur': array([51., 30.]),
#  'instead': array([21., 21.]),
#  'chanc': array([11., 44.]),
#  'revit': array([1., 0.]),
#  'alway': array([40., 26.]),
#  'clung': array([1., 0.]),
#  'tradit': array([16., 23.]),
#  'stuf': array([2., 0.]),
#  'brim': array([6., 0.]),
#  'idea': array([61., 28.]),
#  'instig': array([1., 0.]),
#  'michael': array([14., 37.]),
#  'rambl': array([6., 0.]),
#  'examin': array([22., 13.]),
#  'gun': array([ 9., 34.]),
#  'usual': array([29., 10.]),
#  'modu': array([1., 0.]),
#  'operandi': array([1., 0.]),
#  'crucifixion': array([1., 0.]),
#  'juxtaposit': array([2., 0.]),
#  'joke': array([35.,  5.]),
#  'flaki': array([2., 0.]),
#  'reson': array([20.,  0.]),
#  'lightweight': array([7., 0.]),
#  'bizarr': array([19., 19.]),
#  'origin': array([76., 17.]),
#  'fontain': array([4., 0.]),
#  'agreeabl': array([3., 0.]),
#  'startl': array([6., 6.]),
#  'close': array([31., 32.]),
#  'up': array([12.,  1.]),
#  'grace': array([23., 14.]),
#  'move': array([62., 57.]),
#  'camera': array([25., 20.]),
#  'creat': array([49., 44.]),
#  'sheerli': array([2., 0.]),
#  'cinemat': array([49.,  2.]),
#  'start': array([34., 95.]),
#  'adrien': array([1., 3.]),
#  'brodi': array([1., 0.]),
#  'titl': array([42.,  7.]),
#  'conclus': array([8., 3.]),
#  'power': array([68., 87.]),
#  'satisfi': array([34.,  2.]),
#  'refresh': array([11.,  0.]),
#  'whoope': array([1., 0.]),
#  'cushion': array([2., 0.]),
#  'effort': array([39., 13.]),
#  'aim': array([15.,  4.]),
#  'youth': array([ 8., 21.]),
#  'salut': array([3., 0.]),
#  'hanek': array([6., 0.]),
#  'adapt': array([27., 13.]),
#  'elfried': array([1., 0.]),
#  'jelinek': array([2., 0.]),
#  'novel': array([22., 20.]),
#  'nearli': array([34., 12.]),
#  'graphic': array([7., 1.]),
#  'brutal': array([14., 17.]),
#  'shock': array([18., 12.]),
#  'difficult': array([20., 10.]),
#  'barri': array([5., 6.]),
#  'us': array([126.,  29.]),
#  'danger': array([12., 55.]),
#  'secretli': array([ 1., 11.]),
#  'unhing': array([1., 0.]),
#  'guy': array([39., 45.]),
#  'easili': array([23.,  4.]),
#  'kill': array([  8., 129.]),
#  'presid': array([ 2., 12.]),
#  'made': array([117.,  47.]),
#  'distant': array([3., 8.]),
#  'steril': array([2., 0.]),
#  'yet': array([65., 37.]),
#  'compuls': array([5., 6.]),
#  'watchabl': array([11.,  0.]),
#  'sordid': array([2., 2.]),
#  'life': array([149., 377.]),
#  'hogan': array([1., 1.]),
#  'star': array([71., 70.]),
#  'bob': array([4., 8.]),
#  'crane': array([3., 2.]),
#  'disguis': array([12.,  6.]),
#  'worst': array([20., 14.]),
#  'summer': array([23., 21.]),
#  'year': array([130., 322.]),
#  'dan': array([2., 6.]),
#  'veret': array([2., 0.]),
#  'metaphor': array([14.,  3.]),
#  'needl': array([2., 0.]),
#  'segment': array([1., 1.]),
#  'thread': array([1., 2.]),
#  'form': array([24., 38.]),
#  'sweep': array([6., 4.]),
#  'tapestri': array([3., 0.]),
#  'mi': array([1., 3.]),
#  'explan': array([6., 4.]),
#  'content': array([6., 3.]),
#  'waydowntown': array([6., 0.]),
#  'citi': array([ 24., 107.]),
#  'somewher': array([12.,  2.]),
#  'spend': array([16., 35.]),
#  'rest': array([10., 16.]),
#  'sure': array([40., 11.]),
#  'place': array([61., 72.]),
#  'visit': array([ 5., 33.]),
#  'paulin': array([5., 0.]),
#  'paulett': array([4., 0.]),
#  'round': array([6., 7.]),
#  'set': array([ 54., 131.]),
#  'apart': array([10., 31.]),
#  'debrauw': array([3., 0.]),
#  'refus': array([15., 15.]),
#  'push': array([11., 15.]),
#  'easi': array([31.,  8.]),
#  'button': array([5., 0.]),
#  'young': array([ 48., 250.]),
#  'possibl': array([37., 28.]),
#  'infant': array([1., 0.]),
#  'might': array([81., 31.]),
#  'distract': array([7., 6.]),
#  'quick': array([ 8., 11.]),
#  'movement': array([5., 9.]),
#  'sound': array([31.,  7.]),
#  'lot': array([68., 14.]),
#  'cool': array([24.,  9.]),
#  'stuff': array([26.,  1.]),
#  'pack': array([19., 13.]),
#  'espn': array([1., 0.]),
#  'ultim': array([70., 54.]),
#  'x': array([12., 12.]),
#  'old': array([ 97., 206.]),
#  'quickli': array([12., 38.]),
#  'barbershop': array([7., 2.]),
#  'cube': array([5., 2.]),
#  'fix': array([3., 2.]),
#  'sit': array([30., 11.]),
#  'harland': array([1., 0.]),
#  'william': array([15., 22.]),
#  'funni': array([126.,   9.]),
#  'drag': array([19., 10.]),
#  'consid': array([18., 17.]),
#  'perman': array([2., 1.]),
#  'sex': array([22., 32.]),
#  'reassign': array([1., 0.]),
#  'imag': array([28., 17.]),
#  'give': array([96., 59.]),
#  'backbon': array([1., 0.]),
#  'compani': array([14., 27.]),
#  'edg': array([18.,  9.]),
#  'demis': array([1., 3.]),
#  'villain': array([12.,  8.]),
#  'evil': array([14., 62.]),
#  'passport': array([1., 2.]),
#  'photo': array([6., 7.]),
#  'resist': array([10., 11.]),
#  'plotless': array([2., 0.]),
#  'collect': array([10., 11.]),
#  'moron': array([2., 0.]),
#  'stunt': array([13.,  1.]),
#  'far': array([75., 21.]),
#  'broad': array([6., 2.]),
#  'melodramat': array([15.,  0.]),
#  'estrogen': array([3., 0.]),
#  'opera': array([25.,  2.]),
#  'pretti': array([49.,  8.]),
#  'toxic': array([3., 0.]),
#  'right': array([49., 38.]),
#  'kiss': array([10.,  1.]),
#  'come': array([150., 180.]),
#  'fanci': array([9., 1.]),
#  'typic': array([11.,  6.]),
#  'problem': array([45., 35.]),
#  'averag': array([13.,  5.]),
#  'world': array([ 98., 265.]),
#  'inhabit': array([6., 9.]),
#  'notabl': array([7., 0.]),
#  'observ': array([17.,  2.]),
#  'long': array([83., 78.]),
#  'still': array([102.,  48.]),
#  'romant': array([52., 30.]),
#  'plotlin': array([1., 0.]),
#  'straight': array([25., 10.]),
#  'cinderella': array([1., 5.]),
#  'stori': array([268., 312.]),
#  'singl': array([23., 26.]),
#  'surpris': array([46., 21.]),
#  'sleev': array([6., 1.]),
#  'somehow': array([14., 10.]),
#  'manag': array([64., 28.]),
#  'spell': array([12.,  5.]),
#  'charm': array([70., 15.]),
#  'trifl': array([11.,  0.]),
#  'welcom': array([10.,  4.]),
#  'return': array([12., 85.]),
#  'jocular': array([1., 0.]),
#  'spot': array([10.,  3.]),
#  'culprit': array([1., 1.]),
#  'earli': array([11., 20.]),
#  'predict': array([33.,  5.]),
#  'thriller': array([68., 14.]),
#  'without': array([93., 34.]),
#  'spooki': array([7., 3.]),
#  'crystal': array([7., 6.]),
#  'lake': array([3., 9.]),
#  'camp': array([ 9., 26.]),
#  'horror': array([34., 18.]),
#  'lose': array([17., 45.]),
#  'creepi': array([22.,  2.]),
#  'menac': array([6., 6.]),
#  'suspens': array([34.,  5.]),
#  'disbelief': array([4., 1.]),
#  'bad': array([113.,  31.]),
#  'screenwrit': array([24.,  8.]),
#  'wallop': array([4., 1.]),
#  'latter': array([5., 2.]),
#  'littl': array([137.,  72.]),
#  'stylish': array([7., 2.]),
#  'exercis': array([23.,  3.]),
#  'revision': array([1., 0.]),
#  'whose': array([40., 62.]),
#  'point': array([71., 15.]),
#  'doubt': array([13.,  7.]),
#  'true': array([31., 85.]),
#  'serv': array([22., 13.]),
#  'rather': array([53., 11.]),
#  'moral': array([31., 11.]),
#  'know': array([58., 77.]),
#  'fabl': array([8., 1.]),
#  'anyon': array([42., 20.]),
#  'count': array([ 9., 11.]),
#  'five': array([13., 46.]),
#  'target': array([14.,  9.]),
#  'dumb': array([26.,  0.]),
#  'concoct': array([3., 2.]),
#  'defiantli': array([2., 0.]),
#  'top': array([18., 31.]),
#  'action': array([107.,  51.]),
#  'scene': array([70., 31.]),
#  'high': array([52., 81.]),
#  'stake': array([5., 9.]),
#  'car': array([ 7., 42.]),
#  'chase': array([10., 26.]),
#  'fearsom': array([1., 2.]),
#  'drug': array([ 9., 82.]),
#  'bust': array([4., 5.]),
#  'seiz': array([2., 1.]),
#  'adren': array([1., 0.]),
#  'gland': array([1., 0.]),
#  'milk': array([5., 0.]),
#  'epilept': array([1., 0.]),
#  'farmer': array([1., 4.]),
#  'kosminski': array([2., 0.]),
#  'salt': array([3., 2.]),
#  'wound': array([ 8., 13.]),
#  'tortur': array([9., 8.]),
#  'self': array([78., 33.]),
#  'consciou': array([7., 2.]),
#  'sting': array([5., 2.]),
#  'sober': array([5., 1.]),
#  'sever': array([31., 34.]),
#  'reject': array([ 8., 11.]),
#  'mother': array([ 12., 135.]),
#  'bite': array([16.,  0.]),
#  'perform': array([168.,  33.]),
#  'less': array([81., 13.]),
#  'affection': array([7., 2.]),
#  'deftli': array([11.,  1.]),
#  'smartli': array([4., 0.]),
#  'ice': array([11., 11.]),
#  'first': array([106., 128.]),
#  'comput': array([ 7., 19.]),
#  'gener': array([61., 24.]),
#  'featur': array([62., 29.]),
#  'cartoon': array([11.,  2.]),
#  'glacial': array([1., 0.]),
#  'pace': array([41.,  3.]),
#  'christma': array([ 8., 17.]),
#  'elv': array([1., 2.]),
#  'snow': array([6., 1.]),
#  'pimp': array([1., 4.]),
#  'ho': array([7., 2.]),
#  'ferrara': array([4., 0.]),
#  'strongest': array([3., 0.]),
#  'touch': array([44., 12.]),
#  'recent': array([25., 16.]),
#  'skip': array([7., 2.]),
#  'opportun': array([15., 18.]),
#  'nachtwey': array([6., 0.]),
#  'hammer': array([3., 2.]),
#  'grim': array([6., 2.]),
#  'gutter': array([1., 0.]),
#  'battlefield': array([3., 1.]),
#  'question': array([27., 35.]),
#  'news': array([ 6., 16.]),
#  'relentlessli': array([3., 1.]),
#  'wholesom': array([4., 0.]),
#  'swipe': array([3., 1.]),
#  'someth': array([88., 38.]),
#  'shyamalan': array([8., 0.]),
#  'copiou': array([1., 1.]),
#  'hint': array([4., 0.]),
#  'along': array([34., 56.]),
#  'way': array([175., 160.]),
#  'myriad': array([2., 1.]),
#  'sign': array([17., 16.]),
#  'beneath': array([7., 8.]),
#  'familiar': array([34.,  6.]),
#  'surfac': array([13., 15.]),
#  'bigger': array([10.,  4.]),
#  'meaning': array([5., 1.]),
#  'green': array([15., 16.]),
#  'men': array([41., 61.]),
#  'earth': array([13., 35.]),
#  'harvest': array([1., 0.]),
#  'alabama': array([5., 2.]),
#  'pleasant': array([10.,  1.]),
#  'spite': array([7., 5.]),
#  'occasion': array([26.,  4.]),
#  'slow': array([35.,  2.]),
#  'due': array([ 4., 15.]),
#  'primarili': array([4., 3.]),
#  'perki': array([1., 1.]),
#  'witherspoon': array([4., 2.]),
#  'rate': array([17.,  4.]),
#  'odd': array([21., 12.]),
#  'heaven': array([18.,  4.]),
#  'hell': array([19., 21.]),
#  'creep': array([3., 0.]),
#  'fine': array([37.,  4.]),
#  'nice': array([24.,  6.]),
#  'combin': array([19.,  6.]),
#  'enigmat': array([7., 1.]),
#  'memento': array([2., 0.]),
#  'hallucinatori': array([2., 0.]),
#  'requiem': array([2., 0.]),
#  'dream': array([ 19., 118.]),
#  'walk': array([18., 24.]),
#  'halfway': array([7., 1.]),
#  'encourag': array([7., 2.]),
#  'other': array([17., 22.]),
#  'stand': array([34., 28.]),
#  'applaud': array([4., 0.]),
#  'undoubtedli': array([4., 0.]),
#  'leav': array([43., 77.]),
#  'feroci': array([1., 1.]),
#  'debat': array([3., 6.]),
#  'japan': array([5., 6.]),
#  'premier': array([1., 1.]),
#  'stylist': array([9., 2.]),
#  'hit': array([28., 47.]),
#  'audienc': array([89., 10.]),
#  'may': array([125.,  61.]),
#  'dement': array([6., 1.]),
#  'date': array([20., 20.]),
#  'filmmak': array([97., 30.]),
#  'secret': array([21., 87.]),
#  'buri': array([ 6., 11.]),
#  'take': array([140., 204.]),
#  'reveal': array([24., 37.]),
#  'strang': array([29., 41.]),
#  'occurr': array([1., 0.]),
#  'build': array([21., 31.]),
#  'viewer': array([51.,  4.]),
#  'urgenc': array([4., 1.]),
#  'spirit': array([46., 37.]),
#  'voltair': array([1., 1.]),
#  'moli': array([1., 0.]),
#  'guard': array([ 4., 20.]),
#  'volley': array([1., 0.]),
#  'wit': array([40., 30.]),
#  'deadli': array([6., 9.]),
#  'gestur': array([6., 0.]),
#  'milieu': array([4., 0.]),
#  'lush': array([7., 3.]),
#  'apparel': array([1., 0.]),
#  'landscap': array([12., 10.]),
#  'captiv': array([7., 9.]),
#  '18th': array([1., 2.]),
#  'laci': array([1., 1.]),
#  'holm': array([4., 9.]),
#  'terrif': array([23.,  1.]),
#  'hjejl': array([1., 0.]),
#  'quit': array([71., 25.]),
#  'fail': array([34., 21.]),
#  'intrigu': array([25., 12.]),
#  'premis': array([24.,  1.]),
#  'hollywood': array([66., 30.]),
#  'share': array([ 9., 29.]),
#  'belli': array([1., 1.]),
#  'includ': array([19., 48.]),
#  'knockout': array([4., 0.]),
#  'line': array([34., 25.]),
#  'wind': array([16., 10.]),
#  'miss': array([35., 31.]),
#  'histori': array([34., 37.]),
#  'academi': array([2., 9.]),
#  'wonder': array([57., 16.]),
#  'jazz': array([4., 3.]),
#  'chicago': array([ 7., 18.]),
#  '2002': array([13.,  9.]),
#  'zellweg': array([4., 3.]),
#  'whini': array([3., 0.]),
#  'pouti': array([1., 0.]),
#  'lip': array([8., 2.]),
#  'poof': array([1., 0.]),
#  'spindli': array([1., 0.]),
#  'ingenu': array([2., 1.]),
#  'nomin': array([7., 1.]),
#  'es': array([9., 0.]),
#  'divertida': array([3., 0.]),
#  'visualment': array([1., 0.]),
#  'espectacular': array([1., 0.]),
#  'muy': array([2., 0.]),
#  'entretenida': array([1., 0.]),
#  'simpl': array([20., 13.]),
#  'sencillament': array([1., 0.]),
#  'te': array([1., 2.]),
#  'sorprend': array([1., 0.]),
#  'sinc': array([37., 38.]),
#  'japanes': array([ 5., 20.]),
#  'akira': array([1., 1.]),
#  'kurosawa': array([1., 0.]),
#  'ran': array([2., 2.]),
#  'savageri': array([1., 0.]),
#  'combat': array([ 4., 13.]),
#  'specter': array([2., 1.]),
#  'death': array([ 32., 108.]),
#  'visual': array([61., 14.]),
#  'operat': array([3., 0.]),
#  'grandeur': array([3., 0.]),
#  'graini': array([2., 0.]),
#  'rough': array([7., 4.]),
#  'depend': array([12.,  7.]),
#  'naturalist': array([5., 0.]),
#  'care': array([57., 32.]),
#  'lit': array([1., 2.]),
#  'exhaust': array([7., 4.]),
#  'screenplay': array([29.,  1.]),
#  'across': array([12., 30.]),
#  'hip': array([17., 11.]),
#  'hop': array([8., 7.]),
#  'scoobi': array([8., 2.]),
#  'doo': array([4., 1.]),
#  'next': array([31., 37.]),
#  'hot': array([14., 18.]),
#  'directori': array([8., 0.]),
#  'debut': array([23.,  4.]),
#  'cumul': array([4., 0.]),
#  'repuls': array([4., 0.]),
#  'depress': array([21., 10.]),
#  'judg': array([4., 9.]),
#  'strength': array([16., 11.]),
#  'superbl': array([9., 0.]),
#  'oliveira': array([5., 0.]),
#  'seem': array([121.,  66.]),
#  'readi': array([ 7., 10.]),
#  'passion': array([25., 26.]),
#  'irrat': array([2., 0.]),
#  'suffer': array([27., 23.]),
#  'cruel': array([5., 2.]),
#  'tarantula': array([2., 0.]),
#  'helga': array([1., 0.]),
#  'figur': array([18., 18.]),
#  'promin': array([2., 4.]),
#  'proceed': array([8., 1.]),
#  'grown': array([9., 5.]),
#  'rugrat': array([2., 0.]),
#  'christian': array([12., 11.]),
#  'sensit': array([17.,  3.]),
#  'reductionist': array([1., 0.]),
#  'view': array([32., 18.]),
#  'lord': array([ 3., 19.]),
#  'luv': array([2., 0.]),
#  'spread': array([4., 7.]),
#  'dr': array([ 3., 35.]),
#  'feelgood': array([1., 0.]),
#  'omnipot': array([1., 0.]),
#  'slacker': array([6., 1.]),
#  'vastli': array([4., 0.]),
#  'affront': array([1., 0.]),
#  'secularist': array([1., 0.]),
#  'prais': array([10.,  2.]),
#  'god': array([13., 35.]),
#  'deliv': array([48., 13.]),
#  'instant': array([3., 6.]),
#  'classic': array([36., 21.]),
#  'aloof': array([2., 1.]),
#  'raw': array([9., 3.]),
#  'fatal': array([12.,  8.]),
#  'reli': array([13.,  3.]),
#  'relationship': array([21., 86.]),
#  'festiv': array([5., 6.]),
#  'cann': array([2., 0.]),
#  'nail': array([4., 5.]),
#  'boil': array([6., 1.]),
#  'argot': array([1., 0.]),
#  'bracingli': array([1., 0.]),
#  'nasti': array([7., 4.]),
#  'accuraci': array([3., 0.]),
#  'frustratingli': array([4., 0.]),
#  'unconvinc': array([6., 0.]),
#  'demean': array([1., 0.]),
#  'subject': array([55., 14.]),
#  'fright': array([3., 2.]),
#  'vaniti': array([3., 2.]),
#  'pay': array([14., 23.]),
#  'debt': array([ 2., 13.]),
#  'miramax': array([1., 0.]),
#  'felt': array([16.,  2.]),
#  'owe': array([7., 4.]),
#  'benigni': array([8., 0.]),
#  'illus': array([3., 2.]),
#  'versu': array([3., 1.]),
#  'least': array([51., 10.]),
#  'passabl': array([4., 0.]),
#  'confus': array([20.,  8.]),
#  'favourit': array([2., 1.]),
#  '146': array([1., 0.]),
#  'minut': array([93., 12.]),
#  'third': array([15.,  6.]),
#  'row': array([2., 5.]),
#  'imax': array([14.,  0.]),
#  'cinema': array([51.,  8.]),
#  'sydney': array([1., 2.]),
#  'darl': array([1., 3.]),
#  'harbour': array([1., 5.]),
#  'tini': array([5., 2.]),
#  'seater': array([1., 0.]),
#  'plane': array([2., 6.]),
#  'carri': array([17., 28.]),
#  'giant': array([8., 4.]),
#  'australia': array([4., 4.]),
#  'glide': array([1., 0.]),
#  'bank': array([ 3., 45.]),
#  'hover': array([2., 0.]),
#  'seri': array([34., 33.]),
#  'assur': array([6., 2.]),
#  'respect': array([18., 15.]),
#  'past': array([34., 74.]),
#  'thrill': array([22.,  5.]),
#  'abundantli': array([2., 0.]),
#  'clear': array([21., 21.]),
#  'phenomenon': array([2., 7.]),
#  'reinvent': array([2., 1.]),
#  'new': array([120., 268.]),
#  'result': array([28., 35.]),
#  'reverber': array([1., 0.]),
#  'forc': array([49., 93.]),
#  'furi': array([4., 1.]),
#  'intens': array([25., 19.]),
#  'anyth': array([35., 21.]),
#  'mr': array([27., 31.]),
#  'scorses': array([10.,  0.]),
#  'achiev': array([25.,  8.]),
#  'meanest': array([1., 1.]),
#  'belov': array([5., 9.]),
#  'street': array([ 8., 59.]),
#  'imagin': array([51., 18.]),
#  'recal': array([6., 2.]),
#  'spare': array([6., 4.]),
#  'unlik': array([24., 23.]),
#  'alien': array([15., 21.]),
#  'either': array([31.,  6.]),
#  'gender': array([4., 2.]),
#  'leap': array([6., 1.]),
#  'shape': array([9., 4.]),
#  'peter': array([ 7., 35.]),
#  'sharp': array([20.,  4.]),
#  'sliver': array([1., 0.]),
#  'cut': array([21., 14.]),
#  'impress': array([29.,  9.]),
#  'show': array([70., 69.]),
#  'detail': array([29.,  8.]),
#  'condens': array([2., 0.]),
#  'evoc': array([10.,  0.]),
#  'strike': array([20., 21.]),
#  'trait': array([1., 1.]),
#  'interest': array([113.,  24.]),
#  'jerk': array([4., 1.]),
#  'byzantin': array([2., 0.]),
#  'incarn': array([5., 0.]),
#  'bother': array([8., 0.]),
#  'rapsploit': array([1., 0.]),
#  'frown': array([1., 0.]),
#  'upon': array([21., 31.]),
#  'darker': array([2., 3.]),
#  'natur': array([50., 21.]),
#  'certainli': array([27.,  2.]),
#  'matur': array([9., 1.]),
#  'seduc': array([ 2., 13.]),
#  'putti': array([2., 0.]),
#  'manipul': array([11., 21.]),
#  'card': array([6., 7.]),
#  'shark': array([2., 8.]),
#  'taken': array([18., 20.]),
#  'shameless': array([5., 0.]),
#  'contriv': array([24.,  1.]),
#  'erot': array([6., 6.]),
#  'neither': array([21.,  5.]),
#  'part': array([59., 57.]),
#  'gang': array([10., 44.]),
#  'daniel': array([ 4., 17.]),
#  'day': array([ 51., 193.]),
#  'lewi': array([3., 1.]),
#  'torment': array([2., 4.]),
#  'heritag': array([1., 2.]),
#  'storytel': array([25.,  2.]),
#  'abil': array([17., 15.]),
#  'honor': array([10., 13.]),
#  'faceless': array([1., 0.]),
#  'victim': array([ 8., 30.]),
#  'skin': array([15.,  9.]),
#  'beauti': array([80., 76.]),
#  'desir': array([13., 21.]),
#  'delect': array([3., 0.]),
#  'troubl': array([18., 38.]),
#  'disjoint': array([3., 0.]),
#  'mess': array([20.,  8.]),
#  'flow': array([9., 3.]),
#  'joli': array([6., 3.]),
#  'hideou': array([1., 0.]),
#  'yellow': array([2., 4.]),
#  'plan': array([  4., 109.]),
#  'inspir': array([40., 19.]),
#  'surviv': array([ 7., 35.]),
#  'wrap': array([10.,  1.]),
#  'pound': array([1., 4.]),
#  'psycholog': array([25., 12.]),
#  'flop': array([3., 1.]),
#  'souffl': array([2., 0.]),
#  'gone': array([20., 11.]),
#  'wrong': array([18., 28.]),
#  'schmidt': array([4., 1.]),
#  'reflect': array([11., 10.]),
#  'cautionari': array([4., 1.]),
#  'raunchi': array([6., 0.]),
#  'cho': array([7., 8.]),
#  'embrac': array([12.,  5.]),
#  'comer': array([1., 0.]),
#  'regardless': array([3., 3.]),
#  'sexual': array([19., 22.]),
#  'race': array([ 6., 31.]),
#  'ethnic': array([4., 1.]),
#  'sharper': array([3., 0.]),
#  'funnier': array([7., 1.]),
#  'fan': array([51., 13.]),
#  'behan': array([5., 0.]),
#  'irish': array([ 5., 15.]),
#  'reward': array([16.,  3.]),
#  'borstal': array([4., 0.]),
#  'boy': array([ 40., 108.]),
#  'miller': array([9., 6.]),
#  'free': array([ 9., 35.]),
#  ...}

# %%
# convert the freqs dictionary to nested list
def freqs_to_df(freqs, train_y):
    '''
    input:
        freqs: a frequencies dictionary (ex: {'simplist': array([15.,  4.]), 
                                              'silli': array([64., 20.]), . . })
        train_y: labels for data
    output:
        a frequencies dictionary in the form of dataframe
    '''
    # initialize an empty list to store the rows for dataframe
    freqs_list = []
    
    # Define the names of the dataframe columns
    column_names = ['word']
    column_names = column_names + list(np.unique(train_y))
    
    # convert the keys from the freqs dictionary to a list
    keys = list(freqs.keys())

    # For each row
    for i in range(len(freqs)):
        
        # define the elements for each column
        row = [keys[i]] + list(freqs.get(keys[i]))
        
        # update the frequency list
        freqs_list.append(row)
    
    # Create the dataframe
    df = pd.DataFrame(freqs_list, columns=column_names)
    df.set_index('word', inplace=True)
    return df

# %%
freqs_df = freqs_to_df(freqs, labels)
freqs_df
# Out:
#               0      1
# word
# smart      31.0   10.0
# alert       5.0    0.0
# thirteen    2.0    2.0
# convers     8.0    9.0
# one       409.0  375.0
# ...         ...    ...
# sculpt      0.0    1.0
# tomin       0.0    1.0
# bazaar      0.0    1.0
# schmitt     0.0    1.0
# gaffga      0.0    1.0
#
# [14591 rows x 2 columns]

# %%
freqs_df[0].sum()
# Out:
# 58780.0

# %% [markdown]
# # Training and Testing the Model

# %% [markdown]
# ## Build Training Function

# %%
def train_naive_bayes(freq_df, train_x, train_y):
    '''
    Input:
        freqs: a pandas dataframe with word indexing
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    
    freqs = freq_df

    # calculate V, the number of unique words in the vocabulary
    vocab = list(freqs.index)
    V = len(vocab)
    
    ########################################################################################
    # Part 1: Calculate the log prior probability for each class
    
    # Calculate D, the number of documents
    D = len(train_y)
    
    labels = list(np.unique(train_y.astype(int)))
    count = np.zeros((len(labels),))

    for train_label in train_y:
        for unique_label in labels:
            if train_label == unique_label:
                count[unique_label]+=1
                
    # -> count = [4000, 4000]; it means perfectly balanced between each classese

    # Calculate prior probability for each class
    prior = count/D # -> prior = array([0.5, 0.5])
    
        
    # Calculate the logprior for each class
    logprior = np.log(prior) # -> prior = array([-0.69314718, -0.69314718])
    
    ########################################################################################
    # Part 2.a. Calculate the total number of word occurrences for each class
    
    columns = list(freqs.columns)
    N_classes = []
    # calculate N frequency for each class
    for column in columns:
        
        freqs[column] = (freqs[column] + 1)/(freqs[column].sum()+V)
        
    # Calculate the log likelihood of the word
    loglikelihood = np.log(freqs)
        
    ########################################################################################
        
    return logprior, loglikelihood

# %%
labels = np.array(labels)
logprior, loglikelihood = train_naive_bayes(freqs_df, sentences, labels)
print(logprior)
loglikelihood
# Out:
# [-0.69314718 -0.69314718]
#                   0          1
# word
# smart     -7.737548  -8.869015
# alert     -9.411525 -11.266910
# thirteen -10.104672 -10.168298
# convers   -9.006059  -8.964325
# one       -5.187127  -5.337321
# ...             ...        ...
# sculpt   -11.203284 -10.573763
# tomin    -11.203284 -10.573763
# bazaar   -11.203284 -10.573763
# schmitt  -11.203284 -10.573763
# gaffga   -11.203284 -10.573763
#
# [14591 rows x 2 columns]

# %% [markdown]
# ## Build Testing Function

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    input:
        tweet: a string
        logprior: initial probability based on dataset
        loglikelihood: a dictionary of words mapping to numbers
    output:
        p: the sum of all the loglikelihood of each word in the tweet
        (if found in the dictionary) + logprior (a number)
    '''
    
    # process the tweet to get the list of words
    words = clean_doc(tweet)
    
    
    # Initialize probability to zero
    probs = []
    columns = list(loglikelihood.columns)
    for column in columns:
        prob = 0
        # Iterate for each word in word list
        for word in words:

            # check if the word exist in the loglikelihood dictionary
            if word in loglikelihood.index:
                prob += loglikelihood.loc[word, column]
        
        probs.append(prob)
        
    probs = logprior + probs
    y_hat = np.argmax(probs)
    
    return probs, y_hat

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    output:
        accuracy: (# of tweets classified correctly)/total # of tweets
    """
    # initial accuracy
    acc = 0
    
    # initialize an empty list for storing the predictions
    y_hats = []

    for tweet in test_x:
        
        _ , y = naive_bayes_predict(tweet, logprior, loglikelihood)
        
#         y_hat = np.argmax(probs)
        
        # update the y_hats
        y_hats.append(y)
        
#     Error: the mean absolute values between y_hats and test_y
    error = np.mean(np.abs(np.array(y_hats)-np.array(test_y)))
        
#     Accuracy is 1 - error
    acc = 1-error
    return acc

# %% [markdown]
# ## KFold CV

# %%
###############################################
# Training and Testing using the same Dataset #
###############################################

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), np.array(list(corpus.label))

# Build the freqs dictionary for later uses
freqs = count_docs({}, sentences, labels)

# Turn the frequencies dictionary into dataframe
freqs_df = freqs_to_df(freqs, labels)
print(freqs_df.head())

# Retrieve the logprior and loglikelihood
logprior, loglikelihood = train_naive_bayes(freqs_df, sentences, labels)
print(logprior)
print(loglikelihood.head())

print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(sentences, labels, logprior, loglikelihood)))
# Out:
#               0      1
# word
# smart      31.0   10.0
# alert       5.0    0.0
# thirteen    2.0    2.0
# convers     8.0    9.0
# one       409.0  375.0
# [-0.69314718 -0.69314718]
#                   0          1
# word
# smart     -7.737548  -8.869015
# alert     -9.411525 -11.266910
# thirteen -10.104672 -10.168298
# convers   -9.006059  -8.964325
# one       -5.187127  -5.337321
# Naive Bayes accuracy = 0.9524

# %%
#######################################################
# Training and Testing using 10-fold Cross Validation #
#######################################################

# prepare cross validation
kfold = KFold(10, True)

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)
# count = 0
acc_list = []
# kfold.split() will return set indices for each split
for train, test in kfold.split(sentences):
    train_x, train_y = [], []
    test_x, test_y = [], []
    for i in train:
        train_x.append(sentences[i])
        train_y.append(labels[i])
        
    for i in test:
        test_x.append(sentences[i])
        test_y.append(labels[i])
    
    train_y = np.array(train_y)
    test_y = np.array(test_y)
    
    # Build the freqs dictionary for later uses
    freqs = count_docs({}, train_x, train_y)

    # Turn the frequencies dictionary into dataframe
    freqs_df = freqs_to_df(freqs, train_y)
#     print(freqs_df.head())

    # Retrieve the logprior and loglikelihood
    logprior, loglikelihood = train_naive_bayes(freqs_df, train_x, train_y)
    print('loglikelihood:\n{}'.format(loglikelihood.head()))
    print('logprior: {}'.format(logprior))
    
    acc = test_naive_bayes(test_x, test_y, logprior, loglikelihood)
    print("Naive Bayes test accuracy = %0.4f\n" %(acc))
    
    acc_list.append(acc)

acc_list = np.array(acc_list)
print()
print('The test ccuracy for each training:\n{}'.format(acc_list))
print('The mean of the test accuracy: ', acc_list.mean())
# Out:
# C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass shuffle=True as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# loglikelihood:
#                   0          1
# word
# smart     -7.812783  -8.973126
# alert     -9.499182 -11.170351
# thirteen -10.415473 -10.071738
# convers   -9.029178  -8.973126
# one       -5.179031  -5.344351
# logprior: [-0.69336943 -0.69292498]
# Naive Bayes test accuracy = 0.9120
#
# loglikelihood:
#                   0          1
# word
# smart     -7.742896  -8.869243
# alert     -9.318432 -11.171829
# thirteen -10.011579 -10.073216
# convers   -9.318432  -9.092387
# one       -5.185936  -5.357698
# logprior: [-0.69159283 -0.69470395]
# Naive Bayes test accuracy = 0.9040
#
# loglikelihood:
#                   0          1
# word
# smart     -7.808037  -8.875399
# alert     -9.494436 -11.177984
# thirteen -10.005262 -10.079372
# convers   -8.906649  -8.980759
# one       -5.193077  -5.372849
# logprior: [-0.69894171 -0.68738603]
# Naive Bayes test accuracy = 0.9120
#
# loglikelihood:
#                   0          1
# word
# smart     -7.776100  -8.871014
# alert     -9.498867 -11.173599
# thirteen -10.009693 -10.074987
# convers   -9.028863  -9.094158
# one       -5.205672  -5.368464
# logprior: [-0.69492654 -0.69137098]
# Naive Bayes test accuracy = 0.9190
#
# loglikelihood:
#               0          1
# word
# color -7.501754  -8.606654
# music -7.123688  -7.458031
# bounc -9.726377 -11.171603
# warm  -8.222300  -9.379844
# sea   -8.627765  -8.227165
# logprior: [-0.69026246 -0.69604025]
# Naive Bayes test accuracy = 0.9140
#
# loglikelihood:
#                   0          1
# word
# smart     -7.855649  -8.870059
# alert     -9.321986 -11.172644
# thirteen -10.015133 -10.479497
# convers   -8.916521  -8.870059
# one       -5.194852  -5.326205
# logprior: [-0.69248074 -0.69381407]
# Naive Bayes test accuracy = 0.8960
#
# loglikelihood:
#                   0          1
# word
# smart     -7.674662  -8.777065
# alert     -9.316890 -11.174960
# thirteen -10.010037 -10.076348
# convers   -8.911425  -8.977736
# one       -5.211496  -5.322758
# logprior: [-0.6944814  -0.69181474]
# Naive Bayes test accuracy = 0.8940
#
# loglikelihood:
#                   0          1
# word
# smart     -7.745436  -8.867681
# alert     -9.320972 -11.170266
# thirteen -10.014119 -10.071654
# convers   -9.033290  -8.867681
# one       -5.191153  -5.335455
# logprior: [-0.68893385 -0.69737834]
# Naive Bayes test accuracy = 0.9080
#
# loglikelihood:
#                   0          1
# word
# smart     -7.712444  -8.872768
# alert     -9.504203 -11.175353
# thirteen -10.015029 -10.076740
# convers   -8.916417  -8.978128
# one       -5.235905  -5.358241
# logprior: [-0.69314718 -0.69314718]
# Naive Bayes test accuracy = 0.9120
#
# loglikelihood:
#                   0          1
# word
# smart     -7.645218  -8.976234
# alert     -9.319195 -11.173459
# thirteen -10.012342 -10.480312
# convers   -9.031513  -8.976234
# one       -5.208321  -5.359328
# logprior: [-0.69336943 -0.69292498]
# Naive Bayes test accuracy = 0.9050
#
#
# The test ccuracy for each training:
# [0.912 0.904 0.912 0.919 0.914 0.896 0.894 0.908 0.912 0.905]
# The mean of the test accuracy:  0.9076000000000001
