# %% [markdown]
# # Naive Bayes Classification with CR Dataset
# <hr>
#
# We will build a text classification model using Naive Bayes on the Customer Reviews Dataset. Since there is no standard train/test split for this dataset, we will use 10-Fold Cross Validation (CV).
#
# ## Load the library

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import random
from nltk.corpus import stopwords, twitter_samples
# from nltk.tokenize import TweetTokenizer
from sklearn.model_selection import KFold
from nltk.stem import PorterStemmer
from string import punctuation
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
import time

# %config IPCompleter.greedy=True
# %config IPCompleter.use_jedi=False
# nltk.download('twitter_samples')

# %% [markdown]
# ## Load the Dataset

# %%
corpus = pd.read_pickle('../0_data/CR/CR.pkl')
corpus.label = corpus.label.astype(int)
print(corpus.shape)
corpus
# Out:
# (3775, 3)
#                                                sentence  label  split
# 0     weaknesses are minor the feel and layout of th...      0  train
# 1     many of our disney movies do n 't play on this...      0  train
# 2     player has a problem with dual layer dvd 's su...      0  train
# 3     i know the saying is you get what you pay for ...      0  train
# 4                      will never purchase apex again .      0  train
# ...                                                 ...    ...    ...
# 3770  so far , the anti spam feature seems to be ver...      1  train
# 3771  i downloaded a trial version of computer assoc...      1  train
# 3772  i did not have any of the installation problem...      1  train
# 3773  their products have been great and have saved ...      1  train
# 3774                                                         1  train
#
# [3775 rows x 3 columns]

# %%
corpus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3775 entries, 0 to 3774
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  3775 non-null   object
#  1   label     3775 non-null   int32
#  2   split     3775 non-null   object
# dtypes: int32(1), object(2)
# memory usage: 73.9+ KB

# %%
corpus.groupby( by='label').count()
# Out:
#        sentence  split
# label
# 0          1368   1368
# 1          2407   2407

# %%
# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)

# %% [markdown]
# ## Raw Number of Vocabulary

# %%
# Build the raw vocobulary for first inspection
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
vocab_raw = tokenizer.word_index
print('\nThe vocabulary size: {}\n'.format(len(vocab_raw)))
print(vocab_raw)
# Out:
# The vocabulary size: 5334
#
# {'the': 1, 'and': 2, 'i': 3, 'it': 4, 'to': 5, 'a': 6, 'is': 7, 'of': 8, 'this': 9, 'with': 10, 'for': 11, 'you': 12, 'that': 13, 'in': 14, 'have': 15, 'but': 16, 'not': 17, 'on': 18, 'my': 19, "'t": 20, 'as': 21, "'s": 22, 'are': 23, 'very': 24, 'can': 25, 'was': 26, 'use': 27, 'camera': 28, 'player': 29, 'all': 30, 'has': 31, 'phone': 32, 'great': 33, 'one': 34, 'be': 35, 'so': 36, 'at': 37, 'if': 38, 'good': 39, 'easy': 40, 'quality': 41, 'or': 42, 'up': 43, 'from': 44, 'no': 45, 'like': 46, 'an': 47, 'than': 48, 'had': 49, 'just': 50, 'battery': 51, 'get': 52, 'about': 53, 'when': 54, 'software': 55, 'only': 56, 'your': 57, 'ipod': 58, 'would': 59, 'which': 60, 'well': 61, 'they': 62, 'also': 63, 'more': 64, 'sound': 65, 'there': 66, 'me': 67, 'n': 68, 'other': 69, 'do': 70, 'will': 71, 'out': 72, 'does': 73, 'any': 74, "'ve": 75, 'features': 76, 'its': 77, 'zen': 78, 'router': 79, 'even': 80, 'some': 81, 'really': 82, 'by': 83, 'better': 84, 'after': 85, 'work': 86, 'creative': 87, 'time': 88, 'price': 89, 'problems': 90, 'little': 91, 'much': 92, 'product': 93, '2': 94, 'pictures': 95, 'too': 96, 'best': 97, 'most': 98, 'problem': 99, 'been': 100, 'what': 101, 'am': 102, '1': 103, 'still': 104, 'small': 105, 'dvd': 106, 'because': 107, 'music': 108, "'m": 109, 'nice': 110, 'used': 111, 'screen': 112, 'did': 113, 'works': 114, 'excellent': 115, 'now': 116, 'first': 117, 'thing': 118, 'using': 119, '3': 120, 'play': 121, 'their': 122, 'we': 123, 'over': 124, 'diaper': 125, 'don': 126, 'while': 127, 'far': 128, 'love': 129, 'could': 130, 'buy': 131, 'many': 132, 'picture': 133, 'life': 134, 'find': 135, 'bit': 136, 'take': 137, 'micro': 138, 'size': 139, 'digital': 140, 'computer': 141, 'then': 142, '4': 143, 'files': 144, 'them': 145, 'hard': 146, 'need': 147, 'into': 148, 'songs': 149, 'got': 150, 'want': 151, 'mp3': 152, 'way': 153, 'without': 154, 'feature': 155, 'lot': 156, 'new': 157, 'two': 158, 'were': 159, 'cd': 160, 'support': 161, 'enough': 162, 'long': 163, 'off': 164, '5': 165, 'how': 166, 'easily': 167, 'people': 168, 'through': 169, 'few': 170, 'everything': 171, 'takes': 172, 'make': 173, 'pretty': 174, 'since': 175, 'seems': 176, 'overall': 177, 'comes': 178, 'case': 179, 'champ': 180, 'nokia': 181, 'read': 182, 'say': 183, 'think': 184, 'interface': 185, 'big': 186, 'before': 187, 'service': 188, 'button': 189, 'speed': 190, 'light': 191, 'norton': 192, 'never': 193, 'looking': 194, 'go': 195, 'quite': 196, 'down': 197, 'manual': 198, 'another': 199, 'getting': 200, 'recommend': 201, 'mode': 202, 'made': 203, 'fast': 204, 'zoom': 205, 'apex': 206, 'video': 207, 'times': 208, 'fine': 209, 'however': 210, 'canon': 211, 'design': 212, 'user': 213, 'right': 214, 'buttons': 215, 'found': 216, 'hours': 217, 'tried': 218, 'unit': 219, 'back': 220, 'less': 221, 'see': 222, 'though': 223, 'controls': 224, 'nomad': 225, 'ever': 226, 'etc': 227, 'bought': 228, 'same': 229, 'scroll': 230, 't': 231, 'device': 232, 'radio': 233, 'perfect': 234, 'happy': 235, 'every': 236, 'anything': 237, 'working': 238, 'looks': 239, 'fact': 240, 'system': 241, 'give': 242, 'fm': 243, 'control': 244, 'who': 245, 'look': 246, 'windows': 247, 'included': 248, 'pc': 249, 'doesn': 250, 'should': 251, 'something': 252, 'touch': 253, "'": 254, 'program': 255, 'simple': 256, 'cool': 257, 'bags': 258, 'players': 259, 'able': 260, "'re": 261, 'although': 262, 'those': 263, 'day': 264, 'audio': 265, 'lcd': 266, 'pocket': 267, 'having': 268, 'put': 269, 'awesome': 270, 'power': 271, 'money': 272, 'set': 273, 'g3': 274, 'once': 275, 'internet': 276, 'know': 277, 'keep': 278, 'worked': 279, 'start': 280, 'card': 281, 'high': 282, 'around': 283, 'purchase': 284, 'again': 285, 'customer': 286, 'always': 287, 'months': 288, 'being': 289, 'free': 290, 'makes': 291, 'usb': 292, 'drive': 293, 'wireless': 294, 'bluetooth': 295, 'such': 296, 'almost': 297, 'especially': 298, 'month': 299, 'come': 300, 'lens': 301, 'photos': 302, 'memory': 303, 'things': 30 ...

# %% [markdown]
# <!--## Split Dataset-->

# %% [markdown]
# # Data Preprocessing
# <hr>

# %% [markdown]
# ## Define `clean_doc` function

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stemmer = PorterStemmer()
    
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # remove remaining tokens that are not alphabetic
#     tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    tokens = [w for w in tokens if not w in stopwords]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) >= 1]
    # Stem the token
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

# %% [markdown]
# ## Define `count_docs` function

# %%
def count_docs(data, docs, ys):
    '''
    Input:
        data: a dictionary that will be used to map each pair to its frequency
        docs: a list of sentences
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''
    onehot = OneHotEncoder( sparse=False)
    y_onehot = onehot.fit_transform(np.reshape(ys, (-1,1)))
    # print(y_onehot)
    count = 0                    
    for doc, y in zip(docs, y_onehot):
        # For each word
        for word in clean_doc(doc):
            # if not in the data yet
            if word not in data:
                # assign it
                data[word] = y
            # if already in the data 
            else:
                # update it
                data[word] = data.get(word) + y

    return data

# %% [markdown]
# ## Build Frequencies Dictionary

# %%
# Build the freqs dictionary for later uses
freqs = count_docs({}, sentences, labels)
freqs
# Out:
# {'weak': array([10.,  2.]),
#  'minor': array([8., 1.]),
#  'feel': array([19., 29.]),
#  'layout': array([3., 2.]),
#  'remot': array([17., 13.]),
#  'control': array([34., 50.]),
#  'n': array([83., 61.]),
#  'show': array([8., 8.]),
#  'complet': array([16.,  3.]),
#  'file': array([36., 53.]),
#  'name': array([9., 4.]),
#  'mp3': array([14., 59.]),
#  'realli': array([34., 85.]),
#  'long': array([25., 31.]),
#  'must': array([13., 13.]),
#  'cycl': array([2., 1.]),
#  'everi': array([22., 18.]),
#  'zoom': array([17., 34.]),
#  'set': array([25., 62.]),
#  '2x': array([2., 1.]),
#  '3x': array([2., 6.]),
#  '4x': array([1., 5.]),
#  '1': array([46., 47.]),
#  'etc': array([ 9., 33.]),
#  'get': array([126., 117.]),
#  'back': array([25., 21.]),
#  'normal': array([ 9., 12.]),
#  'size': array([18., 58.]),
#  'sorri': array([1., 1.]),
#  'ignor': array([2., 0.]),
#  'way': array([35., 33.]),
#  '1x': array([1., 0.]),
#  'quickli': array([ 7., 13.]),
#  'mani': array([27., 43.]),
#  'disney': array([2., 0.]),
#  'movi': array([13., 13.]),
#  'play': array([59., 83.]),
#  'dvd': array([57., 56.]),
#  'player': array([116., 215.]),
#  'problem': array([110.,  92.]),
#  'dual': array([1., 2.]),
#  'layer': array([2., 1.]),
#  'alia': array([2., 0.]),
#  'season': array([3., 0.]),
#  '2': array([46., 56.]),
#  'know': array([20., 23.]),
#  'say': array([20., 40.]),
#  'pay': array([6., 9.]),
#  'stage': array([1., 0.]),
#  'game': array([12., 17.]),
#  'better': array([25., 86.]),
#  'qualiti': array([ 39., 179.]),
#  'excus': array([1., 0.]),
#  'never': array([20., 29.]),
#  'purchas': array([22., 47.]),
#  'apex': array([28., 18.]),
#  'custom': array([32., 10.]),
#  'servic': array([38., 23.]),
#  'technic': array([4., 1.]),
#  'support': array([43., 26.]),
#  'overload': array([2., 0.]),
#  'non': array([6., 6.]),
#  'respons': array([3., 6.]),
#  'tell': array([15.,  9.]),
#  'product': array([64., 66.]),
#  'willing': array([1., 0.]),
#  'stand': array([ 3., 12.]),
#  'behind': array([2., 2.]),
#  'would': array([98., 62.]),
#  'stop': array([16.,  5.]),
#  'middl': array([3., 1.]),
#  'even': array([47., 77.]),
#  'read': array([33., 31.]),
#  'new': array([28., 31.]),
#  'cd': array([25., 49.]),
#  'almost': array([10., 22.]),
#  'alway': array([19., 14.]),
#  'began': array([1., 1.]),
#  'skip': array([5., 3.]),
#  'thought': array([ 8., 15.]),
#  'start': array([30., 23.]),
#  'check': array([5., 8.]),
#  'disc': array([22.,  9.]),
#  'find': array([34., 41.]),
#  '2600': array([6., 5.]),
#  'actual': array([11., 27.]),
#  'ruin': array([2., 1.]),
#  'media': array([ 4., 15.]),
#  'worth': array([ 6., 17.]),
#  'price': array([ 11., 105.]),
#  'recommend': array([ 5., 47.]),
#  'answer': array([11.,  2.]),
#  'phone': array([ 76., 236.]),
#  'contact': array([7., 5.]),
#  'bad': array([20., 11.]),
#  'everyth': array([11., 42.]),
#  '3': array([38., 42.]),
#  'die': array([8., 2.]),
#  'shortli': array([3., 0.]),
#  'nice': array([14., 82.]),
#  'machin': array([ 7., 18.]),
#  'consid': array([ 8., 13.]),
#  'pretti': array([15., 37.]),
#  'low': array([14., 15.]),
#  'item': array([4., 8.]),
#  'broke': array([5., 1.]),
#  'two': array([25., 34.]),
#  'week': array([25., 24.]),
#  'gave': array([11.,  5.]),
#  'kid': array([2., 1.]),
#  'christma': array([7., 8.]),
#  'door': array([6., 1.]),
#  'close': array([16.,  9.]),
#  'tri': array([52., 25.]),
#  'return': array([5., 4.]),
#  'miss': array([9., 4.]),
#  'amazon': array([ 5., 21.]),
#  'period': array([7., 4.]),
#  'took': array([17., 12.]),
#  'month': array([40., 25.]),
#  'dept': array([2., 0.]),
#  'unfortun': array([15.,  1.]),
#  'turn': array([20., 26.]),
#  'dispos': array([2., 6.]),
#  'type': array([5., 6.]),
#  'sinc': array([23., 29.]),
#  'first': array([41., 45.]),
#  'day': array([38., 27.]),
#  'final': array([16.,  8.]),
#  'less': array([18., 25.]),
#  '60': array([2., 4.]),
#  'recogn': array([14.,  1.]),
#  'anyth': array([21., 19.]),
#  'pop': array([13., 11.]),
#  'tend': array([6., 1.]),
#  'run': array([15., 32.]),
#  'quit': array([18., 33.]),
#  'hot': array([8., 3.]),
#  'given': array([8., 9.]),
#  'lot': array([25., 53.]),
#  'room': array([ 5., 12.]),
#  'air': array([2., 0.]),
#  'circul': array([1., 0.]),
#  'also': array([55., 95.]),
#  'seem': array([41., 44.]),
#  'strong': array([3., 7.]),
#  'electron': array([2., 6.]),
#  'smell': array([11., 16.]),
#  'time': array([85., 70.]),
#  'thing': array([52., 63.]),
#  'experi': array([13., 10.]),
#  'freez': array([19.,  0.]),
#  'abl': array([12., 25.]),
#  'clear': array([ 7., 24.]),
#  'open': array([19., 19.]),
#  'blow': array([1., 5.]),
#  'can': array([1., 0.]),
#  'okay': array([2., 2.]),
#  'fan': array([1., 2.]),
#  'tini': array([ 7., 12.]),
#  'button': array([63., 32.]),
#  'especi': array([14., 18.]),
#  'like': array([ 74., 140.]),
#  'commonli': array([1., 0.]),
#  'use': array([148., 367.]),
#  'paus': array([4., 1.]),
#  'larger': array([10.,  9.]),
#  'conveni': array([ 5., 13.]),
#  'place': array([8., 9.]),
#  'display': array([19., 14.]),
#  'inform': array([7., 3.]),
#  'screen': array([32., 56.]),
#  'mode': array([11., 49.]),
#  'goe': array([5., 6.]),
#  'magnif': array([1., 0.]),
#  'one': array([126., 171.]),
#  'quarter': array([1., 0.]),
#  'top': array([12., 12.]),
#  'interfer': array([2., 0.]),
#  'view': array([7., 8.]),
#  'spent': array([4., 3.]),
#  'consider': array([1., 3.]),
#  'profession': array([3., 3.]),
#  'video': array([19., 31.]),
#  'gear': array([1., 0.]),
#  'onscreen': array([1., 1.]),
#  'annoy': array([19.,  2.]),
#  '90': array([5., 4.]),
#  'pictur': array([ 40., 131.]),
#  'matter': array([8., 4.]),
#  'see': array([18., 25.]),
#  'total': array([7., 6.]),
#  '6': array([13., 13.]),
#  'frustrat': array([11.,  1.]),
#  'aggrav': array([1., 0.]),
#  'job': array([ 7., 11.]),
#  'hold': array([15., 29.]),
#  'email': array([11.,  7.]),
#  'telephon': array([4., 1.]),
#  'number': array([24., 12.]),
#  'constantli': array([7., 1.]),
#  'busi': array([9., 4.]),
#  'believ': array([ 5., 11.]),
#  'lone': array([1., 0.]),
#  'rep': array([4., 1.]),
#  'probabl': array([12., 11.]),
#  'extrem': array([ 5., 19.]),
#  'overwork': array([1., 0.]),
#  'wo': array([10.,  4.]),
#  'yesterday': array([2., 2.]),
#  'today': array([4., 4.]),
#  '80': array([2., 1.]),
#  'store': array([ 9., 25.]),
#  'bough': array([1., 0.]),
#  'ten': array([3., 1.]),
#  'tech': array([13., 12.]),
#  'liter': array([3., 3.]),
#  'nonexist': array([1., 0.]),
#  'bought': array([10., 32.]),
#  'model': array([ 8., 14.]),
#  'present': array([4., 3.]),
#  'neither': array([7., 0.]),
#  'work': array([111., 158.]),
#  'embarass': array([2., 0.]),
#  'call': array([26., 17.]),
#  'famili': array([5., 2.]),
#  'member': array([1., 0.]),
#  'ago': array([ 4., 10.]),
#  'longer': array([5., 8.]),
#  'properli': array([9., 2.]),
#  'usual': array([ 3., 10.]),
#  'occasion': array([12.,  0.]),
#  'particular': array([2., 1.]),
#  'point': array([10., 23.]),
#  'access': array([11., 19.]),
#  'certain': array([7., 2.]),
#  'special': array([ 1., 14.]),
#  'featur': array([ 33., 163.]),
#  'rental': array([1., 1.]),
#  'happen': array([4., 1.]),
#  'sever': array([12.,  9.]),
#  'differ': array([10., 23.]),
#  'keep': array([19., 25.]),
#  'someth': array([19., 20.]),
#  'discov': array([3., 5.]),
#  'flor': array([1., 0.]),
#  'got': array([26., 37.]),
#  'touch': array([17., 24.]),
#  'web': array([5., 8.]),
#  'far': array([13., 60.]),
#  'refus': array([4., 1.]),
#  'episod': array([1., 0.]),
#  'other': array([ 6., 11.]),
#  'ps2': array([1., 0.]),
#  'could': array([29., 43.]),
#  'went': array([9., 7.]),
#  'sound': array([ 33., 133.]),
#  'hate': array([4., 3.]),
#  'love': array([ 3., 80.]),
#  'everyon': array([4., 5.]),
#  'crap': array([7., 0.]),
#  'univers': array([3., 2.]),
#  'claim': array([3., 2.]),
#  'none': array([5., 6.]),
#  'cours': array([5., 8.]),
#  'coupl': array([8., 5.]),
#  'appear': array([7., 8.]),
#  'defect': array([9., 0.]),
#  'list': array([ 9., 11.]),
#  'toll': array([2., 0.]),
#  'free': array([ 8., 25.]),
#  'real': array([ 7., 14.]),
#  'hassl': array([4., 5.]),
#  'regular': array([ 4., 17.]),
#  'line': array([13., 17.]),
#  'inclin': array([1., 0.]),
#  'unit': array([18., 27.]),
#  'forev': array([3., 1.]),
#  'begin': array([5., 3.]),
#  'higher': array([3., 5.]),
#  'scene': array([1., 9.]),
#  'engin': array([5., 0.]),
#  'embarrass': array([1., 0.]),
#  'profess': array([1., 0.]),
#  'releas': array([4., 4.]),
#  'sale': array([1., 2.]),
#  'send': array([8., 5.]),
#  'discontinu': array([1., 0.]),
#  'signal': array([ 6., 18.]),
#  'tv': array([4., 6.]),
#  'moment': array([8., 2.]),
#  'white': array([ 4., 14.]),
#  'nois': array([ 4., 11.]),
#  'make': array([34., 64.]),
#  'color': array([ 8., 38.]),
#  'look': array([ 28., 111.]),
#  'satur': array([1., 0.]),
#  'entir': array([2., 5.]),
#  'poorli': array([7., 0.]),
#  'craft': array([1., 1.]),
#  'sharp': array([ 3., 12.]),
#  'screw': array([5., 0.]),
#  'tip': array([2., 2.]),
#  'undersid': array([1., 0.]),
#  'come': array([38., 51.]),
#  'insid': array([ 7., 11.]),
#  'obvious': array([3., 1.]),
#  'anchor': array([1., 0.]),
#  'intern': array([2., 2.]),
#  'board': array([4., 0.]),
#  'hook': array([4., 6.]),
#  'found': array([18., 27.]),
#  '50': array([6., 6.]),
#  'put': array([16., 23.]),
#  'spin': array([3., 2.]),
#  'alreadi': array([ 9., 15.]),
#  'disappoint': array([28.,  8.]),
#  'respond': array([8., 0.]),
#  'promis': array([5., 2.]),
#  'turnaround': array([1., 0.]),
#  '24': array([5., 1.]),
#  'hour': array([29., 25.]),
#  'piec': array([ 6., 11.]),
#  'junk': array([5., 3.]),
#  'later': array([4., 0.]),
#  'eventu': array([4., 2.]),
#  'stori': array([1., 0.]),
#  'everybodi': array([1., 1.]),
#  'els': array([ 7., 13.]),
#  'noth': array([9., 8.]),
#  'fine': array([14., 32.]),
#  '1st': array([4., 1.]),
#  'half': array([9., 3.]),
#  'disappear': array([1., 2.]),
#  'still': array([36., 57.]),
#  'describ': array([1., 2.]),
#  'basic': array([ 7., 11.]),
#  'cu': array([1., 0.]),
#  'st': array([1., 0.]),
#  'help': array([17., 19.]),
#  'mine': array([ 9., 16.]),
#  'old': array([10., 18.]),
#  'chuck': array([3., 0.]),
#  'trash': array([ 4., 14.]),
#  'belong': array([1., 0.]),
#  '4': array([27., 39.]),
#  'last': array([22., 22.]),
#  'six': array([2., 1.]),
#  'sent': array([6., 2.]),
#  'ad2600': array([1., 1.]),
#  'messag': array([9., 3.]),
#  'though': array([21., 22.]),
#  'bit': array([50., 31.]),
#  'flimsi': array([7., 3.]),
#  'predict': array([1., 1.]),
#  'gift': array([4., 3.]),
#  'second': array([29., 20.]),
#  'digit': array([ 9., 58.]),
#  'site': array([13.,  7.]),
#  '25': array([2., 3.]),
#  'watch': array([2., 4.]),
#  'kick': array([1., 3.]),
#  'rate': array([11., 11.]),
#  'five': array([5., 5.]),
#  'star': array([19., 20.]),
#  'poor': array([9., 0.]),
#  'manual': array([20., 38.]),
#  '12': array([ 6., 10.]),
#  '26': array([1., 2.]),
#  '9': array([4., 2.]),
#  'fail': array([9., 3.]),
#  'neg': array([8., 4.]),
#  'review': array([25., 32.]),
#  'ask': array([8., 5.]),
#  'repli': array([3., 0.]),
#  'wait': array([10.,  6.]),
#  '27': array([3., 0.]),
#  '10': array([13., 15.]),
#  'otherwis': array([7., 6.]),
#  'clean': array([ 7., 10.]),
#  'friend': array([ 3., 13.]),
#  'gripe': array([3., 0.]),
#  'incred': array([ 1., 16.]),
#  'crappi': array([2., 0.]),
#  'wors': array([5., 1.]),
#  'cheaper': array([1., 9.]),
#  'press': array([17.,  1.]),
#  'hard': array([35., 30.]),
#  'frequent': array([3., 2.]),
#  'end': array([ 7., 14.]),
#  'enter': array([3., 1.]),
#  'meant': array([2., 1.]),
#  'scroll': array([30., 14.]),
#  'reason': array([13., 18.]),
#  'wash': array([2., 2.]),
#  'bleed': array([2., 0.]),
#  'compar': array([ 7., 22.]),
#  'compon': array([5., 3.]),
#  'connect': array([24., 34.]),
#  'much': array([36., 68.]),
#  'percept': array([1., 0.]),
#  'cheap': array([ 9., 16.]),
#  'ch': array([2., 0.]),
#  'easi': array([ 23., 194.]),
#  'sure': array([13., 17.]),
#  'buck': array([4., 8.]),
#  'heck': array([2., 0.]),
#  'dirti': array([4., 9.]),
#  'ice': array([1., 2.]),
#  'age': array([2., 0.]),
#  'e': array([9., 9.]),
#  'mail': array([6., 3.]),
#  'undeliver': array([1., 0.]),
#  'leav': array([10.,  6.]),
#  'question': array([4., 3.]),
#  'attempt': array([4., 0.]),
#  'multitud': array([1., 0.]),
#  'method': array([2., 0.]),
#  'ad': array([6., 9.]),
#  'numer': array([4., 3.]),
#  'recent': array([6., 9.]),
#  'yet': array([ 5., 25.]),
#  'without': array([20., 41.]),
#  'depart': array([1., 3.]),
#  'request': array([1., 0.]),
#  'ra': array([1., 0.]),
#  'disk': array([7., 6.]),
#  'natur': array([4., 7.]),
#  '31': array([1., 0.]),
#  'froze': array([2., 0.]),
#  'load': array([17., 15.]),
#  'via': array([10., 11.]),
#  'customerservic': array([1., 0.]),
#  'apexdigit': array([1., 0.]),
#  'com': array([ 5., 11.]),
#  'address': array([5., 2.]),
#  'valid': array([1., 0.]),
#  '866': array([1., 1.]),
#  '4apexgo': array([1., 0.]),
#  'suck': array([14.,  0.]),
#  'hear': array([8., 3.]),
#  'www': array([1., 4.]),
#  'inc': array([2., 0.]),
#  'receiv': array([ 6., 15.]),
#  'kept': array([9., 3.]),
#  'rent': array([1., 1.]),
#  'great': array([ 17., 263.]),
#  'girlfriend': array([1., 0.]),
#  'somewhat': array([12.,  4.]),
#  'fact': array([13., 27.]),
#  'exampl': array([5., 4.]),
#  'pirat': array([1., 0.]),
#  'caribbean': array([1., 0.]),
#  'extra': array([ 8., 21.]),
#  'isol': array([1., 0.]),
#  'incid': array([2., 0.]),
#  'proven': array([1., 4.]),
#  'wrong': array([10.,  6.]),
#  'well': array([ 34., 122.]),
#  'output': array([5., 4.]),
#  'catch': array([4., 1.]),
#  'occas': array([4., 1.]),
#  'littl': array([54., 52.]),
#  'understand': array([ 4., 12.]),
#  'jpeg': array([2., 6.]),
#  'viewabl': array([1., 0.]),
#  'vivid': array([1., 1.]),
#  '17': array([2., 0.]),
#  'monitor': array([1., 1.]),
#  'awesom': array([ 1., 34.]),
#  'lip': array([2., 0.]),
#  'sync': array([ 4., 15.]),
#  'issu': array([19., 13.]),
#  'move': array([6., 9.]),
#  'dialog': array([1., 0.]),
#  'black': array([6., 8.]),
#  'composit': array([1., 0.]),
#  'v': array([1., 0.]),
#  'p': array([2., 1.]),
#  'confus': array([5., 4.]),
#  'doesnt': array([4., 2.]),
#  'may': array([14.,  8.]),
#  'oper': array([13., 24.]),
#  'error': array([9., 0.]),
#  'hell': array([4., 1.]),
#  'forget': array([2., 3.]),
#  'sleek': array([ 1., 17.]),
#  'within': array([7., 8.]),
#  '45': array([3., 0.]),
#  'rca': array([1., 1.]),
#  'optic': array([ 5., 17.]),
#  'instal': array([51., 38.]),
#  'devast': array([1., 0.]),
#  'least': array([10., 11.]),
#  'updat': array([12., 15.]),
#  'januari': array([1., 0.]),
#  '27th': array([1., 0.]),
#  '2004': array([16.,  6.]),
#  'dont': array([7., 8.]),
#  'buy': array([32., 54.]),
#  'immedi': array([4., 1.]),
#  'favorit': array([ 2., 12.]),
#  'multipl': array([4., 6.]),
#  'avail': array([ 6., 13.]),
#  'success': array([3., 4.]),
#  'broken': array([7., 1.]),
#  'motor': array([2., 3.]),
#  'eject': array([1., 0.]),
#  'brother': array([1., 1.]),
#  'hous': array([ 3., 11.]),
#  'either': array([17.,  8.]),
#  'imagin': array([5., 4.]),
#  'shock': array([2., 1.]),
#  'absolut': array([ 5., 17.]),
#  'instant': array([2., 5.]),
#  'disdain': array([1., 0.]),
#  'made': array([19., 28.]),
#  '2nd': array([2., 1.]),
#  'faulti': array([2., 0.]),
#  'power': array([12., 39.]),
#  'suppli': array([3., 7.]),
#  'caus': array([10.,  1.]),
#  '1600': array([1., 0.]),
#  'correctli': array([4., 2.]),
#  '1220': array([1., 0.]),
#  'act': array([1., 2.]),
#  'front': array([10.,  7.]),
#  'align': array([1., 0.]),
#  'life': array([23., 47.]),
#  'slightli': array([6., 6.]),
#  'ah': array([1., 0.]),
#  'wile': array([1., 1.]),
#  'memo': array([1., 1.]),
#  'chapter': array([3., 0.]),
#  '28': array([1., 1.]),
#  'frame': array([2., 0.]),
#  'good': array([ 29., 199.]),
#  'own': array([ 1., 18.]),
#  'expect': array([16., 15.]),
#  'anoth': array([21., 27.]),
#  'progress': array([1., 5.]),
#  'scan': array([6., 6.]),
#  'soon': array([1., 3.]),
#  'yell': array([1., 0.]),
#  'dad': array([1., 1.]),
#  'quick': array([ 4., 25.]),
#  'left': array([10.,  3.]),
#  'think': array([24., 31.]),
#  '5': array([20., 35.]),
#  'post': array([2., 2.]),
#  'somewher': array([1., 0.]),
#  'code': array([1., 1.]),
#  'useless': array([14.,  0.]),
#  'websit': array([7., 4.]),
#  'slow': array([23.,  9.]),
#  'identifi': array([1., 0.]),
#  'insert': array([2., 2.]),
#  'mayb': array([11.,  3.]),
#  'produc': array([ 3., 12.]),
#  'audio': array([ 9., 27.]),
#  'deal': array([13., 18.]),
#  'pp': array([1., 0.]),
#  'music': array([28., 62.]),
#  'take': array([53., 89.]),
#  'conclud': array([1., 0.]),
#  'grant': array([1., 0.]),
#  'mom': array([1., 1.]),
#  'enough': array([20., 37.]),
#  'allow': array([ 8., 28.]),
#  'menu': array([23., 26.]),
#  'lame': array([1., 0.]),
#  'awkward': array([8., 2.]),
#  'addit': array([6., 6.]),
#  'feet': array([2., 5.]),
#  'away': array([12.,  9.]),
#  'although': array([16., 21.]),
#  'batteri': array([ 64., 136.]),
#  'came': array([11., 11.]),
#  'huge': array([ 5., 11.]),
#  'parent': array([2., 3.]),
#  'three': array([4., 7.]),
#  'afflict': array([1., 0.]),
#  'glitch': array([6., 2.]),
#  'repeatedli': array([3., 1.]),
#  'playback': array([1., 5.]),
#  'counter': array([1., 1.]),
#  'go': array([31., 46.]),
#  'exhibit': array([1., 0.]),
#  'speed': array([14., 42.]),
#  'scratch': array([15.,  4.]),
#  'save': array([ 4., 10.]),
#  'money': array([ 7., 28.]),
#  'result': array([ 7., 12.]),
#  'shell': array([1., 2.]),
#  'nicer': array([3., 0.]),
#  'vcr': array([1., 0.]),
#  'combo': array([1., 1.]),
#  'blaze': array([1., 0.]),
#  'creepi': array([1., 0.]),
#  'impress': array([ 3., 28.]),
#  'inexpens': array([1., 2.]),
#  'quirk': array([1., 0.]),
#  'tray': array([1., 0.]),
#  'perv': array([1., 0.]),
#  'automat': array([11., 17.]),
#  'extern': array([4., 8.]),
#  'small': array([25., 68.]),
#  'fade': array([1., 0.]),
#  'signific': array([3., 1.]),
#  'distanc': array([4., 1.]),
#  '34': array([2., 0.]),
#  'navig': array([17., 24.]),
#  'past': array([10.,  3.]),
#  'built': array([11., 17.]),
#  'region': array([1., 2.]),
#  'damag': array([6., 2.]),
#  'ring': array([7., 8.]),
#  'build': array([4., 6.]),
#  'base': array([ 6., 12.]),
#  'plate': array([4., 3.]),
#  'soni': array([ 6., 11.]),
#  'overal': array([ 8., 44.]),
#  'plastic': array([9., 7.]),
#  'space': array([ 5., 15.]),
#  'howev': array([26., 20.]),
#  'deliv': array([2., 6.]),
#  'difficulti': array([2., 1.]),
#  'troubl': array([6., 5.]),
#  'consum': array([3., 1.]),
#  'report': array([2., 1.]),
#  'reliabl': array([3., 7.]),
#  'brand': array([2., 7.]),
#  'homework': array([1., 0.]),
#  'fals': array([1., 0.]),
#  'silver': array([2., 5.]),
#  'instead': array([ 6., 11.]),
#  'window': array([23., 25.]),
#  'dix': array([1., 0.]),
#  'rip': array([ 8., 16.]),
#  'whether': array([6., 4.]),
#  'rec': array([1., 0.]),
#  'rw': array([1., 4.]),
#  'vcd': array([1., 4.]),
#  'main': array([11.,  5.]),
#  'dial': array([16.,  3.]),
#  'backlit': array([1., 4.]),
#  'len': array([24.,  9.]),
#  'visibl': array([5., 4.]),
#  'viewfind': array([15.,  2.]),
#  'wide': array([2., 7.]),
#  'angl': array([2., 1.]),
#  'lcd': array([16., 20.]),
#  'bother': array([4., 6.]),
#  'four': array([4., 2.]),
#  'darn': array([1., 3.]),
#  'diopter': array([2., 0.]),
#  'adjust': array([20., 22.]),
#  'accur': array([5., 5.]),
#  'focu': array([ 8., 12.]),
#  'eyesight': array([1., 0.]),
#  'bulki': array([4., 1.]),
#  'minolta': array([1., 0.]),
#  'vector': array([1., 0.]),
#  'ap': array([1., 1.]),
#  'slr': array([3., 9.]),
#  'heavi': array([4., 9.]),
#  'solid': array([ 6., 14.]),
#  'contract': array([2., 0.]),
#  'mostli': array([2., 5.]),
#  'unlik': array([ 2., 12.]),
#  'canon': array([ 6., 40.]),
#  'elph': array([1., 7.]),
#  'ergonom': array([3., 3.]),
#  'shoot': array([ 6., 18.]),
#  'border': array([1., 0.]),
#  'ski': array([1., 1.]),
#  'camera': array([ 61., 267.]),
#  'cap': array([4., 3.]),
#  'snug': array([1., 0.]),
#  'easili': array([18., 36.]),
#  'partial': array([3., 1.]),
#  'obstruct': array([3., 0.]),
#  'drawback': array([5., 1.]),
#  'block': array([5., 0.]),
#  'b': array([2., 3.]),
#  'cover': array([15., 12.]),
#  'loos': array([3., 2.]),
#  'accid': array([2., 3.]),
#  'finger': array([9., 4.]),
#  'print': array([ 4., 13.]),
#  'au': array([1., 0.]),
#  'ti': array([1., 0.]),
#  'gt': array([1., 0.]),
#  'potenti': array([4., 1.]),
#  'lever': array([2., 0.]),
#  'shaki': array([1., 0.]),
#  'hope': array([6., 3.]),
#  'mechan': array([5., 1.]),
#  'uneasi': array([1., 0.]),
#  'lack': array([12.,  4.]),
#  'shot': array([10., 21.]),
#  'sold': array([2., 3.]),
#  'expens': array([ 6., 12.]),
#  'girl': array([1., 0.]),
#  'basketbal': array([1., 0.]),
#  'wan': array([1., 0.]),
#  'task': array([2., 2.]),
#  'light': array([11., 45.]),
#  'situat': array([4., 6.]),
#  'combin': array([ 3., 10.]),
#  'sort': array([8., 5.]),
#  'action': array([4., 2.]),
#  'dust': array([2., 0.]),
#  'grain': array([1., 1.]),
#  'terribl': array([11.,  2.]),
#  'flash': array([14., 21.]),
#  'photo': array([ 8., 45.]),
#  'limit': array([7., 6.]),
#  'knew': array([3., 2.]),
#  'lag': array([3., 1.]),
#  'lock': array([16., 11.]),
#  'bright': array([ 1., 15.]),
#  'unsatisfactori': array([1., 0.]),
#  'rel': array([3., 8.]),
#  'achiev': array([2., 3.]),
#  'nikon': array([ 3., 17.]),
#  'g3': array([ 8., 27.]),
#  'harsh': array([1., 0.]),
#  'flat': array([4., 4.]),
#  'imag': array([14., 30.]),
#  'ugli': array([3., 3.]),
#  'spot': array([1., 2.]),
#  'complaint': array([17.,  9.]),
#  'softwar': array([80., 92.]),
#  'process': array([17.,  8.]),
#  'raw': array([7., 5.]),
#  'replac': array([18., 31.]),
#  '32': array([1., 1.]),
#  'mbyte': array([2., 0.]),
#  'cf': array([2., 1.]),
#  '512': array([1., 2.]),
#  'give': array([22., 50.]),
#  '130': array([1., 1.]),
#  'oppos': array([1., 1.]),
#  '7': array([4., 9.]),
#  'affect': array([4., 0.]),
#  'fantasi': array([1., 0.]),
#  'world': array([1., 7.]),
#  'design': array([24., 37.]),
#  'pleas': array([ 1., 33.]),
#  'uncrit': array([1., 0.]),
#  'legitim': array([1., 0.]),
#  'critic': array([2., 1.]),
#  'onlin': array([8., 7.]),
#  'focus': array([4., 6.]),
#  'shutter': array([ 6., 10.]),
#  'blurri': array([2., 2.]),
#  'perhap': array([3., 8.]),
#  'unrespons': array([2., 0.]),
#  'preciou': array([1., 0.]),
#  'sometim': array([20.,  1.]),
#  'indefinit': array([1., 1.]),
#  'consist': array([2., 4.]),
#  'unbear': array([1., 0.]),
#  'captur': array([4., 6.]),
#  'devic': array([19., 31.]),
#  'want': array([24., 62.]),
#  'includ': array([21., 36.]),
#  'bodi': array([3., 3.]),
#  'construct': array([11.,  6.]),
#  'case': array([29., 29.]),
#  'heavier': array([3., 1.]),
#  'sturdi': array([1., 7.]),
#  'flaw': array([18.,  3.]),
#  'detract': array([3., 0.]),
#  'barrel': array([3., 0.]),
#  'finder': array([1., 2.]),
#  'hand': array([10., 35.]),
#  'tiff': array([1., 0.]),
#  'format': array([ 9., 16.]),
#  'meter': array([1., 3.]),
#  'piti': array([1., 0.]),
#  '32mb': array([1., 1.]),
#  'compactflash': array([2., 0.]),
#  'card': array([14., 24.]),
#  'purpos': array([4., 1.]),
#  'memori': array([12., 21.]),
#  'fragil': array([4., 1.]),
#  'bag': array([13., 49.]),
#  'carri': array([ 8., 15.]),
#  'round': array([2., 3.]),
#  'handbag': array([1., 0.]),
#  'pocket': array([ 5., 34.]),
#  'function': array([22., 25.]),
#  'switch': array([ 3., 11.]),
#  'illumin': array([1., 1.]),
#  'subject': array([4., 3.]),
#  'depth': array([5., 8.]),
#  'lost': array([1., 1.]),
#  'strap': array([5., 1.]),
#  'horribl': array([3., 2.]),
#  'part': array([7., 7.]),
#  'need': array([38., 59.]),
#  'ye': array([9., 6.]),
#  'corner': array([4., 2.]),
#  'distort': array([5., 2.]),
#  'harm': array([1., 0.]),
#  'done': array([9., 3.]),
#  'cam': array([1., 0.]),
#  'ea': array([1., 0.]),
#  'exactli': array([4., 4.]),
#  'minim': array([2., 2.]),
#  'parallax': array([1., 0.]),
#  'phenomenon': array([1., 0.]),
#  'lamest': array([1., 0.]),
#  'ot': array([1., 1.]),
#  'previou': array([5., 6.]),
#  'lower': array([7., 4.]),
#  'rather': array([9., 8.]),
#  'stun': array([1., 3.]),
#  'rare': array([4., 4.]),
#  'major': array([13.,  6.]),
#  'bottom': array([ 2., 10.]),
#  '15': array([2., 6.]),
#  'blown': array([1., 0.]),
#  'highlight': array([1., 1.]),
#  's330': array([2., 1.]),
#  'depress': array([3., 0.]),
#  'gener': array([ 7., 11.]),
#  'stainless': array([1., 0.]),
#  'steel': array([2., 0.]),
#  'heft': array([1., 1.]),
#  'nit': array([2., 0.]),
#  'fairli': array([3., 9.]),
#  'boxi': array([1., 0.]),
#  'wrist': array([1., 0.]),
#  'neck': array([1., 1.]),
#  'spite': array([1., 0.]),
#  'pricey': array([1., 2.]),
#  'crack': array([4., 1.]),
#  'sd': array([1., 2.]),
#  'fluid': array([1., 0.]),
#  'jackson': array([1., 0.]),
#  'pollock': array([1., 0.]),
#  'blue': array([ 2., 18.]),
#  'purpl': array([1., 2.]),
#  'blotch': array([1., 0.]),
#  'streak': array([2., 0.]),
#  'knock': array([2., 1.]),
#  'underpow': array([1., 0.]),
#  'blob': array([1., 0.]),
#  'figur': array([4., 4.]),
#  '57': array([1., 1.]),
#  'except': array([10., 14.]),
#  'icon': array([2., 1.]),
#  'due': array([10.,  5.]),
#  'weight': array([ 4., 12.]),
#  'shake': array([3., 3.]),
#  'contend': array([1., 0.]),
#  'disadvantag': array([1., 0.]),
#  'autofocu': array([3., 2.]),
#  'candid': array([1., 0.]),
#  'compact': array([ 2., 23.]),
#  'someon': array([4., 4.]),
#  'clip': array([10., 14.]),
#  'warm': array([2., 0.]),
#  'loud': array([ 6., 11.]),
#  'downsid': array([10.,  0.]),
#  'condit': array([1., 2.]),
#  'sd500': array([ 3., 11.]),
#  'possess': array([1., 0.]),
#  'twice': array([3., 3.]),
#  'sensit': array([11.,  4.]),
#  'compromis': array([2., 2.]),
#  'rebel': array([2., 0.]),
#  'agre': array([3., 1.]),
#  'advanc': array([2., 7.]),
#  'robust': array([2., 3.]),
#  'head': array([2., 2.]),
#  'share': array([3., 3.]),
#  'click': array([ 7., 19.]),
#  'stiff': array([2., 0.]),
#  'aw': array([8., 1.]),
#  'ton': array([2., 8.]),
#  'research': array([3., 6.]),
#  'cnet': array([2., 1.]),
#  'manipul': array([1., 4.]),
#  'dark': array([4., 3.]),
#  '8': array([ 3., 15.]),
#  'meg': array([2., 1.]),
#  'next': array([8., 8.]),
#  '256': array([3., 0.]),
#  'eye': array([2., 7.]),
#  'taken': array([12.,  8.]),
#  'lithium': array([4., 2.]),
#  'highli': array([ 1., 26.]),
#  'inconveni': array([6., 0.]),
#  'vacat': array([1., 1.]),
#  'nearest': array([2., 0.]),
#  'ga': array([1., 0.]),
#  'station': array([4., 4.]),
#  'span': array([2., 0.]),
#  'short': array([9., 8.]),
#  'uncommon': array([1., 0.]),
#  'bring': array([4., 3.]),
#  'charger': array([1., 7.]),
#  'spare': array([2., 7.]),
#  'length': array([2., 1.]),
#  'silent': array([2., 2.]),
#  'hardli': array([2., 3.]),
#  'unabl': array([2., 1.]),
#  'quiet': array([5., 6.]),
#  'noisi': array([2., 0.]),
#  'macro': array([ 1., 12.]),
#  'auto': array([ 6., 22.]),
#  'overrid': array([1., 0.]),
#  'overcom': array([2., 0.]),
#  'choic': array([ 3., 13.]),
#  'difficult': array([14.,  8.]),
#  'manag': array([6., 5.]),
#  'imposs': array([4., 3.]),
#  'glass': array([2., 0.]),
#  'steadi': array([2., 2.]),
#  'challeng': array([4., 2.]),
#  'grip': array([2., 2.]),
#  'delay': array([1., 2.]),
#  'fulli': array([3., 5.]),
#  'yield': array([1., 2.]),
#  'fuzzi': array([1., 0.]),
#  'unusu': array([1., 0.]),
#  'system': array([20., 23.]),
#  'intermedi': array([1., 0.]),
#  'resolut': array([ 1., 12.]),
#  'suggest': array([4., 3.]),
#  'meaningless': array([1., 0.]),
#  'snap': array([2., 3.]),
#  'car': array([ 7., 11.]),
#  'realiz': array([3., 2.]),
#  'select': array([10.,  9.]),
#  'luck': array([3., 2.]),
#  'repres': array([2., 0.]),
#  'record': array([10., 30.]),
#  'max': array([2., 3.]),
#  '30': array([9., 4.]),
#  '160x120': array([1., 0.]),
#  'per': array([5., 6.]),
#  '640x480': array([1., 2.]),
#  'origin': array([3., 5.]),
#  '98': array([2., 3.]),
#  'wonder': array([ 3., 18.]),
#  'comput': array([29., 48.]),
#  'novemb': array([1., 0.]),
#  'xp': array([6., 8.]),
#  'usb': array([ 8., 25.]),
#  'soho': array([2., 0.]),
#  'compat': array([2., 9.]),
#  'driver': array([6., 3.]),
#  'cannon': array([1., 0.]),
#  'backup': array([1., 3.]),
#  'adob': array([1., 0.]),
#  'let': array([ 8., 11.]),
#  'forc': array([3., 0.]),
#  'creat': array([7., 9.]),
#  'document': array([6., 6.]),
#  'export': array([1., 1.]),
#  'applic': array([8., 8.]),
#  'intuit': array([ 6., 21.]),
#  'often': array([4., 6.]),
#  'struggl': array([1., 0.]),
#  'said': array([11.,  8.]),
#  'peopl': array([20., 35.]),
#  'skin': array([1., 0.]),
#  'pic': array([ 3., 17.]),
#  'true': array([4., 6.]),
#  'exposur': array([1., 9.]),
#  'redey': array([1., 1.]),
#  'reduct': array([1., 0.]),
#  'balanc': array([ 2., 10.]),
#  'fool': array([2., 0.]),
#  'dens': array([1., 1.]),
#  'cloud': array([1., 0.]),
#  'dynam': array([2., 1.]),
#  'rang': array([ 1., 19.]),
#  'kodak': array([1., 3.]),
#  'dc260': array([1., 0.]),
#  'ed': array([1., 5.]),
#  'casio': array([1., 2.]),
#  'worst': array([8., 0.]),
#  'calcul': array([1., 1.]),
#  'ok': array([ 7., 12.]),
#  'wife': array([2., 2.]),
#  'granni': array([1., 0.]),
#  'side': array([12.,  7.]),
#  'fix': array([7., 2.]),
#  'photoshop': array([2., 3.]),
#  '0': array([ 5., 11.]),
#  'level': array([9., 7.]),
#  'person': array([10., 24.]),
#  'accessori': array([6., 9.]),
#  'headphon': array([33., 21.]),
#  ...}

# %%
# convert the freqs dictionary to nested list
def freqs_to_df(freqs, train_y):
    '''
    input:
        freqs: a frequencies dictionary (ex: {'simplist': array([15.,  4.]), 
                                              'silli': array([64., 20.]), . . })
        train_y: labels for data
    output:
        a frequencies dictionary in the form of dataframe
    '''
    # initialize an empty list to store the rows for dataframe
    freqs_list = []
    
    # Define the names of the dataframe columns
    column_names = ['word']
    column_names = column_names + list(np.unique(train_y))
    
    # convert the keys from the freqs dictionary to a list
    keys = list(freqs.keys())

    # For each row
    for i in range(len(freqs)):
        
        # define the elements for each column
        row = [keys[i]] + list(freqs.get(keys[i]))
        
        # update the frequency list
        freqs_list.append(row)
    
    # Create the dataframe
    df = pd.DataFrame(freqs_list, columns=column_names)
    df.set_index('word', inplace=True)
    return df

# %%
freqs_df = freqs_to_df(freqs, labels)
freqs_df
# Out:
#            0     1
# word
# weak    10.0   2.0
# minor    8.0   1.0
# feel    19.0  29.0
# layout   3.0   2.0
# remot   17.0  13.0
# ...      ...   ...
# pi       0.0   1.0
# 1ghz     0.0   1.0
# rd       0.0   1.0
# 80gb     0.0   1.0
# bacon    0.0   1.0
#
# [3714 rows x 2 columns]

# %%
freqs_df[0].sum()
# Out:
# 12725.0

# %% [markdown]
# # Training and Testing the Model

# %% [markdown]
# ## Build Training Function

# %%
def train_naive_bayes(freq_df, train_x, train_y):
    '''
    Input:
        freqs: a pandas dataframe with word indexing
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    
    freqs = freq_df

    # calculate V, the number of unique words in the vocabulary
    vocab = list(freqs.index)
    V = len(vocab)
    
    ########################################################################################
    # Part 1: Calculate the log prior probability for each class
    
    # Calculate D, the number of documents
    D = len(train_y)
    
    labels = list(np.unique(train_y.astype(int)))
    count = np.zeros((len(labels),))

    for train_label in train_y:
        for unique_label in labels:
            if train_label == unique_label:
                count[unique_label]+=1
                
    # -> count = [4000, 4000]; it means perfectly balanced between each classese

    # Calculate prior probability for each class
    prior = count/D # -> prior = array([0.5, 0.5])
    
        
    # Calculate the logprior for each class
    logprior = np.log(prior) # -> prior = array([-0.69314718, -0.69314718])
    
    ########################################################################################
    # Part 2.a. Calculate the total number of word occurrences for each class
    
    columns = list(freqs.columns)
    N_classes = []
    # calculate N frequency for each class
    for column in columns:
        
        freqs[column] = (freqs[column] + 1)/(freqs[column].sum()+V)
        
    # Calculate the log likelihood of the word
    loglikelihood = np.log(freqs)
        
    ########################################################################################
        
    return logprior, loglikelihood

# %%
labels = np.array(labels)
logprior, loglikelihood = train_naive_bayes(freqs_df, sentences, labels)
print(logprior)
loglikelihood
# Out:
# [-1.01505056 -0.45001922]
#                0         1
# word
# weak   -7.309517 -9.014488
# minor  -7.510187 -9.419953
# feel   -6.711680 -6.711903
# layout -8.321117 -9.014488
# remot  -6.817040 -7.474043
# ...          ...       ...
# pi     -9.707412 -9.419953
# 1ghz   -9.707412 -9.419953
# rd     -9.707412 -9.419953
# 80gb   -9.707412 -9.419953
# bacon  -9.707412 -9.419953
#
# [3714 rows x 2 columns]

# %% [markdown]
# ## Build Testing Function

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    input:
        tweet: a string
        logprior: initial probability based on dataset
        loglikelihood: a dictionary of words mapping to numbers
    output:
        p: the sum of all the loglikelihood of each word in the tweet
        (if found in the dictionary) + logprior (a number)
    '''
    
    # process the tweet to get the list of words
    words = clean_doc(tweet)
    
    
    # Initialize probability to zero
    probs = []
    columns = list(loglikelihood.columns)
    for column in columns:
        prob = 0
        # Iterate for each word in word list
        for word in words:

            # check if the word exist in the loglikelihood dictionary
            if word in loglikelihood.index:
                prob += loglikelihood.loc[word, column]
        
        probs.append(prob)
        
    probs = logprior + probs
    y_hat = np.argmax(probs)
    
    return probs, y_hat

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    output:
        accuracy: (# of tweets classified correctly)/total # of tweets
    """
    # initial accuracy
    acc = 0
    
    # initialize an empty list for storing the predictions
    y_hats = []

    for tweet in test_x:
        
        _ , y = naive_bayes_predict(tweet, logprior, loglikelihood)
        
#         y_hat = np.argmax(probs)
        
        # update the y_hats
        y_hats.append(y)
        
#     Error: the mean absolute values between y_hats and test_y
    error = np.mean(np.abs(np.array(y_hats)-np.array(test_y)))
        
#     Accuracy is 1 - error
    acc = 1-error
    return acc

# %% [markdown]
# ## KFold CV

# %%
###############################################
# Training and Testing using the same Dataset #
###############################################

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), np.array(list(corpus.label))

# Build the freqs dictionary for later uses
freqs = count_docs({}, sentences, labels)

# Turn the frequencies dictionary into dataframe
freqs_df = freqs_to_df(freqs, labels)
print(freqs_df.head())

# Retrieve the logprior and loglikelihood
logprior, loglikelihood = train_naive_bayes(freqs_df, sentences, labels)
print(logprior)
print(loglikelihood.head())

print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(sentences, labels, logprior, loglikelihood)))
# Out:
#            0     1
# word
# weak    10.0   2.0
# minor    8.0   1.0
# feel    19.0  29.0
# layout   3.0   2.0
# remot   17.0  13.0
# [-1.01505056 -0.45001922]
#                0         1
# word
# weak   -7.309517 -9.014488
# minor  -7.510187 -9.419953
# feel   -6.711680 -6.711903
# layout -8.321117 -9.014488
# remot  -6.817040 -7.474043
# Naive Bayes accuracy = 0.8903

# %%
#######################################################
# Training and Testing using 10-fold Cross Validation #
#######################################################

# prepare cross validation
kfold = KFold(10, True)

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)
# count = 0
acc_list = []
# kfold.split() will return set indices for each split
for train, test in kfold.split(sentences):
    train_x, train_y = [], []
    test_x, test_y = [], []
    for i in train:
        train_x.append(sentences[i])
        train_y.append(labels[i])
        
    for i in test:
        test_x.append(sentences[i])
        test_y.append(labels[i])
    
    train_y = np.array(train_y)
    test_y = np.array(test_y)
    
    # Build the freqs dictionary for later uses
    freqs = count_docs({}, train_x, train_y)

    # Turn the frequencies dictionary into dataframe
    freqs_df = freqs_to_df(freqs, train_y)
#     print(freqs_df.head())

    # Retrieve the logprior and loglikelihood
    logprior, loglikelihood = train_naive_bayes(freqs_df, train_x, train_y)
    print('loglikelihood:\n{}'.format(loglikelihood.head()))
    print('logprior: {}'.format(logprior))
    
    acc = test_naive_bayes(test_x, test_y, logprior, loglikelihood)
    print("Naive Bayes test accuracy = %0.4f\n" %(acc))
    
    acc_list.append(acc)

acc_list = np.array(acc_list)
print()
print('The test ccuracy for each training:\n{}'.format(acc_list))
print('The mean of the test accuracy: ', acc_list.mean())
# Out:
# C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass shuffle=True as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# loglikelihood:
#                0         1
# word
# weak   -7.325412 -8.913775
# minor  -7.430773 -9.319240
# feel   -6.855409 -6.793511
# layout -8.934850 -8.913775
# remot  -6.794784 -7.447437
# logprior: [-1.00697518 -0.45463804]
# Naive Bayes test accuracy = 0.7937
#
# loglikelihood:
#                0         1
# word
# weak   -7.310283 -9.316276
# minor  -7.415643 -9.316276
# feel   -6.617136 -6.677218
# layout -8.226573 -8.910811
# remot  -6.840279 -7.370366
# logprior: [-1.01506584 -0.45001054]
# Naive Bayes test accuracy = 0.7831
#
# loglikelihood:
#                0          1
# word
# mani   -6.431331  -6.284445
# disney -8.510773 -10.022115
# movi   -7.124478  -7.383057
# n      -5.346705  -5.944577
# play   -5.584033  -5.691381
# logprior: [-1.02486184 -0.44448566]
# Naive Bayes test accuracy = 0.7857
#
# loglikelihood:
#                0         1
# word
# weak   -7.316349 -8.920834
# minor  -7.539492 -9.326300
# feel   -6.674495 -6.618249
# layout -8.232640 -9.326300
# remot  -6.846345 -7.454497
# logprior: [-1.01101233 -0.45232161]
# Naive Bayes test accuracy = 0.7857
#
# loglikelihood:
#                0         1
# word
# weak   -7.432944 -8.909506
# minor  -7.550727 -9.314971
# feel   -6.634436 -6.712281
# layout -8.243874 -8.909506
# remot  -6.739797 -7.523211
# logprior: [-1.00215202 -0.45742485]
# Naive Bayes test accuracy = 0.7989
#
# loglikelihood:
#                0         1
# word
# weak   -7.314087 -8.919453
# minor  -7.670762 -9.324918
# feel   -6.844083 -6.759969
# layout -8.230377 -8.919453
# remot  -6.783458 -7.379008
# logprior: [-1.01211605 -0.45169088]
# Naive Bayes test accuracy = 0.8223
#
# loglikelihood:
#                0          1
# word
# weak   -7.307202  -9.330033
# minor  -7.412563 -10.023180
# feel   -6.665348  -6.765083
# layout -8.223493  -8.924568
# remot  -6.776574  -7.458231
# logprior: [-1.02351683 -0.44523924]
# Naive Bayes test accuracy = 0.7454
#
# loglikelihood:
#                0         1
# word
# weak   -7.224091 -8.918383
# minor  -7.542545 -9.323848
# feel   -6.677547 -6.721158
# layout -8.235692 -8.918383
# remot  -6.849398 -7.377937
# logprior: [-1.01211605 -0.45169088]
# Naive Bayes test accuracy = 0.7745
#
# loglikelihood:
#                0         1
# word
# weak   -7.212093 -8.924080
# minor  -7.530547 -9.329545
# feel   -6.719617 -6.803816
# layout -8.223694 -9.329545
# remot  -6.837400 -7.825467
# logprior: [-1.02433616 -0.44478   ]
# Naive Bayes test accuracy = 0.8064
#
# loglikelihood:
#                0         1
# word
# weak   -7.303843 -8.922436
# minor  -7.409204 -9.327901
# feel   -6.716057 -6.619851
# layout -8.220134 -8.922436
# remot  -6.773215 -7.456099
# logprior: [-1.01861486 -0.44799913]
# Naive Bayes test accuracy = 0.7798
#
#
# The test ccuracy for each training:
# [0.79365079 0.78306878 0.78571429 0.78571429 0.7989418  0.82228117
#  0.74535809 0.77453581 0.80636605 0.77984085]
# The mean of the test accuracy:  0.7875471909954669
