# %% [markdown]
# # Naive Bayes Classification with MPQA Dataset
# <hr>
#
# We will build a text classification model using Naive Bayes on the Opinion Polarity Detection subtask of the MPQA Dataset. Since there is no standard train/test split for this dataset, we will use 10-Fold Cross Validation (CV).
#
# ## Load the library

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import random
from nltk.corpus import stopwords, twitter_samples
# from nltk.tokenize import TweetTokenizer
from sklearn.model_selection import KFold
from nltk.stem import PorterStemmer
from string import punctuation
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
import time

# %config IPCompleter.greedy=True
# %config IPCompleter.use_jedi=False
# nltk.download('twitter_samples')

# %% [markdown]
# ## Load the Dataset

# %%
corpus = pd.read_pickle('../0_data/MPQA/MPQA.pkl')
corpus.label = corpus.label.astype(int)
print(corpus.shape)
corpus
# Out:
# (10606, 3)
#                   sentence  label  split
# 0              complaining      0  train
# 1       failing to support      0  train
# 2        desperately needs      0  train
# 3      many years of decay      0  train
# 4             no quick fix      0  train
# ...                    ...    ...    ...
# 10601                urged      1  train
# 10602       strictly abide      1  train
# 10603                 hope      1  train
# 10604       strictly abide      1  train
# 10605                           1  train
#
# [10606 rows x 3 columns]

# %%
corpus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10606 entries, 0 to 10605
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  10606 non-null  object
#  1   label     10606 non-null  int32
#  2   split     10606 non-null  object
# dtypes: int32(1), object(2)
# memory usage: 207.3+ KB

# %%
corpus.groupby( by='label').count()
# Out:
#        sentence  split
# label
# 0          7294   7294
# 1          3312   3312

# %%
# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)

# %% [markdown]
# ## Raw Number of Vocabulary

# %%
# Build the raw vocobulary for first inspection
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
vocab_raw = tokenizer.word_index
print('\nThe vocabulary size: {}\n'.format(len(vocab_raw)))
print(vocab_raw)
# Out:
# The vocabulary size: 6234
#
# {'the': 1, 'of': 2, 'to': 3, 'a': 4, 'and': 5, 'not': 6, 'is': 7, 'in': 8, 'be': 9, 'has': 10, 'for': 11, 'will': 12, 'have': 13, 'are': 14, 'support': 15, 'would': 16, 'was': 17, 'it': 18, 'evil': 19, 'on': 20, 'with': 21, 'as': 22, 'an': 23, 'no': 24, 'more': 25, "'s": 26, 'that': 27, 'its': 28, 'axis': 29, 'against': 30, 'can': 31, 'his': 32, 'by': 33, 'their': 34, 'want': 35, 'had': 36, 'do': 37, 'all': 38, 'were': 39, 'been': 40, 'rights': 41, 'one': 42, 'very': 43, 'war': 44, 'out': 45, 'called': 46, 'only': 47, 'so': 48, 'could': 49, 'at': 50, 'this': 51, 'human': 52, 'good': 53, 'us': 54, 'peace': 55, 'should': 56, 'most': 57, 'up': 58, 'free': 59, 'concern': 60, 'they': 61, 'world': 62, 'fair': 63, 'criticism': 64, 'from': 65, "n't": 66, 'does': 67, 'even': 68, 'or': 69, 'any': 70, 'accused': 71, 'hope': 72, 'if': 73, 'people': 74, 'than': 75, 'like': 76, 'such': 77, 'way': 78, 'warned': 79, 'expressed': 80, 'but': 81, 'legitimate': 82, 'just': 83, 'terrorism': 84, 'better': 85, 'being': 86, 'protest': 87, 'wants': 88, 'right': 89, 'great': 90, 'also': 91, 'violence': 92, 'strong': 93, 'our': 94, 'there': 95, 'refused': 96, 'may': 97, 'serious': 98, 'without': 99, 'international': 100, 'who': 101, 'criticized': 102, 'never': 103, 'into': 104, 'justice': 105, 'what': 106, 'condemned': 107, 'far': 108, 'opposition': 109, 'concerns': 110, 'did': 111, 'we': 112, 'government': 113, 'israeli': 114, 'respect': 115, 'still': 116, 'denied': 117, 'rejected': 118, 'confidence': 119, 'supported': 120, 'dangerous': 121, 'wanted': 122, 'concerned': 123, 'nothing': 124, 'country': 125, 'accept': 126, 'political': 127, 'threat': 128, 'too': 129, 'difficult': 130, 'new': 131, 'power': 132, 'him': 133, 'now': 134, 'urged': 135, 'long': 136, 'security': 137, 'made': 138, 'well': 139, 'democracy': 140, 'put': 141, 'own': 142, 'policy': 143, 'intimidation': 144, 'protests': 145, 'down': 146, 'problem': 147, 'under': 148, 'interests': 149, 'them': 150, 'much': 151, 'back': 152, 'he': 153, 'campaign': 154, 'time': 155, 'enemy': 156, 'considered': 157, 'palestinian': 158, 'peaceful': 159, 'get': 160, 'feel': 161, 'little': 162, 'further': 163, 'must': 164, 'away': 165, 'bad': 166, 'because': 167, 'itself': 168, 'worse': 169, 'critical': 170, 'force': 171, 'freedom': 172, 'those': 173, 'threatened': 174, 'economic': 175, 'some': 176, 'you': 177, 'failed': 178, 'state': 179, 'fear': 180, 'always': 181, 'hopes': 182, 'agreed': 183, 'many': 184, 'opposed': 185, 'over': 186, 'act': 187, 'these': 188, 'every': 189, 'go': 190, 'enough': 191, 'anti': 192, 'hoped': 193, 'think': 194, 'take': 195, 'american': 196, 'law': 197, 'refusal': 198, 'become': 199, 'anything': 200, 'end': 201, 'off': 202, 'possible': 203, 'seek': 204, 'mistake': 205, 'fears': 206, 'already': 207, 'stand': 208, 'warning': 209, 'going': 210, 'situation': 211, 'day': 212, 'high': 213, 'impossible': 214, 'israel': 215, 'committed': 216, 'states': 217, 'wish': 218, 'hard': 219, 'true': 220, 'best': 221, 'threatening': 222, 'i': 223, 'however': 224, 'about': 225, 'side': 226, 'am': 227, 'crisis': 228, 'quite': 229, 'same': 230, 'refuses': 231, 'allow': 232, 'legal': 233, 'threats': 234, 'help': 235, 'supporting': 236, 'calling': 237, 'desire': 238, 'supports': 239, 'years': 240, 'happy': 241, 'other': 242, 'charges': 243, 'worried': 244, 'worst': 245, 'seen': 246, 'seeking': 247, 'use': 248, 'willing': 249, 'rejection': 250, 'growing': 251, 'themselves': 252, 'terrorists': 253, 'sense': 254, 'action': 255, 'despite': 256, 'full': 257, 'calm': 258, 'positive': 259, 'democratic': 260, 'wrong': 261, 'satisfied': 262, 'continue': 263, 'major': 264, 'calls': 265, 'rigged': 266, 'victory': 267, 'suffering': 268, 'fight': 269, 'innocent': 270, 'terror': 271, 'national': 272, 'less': 273, 'make': 274, 'lack': 275, 'see': 276, 'blamed': 277, 'asked': 278, 'united': 279, 'himself': 280, 'how': 281, 'success': 282, 'inhumane': 283, 'commitment': 284, 'election': 285, 'poor': 286, 'call': 287,  ...

# %% [markdown]
# <!--## Split Dataset-->

# %% [markdown]
# # Data Preprocessing
# <hr>

# %% [markdown]
# ## Define `clean_doc` function

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stemmer = PorterStemmer()
    
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # remove remaining tokens that are not alphabetic
#     tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    tokens = [w for w in tokens if not w in stopwords]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) >= 1]
    # Stem the token
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

# %% [markdown]
# ## Define `count_docs` function

# %%
def count_docs(data, docs, ys):
    '''
    Input:
        data: a dictionary that will be used to map each pair to its frequency
        docs: a list of sentences
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''
    onehot = OneHotEncoder( sparse=False)
    y_onehot = onehot.fit_transform(np.reshape(ys, (-1,1)))
    # print(y_onehot)
    count = 0                    
    for doc, y in zip(docs, y_onehot):
        # For each word
        for word in clean_doc(doc):
            # if not in the data yet
            if word not in data:
                # assign it
                data[word] = y
            # if already in the data 
            else:
                # update it
                data[word] = data.get(word) + y

    return data

# %% [markdown]
# ## Build Frequencies Dictionary

# %%
# Build the freqs dictionary for later uses
freqs = count_docs({}, sentences, labels)
freqs
# Out:
# {'complain': array([11.,  2.]),
#  'fail': array([33.,  3.]),
#  'support': array([ 26., 238.]),
#  'desper': array([19.,  0.]),
#  'need': array([12.,  5.]),
#  'mani': array([18.,  2.]),
#  'year': array([18.,  3.]),
#  'decay': array([2., 0.]),
#  'quick': array([3., 2.]),
#  'fix': array([2., 1.]),
#  'happi': array([9., 8.]),
#  'long': array([20.,  8.]),
#  'pain': array([8., 1.]),
#  'nobodi': array([3., 0.]),
#  'complic': array([7., 1.]),
#  'process': array([7., 1.]),
#  'decad': array([3., 1.]),
#  'dramat': array([6., 0.]),
#  'econom': array([13.,  9.]),
#  'declin': array([14.,  0.]),
#  'suffer': array([26.,  0.]),
#  'would': array([113.,  75.]),
#  'sure': array([7., 3.]),
#  'higher': array([3., 2.]),
#  'still': array([16., 14.]),
#  'forbidden': array([1., 0.]),
#  'intox': array([1., 0.]),
#  'far': array([26.,  6.]),
#  'perfect': array([1., 1.]),
#  'sour': array([1., 0.]),
#  'relat': array([5., 7.]),
#  'fell': array([2., 1.]),
#  'mount': array([3., 0.]),
#  'rivalri': array([1., 0.]),
#  'hostil': array([14.,  0.]),
#  'nation': array([31., 11.]),
#  'accus': array([85.,  0.]),
#  'bow': array([4., 2.]),
#  'total': array([13.,  5.]),
#  'depend': array([4., 0.]),
#  'lose': array([10.,  0.]),
#  'control': array([11.,  2.]),
#  'warn': array([76.,  0.]),
#  'heel': array([1., 0.]),
#  'pressur': array([5., 3.]),
#  'knee': array([1., 0.]),
#  'militari': array([13.,  1.]),
#  'adventur': array([3., 0.]),
#  'boost': array([1., 2.]),
#  'threaten': array([50.,  2.]),
#  'heavili': array([4., 0.]),
#  'arm': array([6., 0.]),
#  'place': array([16.,  2.]),
#  'world': array([43., 16.]),
#  'danger': array([42.,  1.]),
#  'flashpoint': array([1., 0.]),
#  'want': array([ 48., 114.]),
#  'avoid': array([13.,  0.]),
#  'superfici': array([2., 0.]),
#  'exercis': array([3., 4.]),
#  'mere': array([19.,  0.]),
#  'speak': array([7., 1.]),
#  'deep': array([9., 0.]),
#  'diverg': array([2., 0.]),
#  'neg': array([11.,  0.]),
#  'bias': array([9., 3.]),
#  'claim': array([22.,  6.]),
#  'complaint': array([10.,  0.]),
#  'suspicion': array([12.,  1.]),
#  'squeez': array([1., 0.]),
#  'ruinou': array([1., 0.]),
#  'mistak': array([21.,  0.]),
#  'play': array([18.,  1.]),
#  'fire': array([10.,  1.]),
#  'subvert': array([3., 0.]),
#  'tri': array([25.,  5.]),
#  'provok': array([14.,  0.]),
#  'protest': array([80.,  0.]),
#  'mdc': array([1., 1.]),
#  'lot': array([7., 1.]),
#  'express': array([41., 29.]),
#  'concern': array([124.,   0.]),
#  'shoot': array([5., 0.]),
#  'man': array([6., 3.]),
#  'offic': array([4., 0.]),
#  'extrem': array([16.,  2.]),
#  'keen': array([1., 0.]),
#  'fight': array([19.,  1.]),
#  'agit': array([3., 0.]),
#  'allegedli': array([1., 0.]),
#  'remov': array([10.,  0.]),
#  'violent': array([10.,  0.]),
#  'reluct': array([10.,  0.]),
#  'villain': array([1., 0.]),
#  'nt': array([53.,  4.]),
#  'challeng': array([13.,  1.]),
#  'flirt': array([1., 0.]),
#  'charg': array([37.,  0.]),
#  'oppos': array([38.,  0.]),
#  'alleg': array([24.,  1.]),
#  'languag': array([4., 0.]),
#  'violenc': array([36.,  2.]),
#  'presid': array([9., 2.]),
#  'mugab': array([5., 0.]),
#  'fear': array([55.,  1.]),
#  'refus': array([84.,  4.]),
#  'parliamentarian': array([1., 0.]),
#  'tens': array([4., 0.]),
#  'relationship': array([2., 4.]),
#  'renegad': array([3., 0.]),
#  'provinc': array([3., 0.]),
#  'unusu': array([1., 0.]),
#  'worri': array([27.,  1.]),
#  'disapprov': array([13.,  0.]),
#  'call': array([44., 78.]),
#  'stop': array([10.,  6.]),
#  'tactic': array([7., 1.]),
#  'resort': array([7., 1.]),
#  'privat': array([1., 1.]),
#  'diplomaci': array([2., 1.]),
#  'gulf': array([2., 0.]),
#  'possess': array([1., 0.]),
#  'necessari': array([6., 0.]),
#  'expertis': array([1., 0.]),
#  'act': array([26.,  3.]),
#  'objection': array([1., 0.]),
#  'brutal': array([13.,  0.]),
#  'gain': array([6., 4.]),
#  'popular': array([3., 6.]),
#  'may': array([24., 12.]),
#  'feel': array([29.,  8.]),
#  'uneasi': array([4., 0.]),
#  'question': array([18.,  1.]),
#  'certain': array([6., 1.]),
#  'excess': array([12.,  0.]),
#  'load': array([4., 0.]),
#  'sin': array([3., 0.]),
#  'function': array([3., 0.]),
#  'optim': array([1., 1.]),
#  'color': array([1., 0.]),
#  'leftist': array([2., 0.]),
#  'ideolog': array([3., 1.]),
#  'hype': array([1., 0.]),
#  'even': array([48.,  7.]),
#  'wors': array([21.,  1.]),
#  'foster': array([1., 0.]),
#  'trade': array([1., 1.]),
#  'anarchi': array([2., 0.]),
#  'blind': array([12.,  1.]),
#  'rather': array([6., 1.]),
#  'target': array([13.,  0.]),
#  'altern': array([4., 1.]),
#  'conflict': array([4., 3.]),
#  'isol': array([10.,  1.]),
#  'ultim': array([2., 0.]),
#  'war': array([73.,  5.]),
#  'cold': array([9., 1.]),
#  'monster': array([2., 0.]),
#  'immens': array([1., 1.]),
#  'slow': array([1., 0.]),
#  'closur': array([1., 0.]),
#  'implement': array([4., 0.]),
#  'unheard': array([1., 0.]),
#  'thought': array([6., 4.]),
#  'annoy': array([3., 0.]),
#  'lost': array([13.,  1.]),
#  'game': array([6., 0.]),
#  'littl': array([21.,  2.]),
#  'liber': array([3., 3.]),
#  'got': array([3., 2.]),
#  'capit': array([1., 0.]),
#  'live': array([13.,  3.]),
#  'polit': array([31.,  9.]),
#  'highli': array([4., 4.]),
#  'sophist': array([1., 1.]),
#  'societi': array([3., 5.]),
#  'summit': array([1., 0.]),
#  'reject': array([66.,  0.]),
#  'think': array([20.,  5.]),
#  'howev': array([14.,  3.]),
#  'illeg': array([10.,  0.]),
#  'crise': array([2., 1.]),
#  'fierc': array([5., 1.]),
#  'competit': array([2., 6.]),
#  'right': array([83., 37.]),
#  'compli': array([2., 0.]),
#  'relentlessli': array([2., 0.]),
#  'demonstr': array([18.,  2.]),
#  'abandon': array([11.,  0.]),
#  'discredit': array([6., 0.]),
#  'fact': array([9., 1.]),
#  'unpreced': array([6., 1.]),
#  'seriou': array([30.,  6.]),
#  'level': array([6., 1.]),
#  'weak': array([5., 0.]),
#  'opposit': array([34.,  0.]),
#  'hand': array([21.,  6.]),
#  'concoct': array([1., 0.]),
#  'without': array([31.,  5.]),
#  'effect': array([10., 10.]),
#  'critic': array([150.,   0.]),
#  'poverti': array([1., 0.]),
#  'entitl': array([2., 1.]),
#  'reach': array([6., 1.]),
#  'boil': array([1., 0.]),
#  'point': array([12.,  4.]),
#  'roughli': array([1., 0.]),
#  'lack': array([20.,  2.]),
#  'conclus': array([5., 0.]),
#  'oper': array([2., 0.]),
#  'reduc': array([5., 0.]),
#  'margin': array([3., 0.]),
#  'secur': array([17., 11.]),
#  'firm': array([ 3., 10.]),
#  'flop': array([1., 0.]),
#  'complet': array([13.,  6.]),
#  'reserv': array([2., 1.]),
#  'experi': array([4., 0.]),
#  'alreadi': array([18.,  0.]),
#  'volatil': array([2., 0.]),
#  'intens': array([6., 2.]),
#  'dissatisfact': array([8., 0.]),
#  'frustrat': array([15.,  0.]),
#  'breed': array([5., 0.]),
#  'insecur': array([2., 0.]),
#  'undermin': array([16.,  0.]),
#  'posit': array([10., 18.]),
#  'particular': array([4., 0.]),
#  'stanc': array([7., 4.]),
#  'global': array([9., 3.]),
#  'easili': array([4., 1.]),
#  'rais': array([21.,  3.]),
#  'kill': array([21.,  0.]),
#  'remind': array([3., 0.]),
#  'whose': array([4., 0.]),
#  'land': array([3., 2.]),
#  'occupi': array([4., 0.]),
#  'scene': array([3., 0.]),
#  'destruct': array([19.,  0.]),
#  'tragic': array([5., 0.]),
#  'shock': array([8., 0.]),
#  'persecut': array([4., 1.]),
#  'enorm': array([10.,  3.]),
#  'injustic': array([12.,  1.]),
#  'expel': array([2., 0.]),
#  'homeland': array([1., 1.]),
#  'bombard': array([1., 0.]),
#  'hatr': array([12.,  1.]),
#  'sorri': array([3., 0.]),
#  'fall': array([8., 2.]),
#  'victim': array([7., 0.]),
#  'sympathi': array([9., 3.]),
#  'grief': array([3., 0.]),
#  'sorrow': array([2., 0.]),
#  'take': array([26.,  9.]),
#  'advantag': array([7., 7.]),
#  'us': array([53.,  9.]),
#  'tragedi': array([6., 2.]),
#  'demolish': array([4., 0.]),
#  'struck': array([1., 1.]),
#  'innoc': array([14.,  1.]),
#  'women': array([5., 0.]),
#  'children': array([6., 0.]),
#  'defenseless': array([1., 0.]),
#  'civilian': array([7., 0.]),
#  'deni': array([46.,  0.]),
#  'twist': array([6., 1.]),
#  'logic': array([7., 3.]),
#  'ongo': array([3., 0.]),
#  'devast': array([12.,  0.]),
#  'destroy': array([23.,  0.]),
#  'depriv': array([9., 0.]),
#  'minimum': array([4., 0.]),
#  'human': array([63., 35.]),
#  'could': array([48., 21.]),
#  'one': array([68., 14.]),
#  'worst': array([16.,  0.]),
#  'day': array([21.,  2.]),
#  'american': array([20.,  4.]),
#  'histori': array([11.,  1.]),
#  'great': array([14., 26.]),
#  'ghastli': array([2., 0.]),
#  'barbar': array([5., 0.]),
#  'strongli': array([10.,  4.]),
#  'condemn': array([61.,  0.]),
#  'label': array([12.,  0.]),
#  'terror': array([56.,  5.]),
#  'attack': array([33.,  0.]),
#  'villag': array([3., 0.]),
#  'loss': array([7., 0.]),
#  'unreservedli': array([1., 0.]),
#  'strongest': array([2., 0.]),
#  'term': array([7., 3.]),
#  'time': array([23., 10.]),
#  'wanton': array([2., 0.]),
#  'properti': array([2., 0.]),
#  'turn': array([25.,  5.]),
#  'stand': array([16., 11.]),
#  'idli': array([1., 0.]),
#  'disrupt': array([3., 0.]),
#  'peac': array([24., 67.]),
#  'mankind': array([5., 1.]),
#  'voic': array([19.,  5.]),
#  'condol': array([3., 0.]),
#  'everyth': array([9., 2.]),
#  'good': array([24., 43.]),
#  'nice': array([1., 0.]),
#  'exceed': array([2., 0.]),
#  'continu': array([21., 17.]),
#  'keep': array([9., 4.]),
#  'aliv': array([3., 0.]),
#  'easi': array([6., 0.]),
#  'context': array([1., 0.]),
#  'struggl': array([7., 2.]),
#  'intern': array([33.,  6.]),
#  'caus': array([15.,  3.]),
#  'demis': array([1., 0.]),
#  'threat': array([44.,  1.]),
#  'distanc': array([3., 0.]),
#  'america': array([10.,  0.]),
#  'chapter': array([1., 0.]),
#  'common': array([4., 2.]),
#  'enemi': array([35.,  1.]),
#  'succeed': array([6., 6.]),
#  'seen': array([10.,  6.]),
#  'behind': array([8., 6.]),
#  'chechen': array([1., 0.]),
#  'much': array([16.,  9.]),
#  'expect': array([5., 6.]),
#  'written': array([1., 2.]),
#  'name': array([7., 1.]),
#  'moscow': array([1., 1.]),
#  'registr': array([1., 1.]),
#  'page': array([1., 2.]),
#  'side': array([15., 11.]),
#  'stereotyp': array([3., 0.]),
#  'rub': array([3., 1.]),
#  'palm': array([2., 1.]),
#  'length': array([2., 2.]),
#  'suspect': array([15.,  0.]),
#  'leak': array([3., 0.]),
#  'frontier': array([1., 0.]),
#  'unsur': array([2., 0.]),
#  'awar': array([3., 2.]),
#  'ensur': array([2., 7.]),
#  'instabl': array([4., 0.]),
#  'milit': array([1., 0.]),
#  'mastermind': array([4., 0.]),
#  'disastr': array([6., 0.]),
#  'unavoid': array([1., 0.]),
#  'culmin': array([1., 0.]),
#  'trump': array([2., 0.]),
#  'card': array([1., 0.]),
#  'commit': array([19., 30.]),
#  'difficult': array([26.,  2.]),
#  'unbeliev': array([1., 0.]),
#  'provoc': array([14.,  1.]),
#  'evil': array([149.,   3.]),
#  'foundat': array([1., 1.]),
#  'west': array([4., 2.]),
#  'degre': array([3., 2.]),
#  'repress': array([11.,  0.]),
#  'sat': array([2., 0.]),
#  'back': array([20., 22.]),
#  'fold': array([1., 0.]),
#  'made': array([21.,  6.]),
#  'hostag': array([6., 0.]),
#  'remain': array([15.,  4.]),
#  'riski': array([5., 0.]),
#  'enterpris': array([1., 0.]),
#  'often': array([7., 1.]),
#  'confus': array([12.,  0.]),
#  'thank': array([ 3., 18.]),
#  'taliban': array([2., 1.]),
#  'regim': array([10.,  1.]),
#  'imperfect': array([1., 0.]),
#  'well': array([ 8., 19.]),
#  'defin': array([1., 0.]),
#  'pervers': array([4., 0.]),
#  'reaction': array([8., 0.]),
#  'repuls': array([1., 0.]),
#  'real': array([8., 3.]),
#  'unfortun': array([11.,  0.]),
#  'bitter': array([9., 0.]),
#  'pill': array([1., 0.]),
#  'swallow': array([2., 0.]),
#  'mire': array([1., 0.]),
#  'increasingli': array([11.,  0.]),
#  'uneas': array([1., 0.]),
#  'affront': array([3., 0.]),
#  'law': array([24.,  4.]),
#  'democraci': array([15., 13.]),
#  'new': array([18., 10.]),
#  'dimens': array([1., 0.]),
#  'crime': array([18.,  0.]),
#  'islam': array([4., 0.]),
#  'perceiv': array([2., 1.]),
#  'consid': array([21., 17.]),
#  'destabilis': array([1., 0.]),
#  'pretext': array([17.,  0.]),
#  'crack': array([6., 0.]),
#  'legitim': array([ 9., 35.]),
#  'dissent': array([5., 1.]),
#  'jeopardis': array([1., 0.]),
#  'order': array([11.,  2.]),
#  'creat': array([10.,  2.]),
#  'troubl': array([8., 2.]),
#  'peopl': array([37., 13.]),
#  'rise': array([10.,  0.]),
#  'mix': array([4., 0.]),
#  'expens': array([4., 1.]),
#  'disput': array([7., 0.]),
#  'unequivoc': array([1., 2.]),
#  'unpalat': array([1., 0.]),
#  'measur': array([7., 3.]),
#  'appal': array([2., 0.]),
#  'find': array([9., 6.]),
#  'afraid': array([6., 1.]),
#  'say': array([11.,  2.]),
#  'self': array([11.,  2.]),
#  'style': array([4., 0.]),
#  'sever': array([19.,  0.]),
#  'tie': array([2., 2.]),
#  'sanction': array([6., 0.]),
#  'bust': array([1., 0.]),
#  'sympath': array([1., 0.]),
#  'displeasur': array([3., 0.]),
#  'lash': array([5., 0.]),
#  'loom': array([1., 0.]),
#  'join': array([6., 3.]),
#  'prevent': array([8., 4.]),
#  'toler': array([12.,  2.]),
#  'turbul': array([2., 0.]),
#  'yet': array([8., 1.]),
#  'anoth': array([13.,  0.]),
#  'burden': array([11.,  0.]),
#  'perpetr': array([6., 0.]),
#  'disrespect': array([1., 0.]),
#  'advic': array([1., 5.]),
#  'crush': array([11.,  0.]),
#  'predatori': array([2., 0.]),
#  'behaviour': array([1., 0.]),
#  'inevit': array([6., 1.]),
#  'chao': array([4., 0.]),
#  'assassin': array([17.,  0.]),
#  'blatantli': array([1., 0.]),
#  'obstruct': array([6., 0.]),
#  'cycl': array([4., 0.]),
#  'decept': array([3., 0.]),
#  'ploy': array([2., 0.]),
#  'disregard': array([9., 0.]),
#  'fair': array([30., 30.]),
#  'weather': array([1., 0.]),
#  'friend': array([7., 8.]),
#  'abhorr': array([1., 0.]),
#  'affect': array([6., 4.]),
#  'everi': array([13.,  7.]),
#  'corner': array([6., 1.]),
#  'earth': array([3., 3.]),
#  'utter': array([2., 0.]),
#  'defianc': array([4., 0.]),
#  'recip': array([1., 0.]),
#  'disast': array([9., 0.]),
#  'aggress': array([28.,  1.]),
#  'persist': array([3., 2.]),
#  'deliber': array([6., 0.]),
#  'fuell': array([1., 0.]),
#  'expansionist': array([4., 0.]),
#  'tel': array([1., 0.]),
#  'aviv': array([1., 0.]),
#  'notic': array([1., 0.]),
#  'opt': array([1., 4.]),
#  'brute': array([1., 0.]),
#  'forc': array([39.,  4.]),
#  'callous': array([2., 0.]),
#  'exploit': array([7., 0.]),
#  'intensifi': array([3., 0.]),
#  'acceler': array([1., 1.]),
#  'seek': array([12., 31.]),
#  'manipul': array([8., 0.]),
#  'risk': array([15.,  0.]),
#  'divid': array([1., 0.]),
#  'rule': array([13.,  6.]),
#  'condit': array([7., 2.]),
#  'former': array([5., 0.]),
#  'state': array([37.,  5.]),
#  'tension': array([13.,  0.]),
#  'confisc': array([2., 0.]),
#  'deal': array([7., 2.]),
#  'improv': array([ 2., 10.]),
#  'carbon': array([1., 0.]),
#  'copi': array([2., 0.]),
#  'edg': array([4., 0.]),
#  'mutin': array([1., 0.]),
#  'medic': array([3., 0.]),
#  'educ': array([1., 1.]),
#  'social': array([12.,  2.]),
#  'life': array([10.,  4.]),
#  'use': array([26., 10.]),
#  'factor': array([2., 1.]),
#  'like': array([48., 19.]),
#  'unabl': array([10.,  0.]),
#  'meet': array([7., 2.]),
#  'kind': array([14.,  1.]),
#  'collect': array([5., 1.]),
#  'punish': array([11.,  1.]),
#  'heavi': array([6., 0.]),
#  'also': array([26., 14.]),
#  'reflect': array([9., 4.]),
#  'way': array([39.,  8.]),
#  'inalien': array([1., 1.]),
#  'palestinian': array([34.,  5.]),
#  'work': array([ 7., 12.]),
#  'push': array([5., 6.]),
#  'brag': array([1., 1.]),
#  'thing': array([11.,  6.]),
#  'larg': array([3., 4.]),
#  'hegemoni': array([4., 1.]),
#  'first': array([7., 5.]),
#  'will': array([10.,  9.]),
#  'recogn': array([13.,  9.]),
#  'add': array([1., 0.]),
#  'fuel': array([3., 0.]),
#  'rage': array([5., 0.]),
#  'labyrinth': array([3., 0.]),
#  'tunnel': array([1., 0.]),
#  'justifi': array([6., 8.]),
#  'excus': array([13.,  1.]),
#  'problem': array([36.,  1.]),
#  'clamp': array([1., 0.]),
#  'freedom': array([ 6., 20.]),
#  'widespread': array([13.,  1.]),
#  'tortur': array([16.,  0.]),
#  'doubl': array([11.,  0.]),
#  'standard': array([17.,  0.]),
#  'pursu': array([3., 4.]),
#  'trend': array([1., 0.]),
#  'violat': array([58.,  0.]),
#  'shortcom': array([3., 0.]),
#  'omin': array([2., 0.]),
#  'phenomenon': array([2., 0.]),
#  'afghan': array([3., 0.]),
#  'crisi': array([17.,  0.]),
#  'forestal': array([1., 0.]),
#  'oil': array([3., 0.]),
#  'price': array([3., 0.]),
#  'intrigu': array([1., 0.]),
#  'go': array([25., 13.]),
#  'silent': array([1., 0.]),
#  'hidden': array([2., 0.]),
#  'subsidi': array([1., 0.]),
#  'look': array([22., 10.]),
#  'bleak': array([2., 0.]),
#  'futur': array([2., 6.]),
#  'everybodi': array([1., 0.]),
#  'jump': array([3., 0.]),
#  'check': array([2., 1.]),
#  'whether': array([6., 1.]),
#  'proper': array([2., 5.]),
#  'safeti': array([4., 2.]),
#  'net': array([2., 0.]),
#  'bottom': array([1., 0.]),
#  'advers': array([4., 0.]),
#  'must': array([16.,  7.]),
#  'virtual': array([2., 0.]),
#  'noth': array([26.,  3.]),
#  'breach': array([1., 0.]),
#  'constitut': array([11.,  4.]),
#  'fundament': array([8., 3.]),
#  'unfair': array([10.,  0.]),
#  'unjust': array([6., 0.]),
#  'render': array([1., 1.]),
#  'worthless': array([1., 0.]),
#  'ban': array([5., 0.]),
#  'dont': array([1., 0.]),
#  'reap': array([2., 0.]),
#  'benefit': array([ 7., 10.]),
#  'mock': array([2., 0.]),
#  'globalis': array([1., 0.]),
#  'greenpeac': array([1., 0.]),
#  'million': array([4., 2.]),
#  'street': array([5., 4.]),
#  'hide': array([4., 2.]),
#  'protestor': array([1., 0.]),
#  'respons': array([19.,  8.]),
#  'island': array([5., 0.]),
#  'biggest': array([8., 1.]),
#  'face': array([18.,  2.]),
#  'today': array([2., 0.]),
#  'vanish': array([2., 0.]),
#  'leav': array([3., 0.]),
#  'home': array([7., 0.]),
#  'disadvantag': array([4., 0.]),
#  'situat': array([15.,  3.]),
#  'unfeas': array([1., 0.]),
#  'bill': array([2., 0.]),
#  'promis': array([ 3., 26.]),
#  'cheap': array([1., 0.]),
#  'kept': array([3., 2.]),
#  'deliv': array([4., 1.]),
#  'blow': array([6., 4.]),
#  'grim': array([6., 0.]),
#  'statist': array([1., 0.]),
#  'trot': array([1., 0.]),
#  'love': array([2., 4.]),
#  'incapac': array([2., 0.]),
#  'put': array([26.,  7.]),
#  'direct': array([3., 4.]),
#  'recept': array([3., 0.]),
#  'elsewher': array([1., 0.]),
#  'repres': array([3., 2.]),
#  'pessimist': array([5., 0.]),
#  'outlook': array([1., 0.]),
#  'relish': array([2., 0.]),
#  'role': array([4., 5.]),
#  'cassandra': array([1., 0.]),
#  'philippin': array([1., 0.]),
#  'polic': array([2., 0.]),
#  'paint': array([6., 0.]),
#  'pictur': array([3., 0.]),
#  'breakdown': array([4., 0.]),
#  'less': array([14.,  1.]),
#  'alarm': array([15.,  0.]),
#  'skin': array([2., 0.]),
#  'make': array([24., 11.]),
#  'govern': array([28.,  4.]),
#  'nemesi': array([1., 0.]),
#  'sap': array([1., 0.]),
#  'countri': array([31., 10.]),
#  'energi': array([1., 1.]),
#  'issu': array([17.,  3.]),
#  'advisori': array([2., 0.]),
#  'bring': array([6., 5.]),
#  'turmoil': array([2., 0.]),
#  'gener': array([4., 6.]),
#  'anxieti': array([2., 0.]),
#  'doomsday': array([1., 0.]),
#  'scenario': array([2., 0.]),
#  'travel': array([2., 0.]),
#  'ca': array([5., 1.]),
#  'buri': array([2., 1.]),
#  'head': array([8., 2.]),
#  'sand': array([1., 0.]),
#  'misplac': array([1., 0.]),
#  'strateg': array([3., 2.]),
#  'prioriti': array([1., 9.]),
#  'strong': array([13., 25.]),
#  'percept': array([6., 1.]),
#  'embarrass': array([6., 0.]),
#  'administr': array([4., 0.]),
#  'scandal': array([6., 1.]),
#  'monger': array([3., 0.]),
#  'grow': array([16.,  2.]),
#  'compatriot': array([1., 1.]),
#  'frighten': array([6., 1.]),
#  'tourist': array([1., 0.]),
#  'investor': array([1., 0.]),
#  'away': array([21.,  2.]),
#  'damag': array([24.,  1.]),
#  'crusad': array([1., 1.]),
#  'receiv': array([5., 1.]),
#  'fake': array([2., 0.]),
#  'uncertainti': array([8., 0.]),
#  'sent': array([6., 3.]),
#  'bell': array([2., 0.]),
#  'ring': array([4., 0.]),
#  'daunt': array([1., 0.]),
#  'spark': array([3., 0.]),
#  'recoveri': array([1., 0.]),
#  'form': array([5., 2.]),
#  'nationalist': array([2., 0.]),
#  'racism': array([1., 0.]),
#  'chang': array([15.,  9.]),
#  'come': array([9., 6.]),
#  'stake': array([3., 0.]),
#  'quit': array([10.,  8.]),
#  'naiv': array([4., 0.]),
#  'ignor': array([15.,  1.]),
#  'spite': array([5., 0.]),
#  'blame': array([32.,  0.]),
#  'fruitless': array([1., 0.]),
#  'effort': array([4., 9.]),
#  'empti': array([7., 0.]),
#  'failur': array([12.,  2.]),
#  'foregon': array([2., 0.]),
#  'stingi': array([1., 0.]),
#  'wait': array([6., 1.]),
#  'anxious': array([2., 1.]),
#  'sort': array([8., 0.]),
#  'vain': array([2., 0.]),
#  'never': array([30.,  4.]),
#  'guilti': array([3., 0.]),
#  'parti': array([7., 2.]),
#  'went': array([11.,  0.]),
#  'shortsighted': array([1., 0.]),
#  'irrespons': array([8., 0.]),
#  'pay': array([5., 1.]),
#  'enough': array([16.,  4.]),
#  'show': array([17.,  5.]),
#  'modicum': array([1., 0.]),
#  'disciplin': array([3., 1.]),
#  'cool': array([2., 0.]),
#  'approach': array([3., 5.]),
#  'realiz': array([5., 6.]),
#  'variou': array([1., 0.]),
#  'mind': array([5., 2.]),
#  'becom': array([19.,  7.]),
#  'irrit': array([10.,  0.]),
#  'obviou': array([3., 0.]),
#  'domest': array([5., 0.]),
#  'difficulti': array([9., 2.]),
#  'leap': array([1., 1.]),
#  'void': array([1., 0.]),
#  'minist': array([2., 0.]),
#  'confront': array([6., 1.]),
#  'tendenc': array([2., 0.]),
#  'toward': array([11.,  7.]),
#  'letterhead': array([1., 0.]),
#  'anyth': array([13.,  6.]),
#  'heighten': array([2., 0.]),
#  'bother': array([3., 0.]),
#  'credibl': array([ 7., 12.]),
#  'unlik': array([1., 2.]),
#  'appar': array([5., 1.]),
#  'strategi': array([5., 2.]),
#  'zone': array([1., 0.]),
#  'delug': array([1., 0.]),
#  'doubt': array([21.,  3.]),
#  'truli': array([2., 1.]),
#  'stress': array([1., 4.]),
#  'scourg': array([2., 0.]),
#  'ill': array([6., 0.]),
#  'serious': array([10.,  0.]),
#  'hinder': array([2., 0.]),
#  'unrealist': array([5., 0.]),
#  'alien': array([7., 0.]),
#  'deterior': array([7., 0.]),
#  'pass': array([4., 2.]),
#  'horror': array([4., 0.]),
#  'hamper': array([3., 0.]),
#  'highest': array([1., 0.]),
#  'abruptli': array([1., 0.]),
#  'shelv': array([1., 0.]),
#  'altogeth': array([1., 0.]),
#  'see': array([14.,  5.]),
#  'red': array([4., 0.]),
#  'light': array([3., 1.]),
#  'big': array([6., 1.]),
#  'unmistak': array([1., 0.]),
#  'potenti': array([3., 4.]),
#  'arduou': array([1., 0.]),
#  'negoti': array([4., 3.]),
#  'formid': array([2., 0.]),
#  'deadlock': array([4., 0.]),
#  'intend': array([7., 2.]),
#  'ratifi': array([2., 1.]),
#  'particularli': array([10.,  1.]),
#  'might': array([9., 2.]),
#  'apart': array([3., 0.]),
#  'high': array([ 9., 10.]),
#  'distress': array([4., 0.]),
#  'rocket': array([2., 0.]),
#  'admit': array([8., 0.]),
#  'handicap': array([1., 0.]),
#  'pour': array([3., 0.]),
#  'money': array([8., 1.]),
#  'weaken': array([3., 2.]),
#  'soon': array([3., 1.]),
#  'accept': array([25., 29.]),
#  'lawbreak': array([1., 0.]),
#  'person': array([13.,  6.]),
#  'inhospit': array([1., 0.]),
#  'ground': array([9., 1.]),
#  'serv': array([6., 3.]),
#  'give': array([15., 11.]),
#  'file': array([3., 0.]),
#  'held': array([6., 2.]),
#  'regard': array([11.,  7.]),
#  'interest': array([15., 37.]),
#  'suffici': array([3., 3.]),
#  'allianc': array([3., 0.]),
#  'apathi': array([2., 0.]),
#  'disagr': array([7., 0.]),
#  'basic': array([4., 1.]),
#  'contravent': array([2., 0.]),
#  'choru': array([5., 0.]),
#  'alway': array([11., 10.]),
#  'divest': array([1., 0.]),
#  'basi': array([5., 1.]),
#  'blatant': array([6., 0.]),
#  'case': array([7., 2.]),
#  'discrimin': array([4., 1.]),
#  'consider': array([5., 4.]),
#  'heard': array([1., 2.]),
#  'anyon': array([6., 0.]),
#  'trial': array([3., 0.]),
#  'swift': array([2., 0.]),
#  'hollow': array([1., 0.]),
#  'toll': array([4., 0.]),
#  'smooth': array([1., 1.]),
#  'either': array([7., 1.]),
#  'significantli': array([1., 1.]),
#  'repeatedli': array([5., 5.]),
#  'outrag': array([11.,  0.]),
#  'harm': array([10.,  2.]),
#  'develop': array([7., 9.]),
#  'stymi': array([1., 0.]),
#  'protect': array([6., 9.]),
#  'insuffici': array([3., 1.]),
#  'evad': array([1., 0.]),
#  'past': array([3., 3.]),
#  'hundr': array([2., 0.]),
#  'thousand': array([11.,  2.]),
#  'fulfil': array([2., 2.]),
#  'oblig': array([4., 0.]),
#  'absorb': array([2., 0.]),
#  'gestur': array([1., 0.]),
#  'signific': array([4., 3.]),
#  'road': array([4., 2.]),
#  'ahead': array([1., 5.]),
#  'surg': array([2., 2.]),
#  'deleteri': array([1., 0.]),
#  'suddenli': array([2., 0.]),
#  'prove': array([3., 3.]),
#  'imposs': array([16.,  2.]),
#  'martyr': array([1., 0.]),
#  'resist': array([10.,  4.]),
#  'disguis': array([2., 1.]),
#  'atmospher': array([4., 0.]),
#  'reign': array([1., 0.]),
#  'swiftli': array([2., 0.]),
#  'countermand': array([1., 0.]),
#  'foretast': array([1., 0.]),
#  'bad': array([21.,  2.]),
#  'memori': array([1., 0.]),
#  'rebuf': array([3., 0.]),
#  'retali': array([4., 0.]),
#  'declar': array([8., 2.]),
#  'deter': array([1., 0.]),
#  'alon': array([8., 0.]),
#  'cater': array([1., 0.]),
#  'coal': array([2., 0.]),
#  'baron': array([1., 0.]),
#  'goe': array([7., 0.]),
#  'spi': array([2., 0.]),
#  'plane': array([1., 0.]),
#  'permit': array([3., 0.]),
#  'doorstep': array([1., 0.]),
#  'apolog': array([2., 0.]),
#  'consist': array([2., 2.]),
#  'terrorist': array([24.,  1.]),
#  'flash': array([2., 0.]),
#  'carrot': array([1., 1.]),
#  'stick': array([3., 2.]),
#  'object': array([23.,  6.]),
#  'rubbl': array([1., 0.]),
#  'legitimaci': array([8., 4.]),
#  'sens': array([10., 10.]),
#  'oppress': array([14.,  1.]),
#  'activ': array([5., 6.]),
#  'vindict': array([2., 0.]),
#  'isra': array([29.,  3.]),
#  'action': array([14.,  3.]),
#  'falter': array([1., 0.]),
#  'result': array([2., 6.]),
#  'israel': array([14.,  4.]),
#  'intransig': array([1., 0.]),
#  'despit': array([15.,  1.]),
#  'weapon': array([9., 0.]),
#  'achiev': array([ 7., 10.]),
#  'full': array([ 3., 13.]),
#  'comprehens': array([5., 0.]),
#  'quiet': array([1., 1.]),
#  'reveng': array([6., 0.]),
#  'demand': array([ 7., 10.]),
#  'overlook': array([2., 0.]),
#  'attempt': array([11.,  0.]),
#  'suppress': array([9., 1.]),
#  'calm': array([ 3., 13.]),
#  'power': array([25.,  7.]),
#  'shrink': array([1., 0.]),
#  'chavez': array([6., 2.]),
#  'incap': array([5., 0.]),
#  'leader': array([2., 8.]),
#  'misfortun': array([4., 0.]),
#  'main': array([4., 1.]),
#  'area': array([3., 1.]),
#  'mean': array([14.,  4.]),
#  'resound': array([2., 0.]),
#  'sustain': array([3., 2.]),
#  'regret': array([5., 0.]),
#  'embark': array([3., 0.]),
#  'trampl': array([5., 0.]),
#  'upon': array([7., 3.]),
#  'deplor': array([2., 0.]),
#  'prohibit': array([2., 0.]),
#  'denounc': array([23.,  0.]),
#  'last': array([10.,  3.]),
#  'move': array([9., 2.]),
#  'contest': array([6., 0.]),
#  'unconstitut': array([2., 0.]),
#  'republ': array([3., 1.]),
#  'china': array([4., 3.]),
#  'quarri': array([1., 0.]),
#  'ambit': array([5., 2.]),
#  'crafti': array([2., 0.]),
#  'ruse': array([1., 0.]),
#  'pretend': array([6., 1.]),
#  'unstabl': array([2., 0.]),
#  'infuri': array([4., 0.]),
#  'sphere': array([1., 1.]),
#  'domin': array([10.,  1.]),
#  'adamantli': array([1., 0.]),
#  'employ': array([1., 0.]),
#  'trick': array([5., 0.]),
#  'scheme': array([3., 0.]),
#  'due': array([3., 3.]),
#  'settlement': array([4., 6.]),
#  'burn': array([2., 0.]),
#  'territori': array([5., 1.]),
#  'sympathet': array([2., 0.]),
#  'wound': array([2., 1.]),
#  'hesit': array([3., 0.]),
#  'took': array([13.,  0.]),
#  'imperi': array([1., 2.]),
#  'sourc': array([3., 0.]),
#  'unchang': array([1., 0.]),
#  'insult': array([8., 0.]),
#  'reason': array([14., 10.]),
#  'optimist': array([ 1., 11.]),
#  'vassal': array([1., 0.]),
#  'abid': array([2., 6.]),
#  'decis': array([12.,  5.]),
#  'disturb': array([7., 0.]),
#  'appear': array([11.,  4.]),
#  'drag': array([5., 0.]),
#  'feet': array([2., 0.]),
#  'atroci': array([3., 0.]),
#  'stratagem': array([1., 0.]),
#  'abus': array([22.,  0.]),
#  'rampant': array([2., 0.]),
#  'ruthlessli': array([1., 0.]),
#  'deem': array([4., 0.]),
#  'realli': array([11.,  3.]),
#  'revert': array([2., 0.]),
#  '1960': array([1., 0.]),
#  'subject': array([7., 1.]),
#  'simpli': array([8., 1.]),
#  'adjud': array([1., 0.]),
#  'passag': array([1., 0.]),
#  'forget': array([6., 0.]),
#  'pick': array([9., 0.]),
#  'quarrel': array([5., 0.]),
#  'send': array([4., 3.]),
#  'disagre': array([12.,  1.]),
#  'surpris': array([6., 4.]),
#  'talk': array([4., 4.]),
#  'wonder': array([3., 0.]),
#  'imperialist': array([8., 1.]),
#  'reactionari': array([1., 0.]),
#  'teach': array([2., 0.]),
#  'lesson': array([4., 1.]),
#  'two': array([8., 1.]),
#  'qualifi': array([5., 0.]),
#  'indiffer': array([5., 0.]),
#  'gaze': array([1., 0.]),
#  'seem': array([17.,  4.]),
#  'extra': array([1., 1.]),
#  'judici': array([1., 0.]),
#  'liquid': array([3., 0.]),
#  'instrument': array([3., 2.]),
#  'hope': array([ 7., 98.]),
#  'massacr': array([9., 0.]),
#  'sabra': array([1., 0.]),
#  'shatila': array([1., 0.]),
#  'deriv': array([1., 0.]),
#  'encourag': array([ 9., 16.]),
#  'chanc': array([6., 5.]),
#  'exodu': array([2., 0.]),
#  'collaps': array([7., 3.]),
#  'death': array([9., 1.]),
#  'normal': array([2., 2.]),
#  'settl': array([4., 0.]),
#  'someon': array([2., 0.]),
#  'els': array([3., 1.]),
#  'absolut': array([7., 3.]),
#  'extremist': array([8., 0.]),
#  'drive': array([3., 0.]),
#  'approv': array([ 3., 24.]),
#  'ask': array([ 1., 25.]),
#  'polici': array([37.,  3.]),
#  'eat': array([3., 0.]),
#  'feed': array([1., 0.]),
#  'longer': array([9., 0.]),
#  'encyst': array([1., 0.]),
#  'expuls': array([1., 0.]),
#  'contradictori': array([2., 0.]),
#  'believ': array([10., 14.]),
#  'end': array([12., 13.]),
#  'french': array([1., 0.]),
#  ...}

# %%
# convert the freqs dictionary to nested list
def freqs_to_df(freqs, train_y):
    '''
    input:
        freqs: a frequencies dictionary (ex: {'simplist': array([15.,  4.]), 
                                              'silli': array([64., 20.]), . . })
        train_y: labels for data
    output:
        a frequencies dictionary in the form of dataframe
    '''
    # initialize an empty list to store the rows for dataframe
    freqs_list = []
    
    # Define the names of the dataframe columns
    column_names = ['word']
    column_names = column_names + list(np.unique(train_y))
    
    # convert the keys from the freqs dictionary to a list
    keys = list(freqs.keys())

    # For each row
    for i in range(len(freqs)):
        
        # define the elements for each column
        row = [keys[i]] + list(freqs.get(keys[i]))
        
        # update the frequency list
        freqs_list.append(row)
    
    # Create the dataframe
    df = pd.DataFrame(freqs_list, columns=column_names)
    df.set_index('word', inplace=True)
    return df

# %%
freqs_df = freqs_to_df(freqs, labels)
freqs_df
# Out:
#              0      1
# word
# complain  11.0    2.0
# fail      33.0    3.0
# support   26.0  238.0
# desper    19.0    0.0
# need      12.0    5.0
# ...        ...    ...
# nich       0.0    2.0
# fairer     0.0    2.0
# window     0.0    3.0
# soften     0.0    1.0
# strictli   0.0    3.0
#
# [4163 rows x 2 columns]

# %%
freqs_df[0].sum()
# Out:
# 14903.0

# %% [markdown]
# # Training and Testing the Model

# %% [markdown]
# ## Build Training Function

# %%
def train_naive_bayes(freq_df, train_x, train_y):
    '''
    Input:
        freqs: a pandas dataframe with word indexing
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    
    freqs = freq_df

    # calculate V, the number of unique words in the vocabulary
    vocab = list(freqs.index)
    V = len(vocab)
    
    ########################################################################################
    # Part 1: Calculate the log prior probability for each class
    
    # Calculate D, the number of documents
    D = len(train_y)
    
    labels = list(np.unique(train_y.astype(int)))
    count = np.zeros((len(labels),))

    for train_label in train_y:
        for unique_label in labels:
            if train_label == unique_label:
                count[unique_label]+=1
                
    # -> count = [4000, 4000]; it means perfectly balanced between each classese

    # Calculate prior probability for each class
    prior = count/D # -> prior = array([0.5, 0.5])
    
        
    # Calculate the logprior for each class
    logprior = np.log(prior) # -> prior = array([-0.69314718, -0.69314718])
    
    ########################################################################################
    # Part 2.a. Calculate the total number of word occurrences for each class
    
    columns = list(freqs.columns)
    N_classes = []
    # calculate N frequency for each class
    for column in columns:
        
        freqs[column] = (freqs[column] + 1)/(freqs[column].sum()+V)
        
    # Calculate the log likelihood of the word
    loglikelihood = np.log(freqs)
        
    ########################################################################################
        
    return logprior, loglikelihood

# %%
labels = np.array(labels)
logprior, loglikelihood = train_naive_bayes(freqs_df, sentences, labels)
print(logprior)
loglikelihood
# Out:
# [-0.37436779 -1.16386764]
#                  0         1
# word
# complain -7.370755 -8.107620
# fail     -6.329301 -7.819938
# support  -6.559825 -3.729768
# desper   -6.859930 -9.206232
# need     -7.290713 -7.414472
# ...            ...       ...
# nich     -9.855662 -8.107620
# fairer   -9.855662 -8.107620
# window   -9.855662 -7.819938
# soften   -9.855662 -8.513085
# strictli -9.855662 -7.819938
#
# [4163 rows x 2 columns]

# %% [markdown]
# ## Build Testing Function

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    input:
        tweet: a string
        logprior: initial probability based on dataset
        loglikelihood: a dictionary of words mapping to numbers
    output:
        p: the sum of all the loglikelihood of each word in the tweet
        (if found in the dictionary) + logprior (a number)
    '''
    
    # process the tweet to get the list of words
    words = clean_doc(tweet)
    
    
    # Initialize probability to zero
    probs = []
    columns = list(loglikelihood.columns)
    for column in columns:
        prob = 0
        # Iterate for each word in word list
        for word in words:

            # check if the word exist in the loglikelihood dictionary
            if word in loglikelihood.index:
                prob += loglikelihood.loc[word, column]
        
        probs.append(prob)
        
    probs = logprior + probs
    y_hat = np.argmax(probs)
    
    return probs, y_hat

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    output:
        accuracy: (# of tweets classified correctly)/total # of tweets
    """
    # initial accuracy
    acc = 0
    
    # initialize an empty list for storing the predictions
    y_hats = []

    for tweet in test_x:
        
        _ , y = naive_bayes_predict(tweet, logprior, loglikelihood)
        
#         y_hat = np.argmax(probs)
        
        # update the y_hats
        y_hats.append(y)
        
#     Error: the mean absolute values between y_hats and test_y
    error = np.mean(np.abs(np.array(y_hats)-np.array(test_y)))
        
#     Accuracy is 1 - error
    acc = 1-error
    return acc

# %% [markdown]
# ## KFold CV

# %%
###############################################
# Training and Testing using the same Dataset #
###############################################

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), np.array(list(corpus.label))

# Build the freqs dictionary for later uses
freqs = count_docs({}, sentences, labels)

# Turn the frequencies dictionary into dataframe
freqs_df = freqs_to_df(freqs, labels)
print(freqs_df.head())

# Retrieve the logprior and loglikelihood
logprior, loglikelihood = train_naive_bayes(freqs_df, sentences, labels)
print(logprior)
print(loglikelihood.head())

print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(sentences, labels, logprior, loglikelihood)))
# Out:
#              0      1
# word
# complain  11.0    2.0
# fail      33.0    3.0
# support   26.0  238.0
# desper    19.0    0.0
# need      12.0    5.0
# [-0.37436779 -1.16386764]
#                  0         1
# word
# complain -7.370755 -8.107620
# fail     -6.329301 -7.819938
# support  -6.559825 -3.729768
# desper   -6.859930 -9.206232
# need     -7.290713 -7.414472
# Naive Bayes accuracy = 0.8995

# %%
#######################################################
# Training and Testing using 10-fold Cross Validation #
#######################################################

# prepare cross validation
kfold = KFold(10, True)

# Separate the sentences and the labels
sentences, labels = list(corpus.sentence), list(corpus.label)
# count = 0
acc_list = []
# kfold.split() will return set indices for each split
for train, test in kfold.split(sentences):
    train_x, train_y = [], []
    test_x, test_y = [], []
    for i in train:
        train_x.append(sentences[i])
        train_y.append(labels[i])
        
    for i in test:
        test_x.append(sentences[i])
        test_y.append(labels[i])
    
    train_y = np.array(train_y)
    test_y = np.array(test_y)
    
    # Build the freqs dictionary for later uses
    freqs = count_docs({}, train_x, train_y)

    # Turn the frequencies dictionary into dataframe
    freqs_df = freqs_to_df(freqs, train_y)
#     print(freqs_df.head())

    # Retrieve the logprior and loglikelihood
    logprior, loglikelihood = train_naive_bayes(freqs_df, train_x, train_y)
    print('loglikelihood:\n{}'.format(loglikelihood.head()))
    print('logprior: {}'.format(logprior))
    
    acc = test_naive_bayes(test_x, test_y, logprior, loglikelihood)
    print("Naive Bayes test accuracy = %0.4f\n" %(acc))
    
    acc_list.append(acc)

acc_list = np.array(acc_list)
print()
print('The test ccuracy for each training:\n{}'.format(acc_list))
print('The mean of the test accuracy: ', acc_list.mean())
# Out:
# C:\Users\Diardano Raihan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass shuffle=True as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# loglikelihood:
#                  0         1
# word
# complain -7.276902 -8.030193
# fail     -6.296073 -7.742511
# support  -6.670766 -3.748908
# desper   -6.928595 -9.128805
# need     -7.459224 -7.337045
# logprior: [-0.37777453 -1.15640567]
# Naive Bayes test accuracy = 0.8360
#
# loglikelihood:
#                  0         1
# word
# complain -7.459684 -8.038727
# fail     -6.361072 -8.038727
# support  -6.584216 -3.771363
# quick    -8.375975 -8.038727
# fix      -8.663657 -8.444192
# logprior: [-0.3779274  -1.15607272]
# Naive Bayes test accuracy = 0.8379
#
# loglikelihood:
#                  0         1
# word
# complain -7.365870 -8.433812
# fail     -6.329778 -7.740664
# support  -6.467929 -3.728796
# desper   -6.873394 -9.126959
# need     -7.278859 -7.517521
# logprior: [-0.37746886 -1.15707189]
# Naive Bayes test accuracy = 0.8577
#
# loglikelihood:
#                 0         1
# word
# fail    -6.424464 -8.021694
# support -6.578614 -3.749668
# desper  -6.812229 -9.120306
# need    -7.271762 -7.328547
# mani    -6.866297 -8.021694
# logprior: [-0.37578934 -1.16074407]
# Naive Bayes test accuracy = 0.8388
#
# loglikelihood:
#                  0         1
# word
# complain -7.366215 -8.026388
# fail     -6.298375 -7.738706
# support  -6.586057 -3.735929
# desper   -6.768378 -9.125000
# need     -7.199161 -7.333241
# logprior: [-0.37426495 -1.16409416]
# Naive Bayes test accuracy = 0.8341
#
# loglikelihood:
#                  0         1
# word
# complain -7.279664 -8.026061
# fail     -6.268063 -7.738379
# support  -6.545694 -3.744776
# desper   -6.931357 -9.124674
# need     -7.279664 -7.332914
# logprior: [-0.37274288 -1.1674555 ]
# Naive Bayes test accuracy = 0.8369
#
# loglikelihood:
#                  0         1
# word
# complain -7.281041 -8.025189
# fail     -6.300212 -7.737507
# support  -6.547072 -3.781467
# desper   -6.875576 -9.123802
# need     -7.281041 -7.332042
# logprior: [-0.37041714 -1.17262357]
# Naive Bayes test accuracy = 0.8453
#
# loglikelihood:
#                  0         1
# word
# complain -7.369429 -8.031169
# desper   -6.994735 -9.129781
# need     -7.369429 -7.743487
# mani     -6.934111 -8.031169
# year     -6.822885 -7.743487
# logprior: [-0.37223946 -1.16857088]
# Naive Bayes test accuracy = 0.8443
#
# loglikelihood:
#                  0         1
# word
# complain -7.568838 -8.019174
# fail     -6.433858 -7.731492
# support  -6.547187 -3.747148
# desper   -6.821624 -9.117786
# need     -7.201114 -7.326027
# logprior: [-0.36890107 -1.1760134 ]
# Naive Bayes test accuracy = 0.8453
#
# loglikelihood:
#                  0         1
# word
# complain -7.363856 -8.025407
# fail     -6.327764 -8.025407
# support  -6.583697 -3.744122
# desper   -6.766019 -9.124020
# need     -7.276845 -7.514582
# logprior: [-0.37619926 -1.15984599]
# Naive Bayes test accuracy = 0.8491
#
#
# The test ccuracy for each training:
# [0.83600377 0.83788878 0.85768143 0.83883129 0.83411876 0.83694628
#  0.84528302 0.84433962 0.84528302 0.8490566 ]
# The mean of the test accuracy:  0.8425432575178275
